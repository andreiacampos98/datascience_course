# %% [markdown]
# # 1. Importação dos ficheiros e merge

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import MinMaxScaler
from sklearn.impute import KNNImputer

# %%
#data_labels_excel = pd.read_excel('Data_labels.xlsx', index_col=None)
#data_store_excel = pd.read_excel('Data_store.xlsx', index_col=None)

# %%
#data_labels_excel.to_csv('data_labels.csv', index=False)
#data_store_excel.to_csv('data_store.csv', index=False)

# %%
data_labels = pd.read_csv('data_labels.csv', low_memory=False)

data_store = pd.read_csv('data_store.csv')

# %%
data_labels.head()
# Out:
#    idstore  sku     brand oldpvp new_pvp (discount)  labelqty weight (g)  \
# 0        1    1  Marca  1   4.22        2.11 (0.50)         1        260
# 1        1    1   Marca 1   3.96        1.98 (0.50)         1        260
# 2        1    1  Marca  1   4.74        2.37 (0.50)         1        260
# 3        1    1   Marca 1    4.2         2.1 (0.50)         1        260
# 4        1    1  Marca  1   4.62        2.31 (0.50)         1        260
#
#   Payment_method  Margin (%)  Profit (€)  perc_expiring_sku expiring_date  \
# 0           Card          16      0.3376           0.010050    03/10/2021
# 1                         16      0.3168           0.005025    02/10/2021
# 2           Cash          16      0.3792           0.010050    03/10/2021
# 3           Card          16      0.3360           0.010050    03/10/2021
# 4           Cash          16      0.3696           0.010050    03/10/2021
#
#   labelling_date   sell_date  sold
# 0     2021-10-01  2021-10-02   1.0
# 1     2021-10-01         NaN   0.0
# 2     2021-10-01  2021-10-03   1.0
# 3     2021-10-01  2021-10-02   1.0
# 4     2021-10-01  2021-10-03   NaN

# %%
data_store.head()
# Out:
#    idstore   type  selling_square_ft  district
# 0        1  Large             4762.0     Évora
# 1        2  Large            12358.0  Bragança
# 2        3  Large            16159.0    Lisboa
# 3        4  Large            17903.0     Porto
# 4        5  Large            16179.0   Coimbra

# %%
db = data_labels.merge(data_store, on = 'idstore' )

# %%
db.head()
# Out:
#    idstore  sku     brand oldpvp new_pvp (discount)  labelqty weight (g)  \
# 0        1    1  Marca  1   4.22        2.11 (0.50)         1        260
# 1        1    1   Marca 1   3.96        1.98 (0.50)         1        260
# 2        1    1  Marca  1   4.74        2.37 (0.50)         1        260
# 3        1    1   Marca 1    4.2         2.1 (0.50)         1        260
# 4        1    1  Marca  1   4.62        2.31 (0.50)         1        260
#
#   Payment_method  Margin (%)  Profit (€)  perc_expiring_sku expiring_date  \
# 0           Card          16      0.3376           0.010050    03/10/2021
# 1                         16      0.3168           0.005025    02/10/2021
# 2           Cash          16      0.3792           0.010050    03/10/2021
# 3           Card          16      0.3360           0.010050    03/10/2021
# 4           Cash          16      0.3696           0.010050    03/10/2021
#
#   labelling_date   sell_date  sold   type  selling_square_ft district
# 0     2021-10-01  2021-10-02   1.0  Large             4762.0    Évora
# 1     2021-10-01         NaN   0.0  Large             4762.0    Évora
# 2     2021-10-01  2021-10-03   1.0  Large             4762.0    Évora
# 3     2021-10-01  2021-10-02   1.0  Large             4762.0    Évora
# 4     2021-10-01  2021-10-03   NaN  Large             4762.0    Évora

# %% [markdown]
# # 2. Exploração inicial

# %% [markdown]
# Problemas detetados:
#
# *   brand's com marcas iguais mas de forma diferente (Ex.: marca 1,  marca  1, Marca1, etc)
# *   oldpvp com alguns valores separados por "," e outros por "."; sem duas casas decimais também
# *   newpvp sem 2 casas decimais também
# *   perc_expiring_sku com valores superiores a 1
# *   expiring_date, labelling_date e selling date com formatos diferentes
# *   payment_method tem valores nulos. Substituir por um valor

# %%
db.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150054 entries, 0 to 150053
# Data columns (total 18 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   idstore             150054 non-null  int64
#  1   sku                 150054 non-null  int64
#  2   brand               150054 non-null  object
#  3   oldpvp              150032 non-null  object
#  4   new_pvp (discount)  150026 non-null  object
#  5   labelqty            150054 non-null  int64
#  6   weight (g)          150050 non-null  object
#  7   Payment_method      150054 non-null  object
#  8   Margin (%)          150054 non-null  int64
#  9   Profit (€)          150054 non-null  float64
#  10  perc_expiring_sku   149929 non-null  float64
#  11  expiring_date       150054 non-null  object
#  12  labelling_date      150054 non-null  object
#  13  sell_date           80511 non-null   object
#  14  sold                149940 non-null  float64
#  15  type                150054 non-null  object
#  16  selling_square_ft   139275 non-null  float64
#  17  district            150054 non-null  object
# dtypes: float64(4), int64(4), object(10)
# memory usage: 20.6+ MB

# %%
db.columns
# Out:
# Index(['idstore', 'sku', 'brand', 'oldpvp', 'new_pvp (discount)', 'labelqty',
#        'weight (g)', 'Payment_method', 'Margin (%)', 'Profit (€)',
#        'perc_expiring_sku', 'expiring_date', 'labelling_date', 'sell_date',
#        'sold', 'type', 'selling_square_ft', 'district'],
#       dtype='object')

# %%
db[db.duplicated()]
# Out:
#         idstore  sku      brand oldpvp new_pvp (discount)  labelqty  \
# 36            7    2     Marca2   3.19        2.39 (0.25)         1
# 39            7    2    Marca 2   3.19        2.39 (0.25)         1
# 41            7    2    Marca 2   3.19        2.39 (0.25)         1
# 42            7    2   Marca  2   3.19        2.39 (0.25)         1
# 43            7    2    Marca 2   3.19        2.39 (0.25)         1
# ...         ...  ...        ...    ...                ...       ...
# 150034      177  318     Marca2   2.49         1,24 (50%)         1
# 150036      177  318    Marca 2   2.49         1,24 (50%)         1
# 150038      177  318  Marca   2   2.49         1,24 (50%)         1
# 150048      193  318   Marca  2   2.49        1.24 (0.50)         1
# 150051      203  318     Marca2   2.49        1.24 (0.50)         1
#
#        weight (g) Payment_method  Margin (%)  Profit (€)  perc_expiring_sku  \
# 36            222                         15      0.3585           0.111111
# 39            222                         15      0.3585           0.111111
# 41            222                         15      0.3585           0.111111
# 42            222                         15      0.3585           0.111111
# 43            222                         15      0.3585           0.111111
# ...           ...            ...         ...         ...                ...
# 150034         97                         11      0.1364           0.006289
# 150036         97                         11      0.1364           0.006289
# 150038         97                         11      0.1364           0.006289
# 150048         97           Cash          11      0.1364           0.100629
# 150051         97           Cash          11      0.1364           0.113208
#
#        expiring_date labelling_date   sell_date  sold    type  \
# 36        26/10/2021     2021-10-15         NaN   0.0   Large
# 39        26/10/2021     2021-10-15         NaN   0.0   Large
# 41        26/10/2021     2021-10-15         NaN   0.0   Large
# 42        26/10/2021     2021-10-15         NaN   0.0   Large
# 43        26/10/2021     2021-10-15         NaN   0.0   Large
# ...              ...            ...         ...   ...     ...
# 150034    19-10-2021     2021-10-18         NaN   0.0   Small
# 150036    19-10-2021     2021-10-18         NaN   0.0   Small
# 150038    19-10-2021     2021-10-18         NaN   0.0   Small
# 150048    19-10-2021     2021-10-03  2021-10-09   1.0  Medium
# 150051    19-10-2021     2021-10-01  2021-10-02   1.0  Medium
#
#         selling_square_ft district
# 36                13618.0   Guarda
# 39                13618.0   Guarda
# 41                13618.0   Guarda
# 42                13618.0   Guarda
# 43                13618.0   Guarda
# ...                   ...      ...
# 150034              842.0    Porto
# 150036              842.0    Porto
# 150038              842.0    Porto
# 150048             5048.0    Viseu
# 150051             9370.0     Faro
#
# [33740 rows x 18 columns]

# %% [markdown]
# várias pessoas podem comprar o mesmo produto, na mesma loja, no mesmo dia, pelo que não iremos apagar os duplicados

# %% [markdown]
# ## 2.1 Tratamento de problemas de formatação

# %% [markdown]
# ### 2.1.1. Brand

# %%
db['brand'].value_counts()
# Out:
# brand
#  marca 2      18249
#  Marca 2      17008
# marca  2       9077
# marca   2      9068
# marca2         9043
#               ...
# Marca 38          1
# marca  39         1
# marca   39        1
# Marca  42         1
#  Marca 42         1
# Name: count, Length: 328, dtype: int64

# %%
db['brand'] = db['brand'].str.lower()
db['brand'] = db['brand'].str.replace(' ', '')
db['brand'].value_counts()
# Out:
# brand
# marca2     106163
# marca7      15428
# marca15     12543
# marca5       5418
# marca12      1760
# marca25      1279
# marca9       1126
# marca3        880
# marca33       846
# marca28       725
# marca8        539
# marca4        513
# marca21       481
# marca26       470
# marca17       258
# marca6        227
# marca16       185
# marca29       175
# marca22       131
# marca13       113
# marca23       111
# marca10       101
# marca41        93
# marca18        86
# marca20        83
# marca40        73
# marca27        71
# marca24        61
# marca32        48
# marca1         14
# marca11        10
# marca31         9
# marca37         8
# marca36         8
# marca19         5
# marca39         4
# marca42         2
# marca14         2
# marca38         2
# marca30         1
# marca34         1
# marca35         1
# Name: count, dtype: int64

# %%
db['brand'].value_counts()
# Out:
# brand
# marca2     106163
# marca7      15428
# marca15     12543
# marca5       5418
# marca12      1760
# marca25      1279
# marca9       1126
# marca3        880
# marca33       846
# marca28       725
# marca8        539
# marca4        513
# marca21       481
# marca26       470
# marca17       258
# marca6        227
# marca16       185
# marca29       175
# marca22       131
# marca13       113
# marca23       111
# marca10       101
# marca41        93
# marca18        86
# marca20        83
# marca40        73
# marca27        71
# marca24        61
# marca32        48
# marca1         14
# marca11        10
# marca31         9
# marca37         8
# marca36         8
# marca19         5
# marca39         4
# marca42         2
# marca14         2
# marca38         2
# marca30         1
# marca34         1
# marca35         1
# Name: count, dtype: int64

# %%
db['brand'].unique()
# Out:
# array(['marca1', 'marca2', 'marca3', 'marca4', 'marca5', 'marca6',
#        'marca7', 'marca8', 'marca9', 'marca10', 'marca11', 'marca12',
#        'marca13', 'marca14', 'marca15', 'marca16', 'marca17', 'marca30',
#        'marca19', 'marca20', 'marca21', 'marca22', 'marca18', 'marca23',
#        'marca24', 'marca25', 'marca26', 'marca27', 'marca28', 'marca29',
#        'marca31', 'marca32', 'marca33', 'marca34', 'marca35', 'marca36',
#        'marca37', 'marca38', 'marca39', 'marca40', 'marca41', 'marca42'],
#       dtype=object)

# %% [markdown]
# ### 2.1.2. Oldpvp

# %%
db['oldpvp'] = db['oldpvp'].str.replace(',', '.')

# %%
db['oldpvp'].unique()
# Out:
# array(['4.22', '3.96', '4.74', '4.2', '4.62', '3.42', '3.62', '4.38',
#        '5.23', '5.89', '3.78', '4.76', '3.19', nan, '2.65', '2.79', '500',
#        '46', '2.99', '1.39', '2.19', '1.19', '1.25', '3.99', '4.29',
#        '1.99', '0.79', '1.29', '1.79', '1.15', '2.69', '2.49', '2.59',
#        '4.39', '0.96', '0.98', '4.59', '1.49', '0.99', '4.99', '17.99',
#        '2.39', '0.97', '0.95', '1', '1.09', '0.69', '0.76', '2.95',
#        '1.59', '1.95', '1.89', '3.29', '2.80', '4.15', '1.69', '3.39',
#        '3.24', '2.89', '1.75', '2.29', '999', '1.54', '3.49', '2.75',
#        '1.05', '3.35', '0.89', '0.85', '1.55', '2.5', '2.50', '2.09',
#        '14.99', '0.59', '1.33', '1.65', '3.8', '2.45', '4.89', '1.9',
#        '3.09', '1.12', '1.47', '1.22', '1.71', '1.36', '1.68', '1.78',
#        '1.5', '1.61', '1.57', '1.26', '1.43', '1.08', '2.1', '0.91',
#        '1.4', '2.03', '0.84', '0.94', '1.44'], dtype=object)

# %%
db['oldpvp'] = db['oldpvp'].astype(float).round(2)

# %% [markdown]
# ### 2.1.3. New_pvp

# %%
db[['new_pvp', 'discount']] = db['new_pvp (discount)'].str.split('(', expand=True)
db['new_pvp'] = db['new_pvp'].str.strip()
db['discount'] = db['discount'].str.rstrip(')')

# %%
db.head()
# Out:
#    idstore  sku   brand  oldpvp new_pvp (discount)  labelqty weight (g)  \
# 0        1    1  marca1    4.22        2.11 (0.50)         1        260
# 1        1    1  marca1    3.96        1.98 (0.50)         1        260
# 2        1    1  marca1    4.74        2.37 (0.50)         1        260
# 3        1    1  marca1    4.20         2.1 (0.50)         1        260
# 4        1    1  marca1    4.62        2.31 (0.50)         1        260
#
#   Payment_method  Margin (%)  Profit (€)  perc_expiring_sku expiring_date  \
# 0           Card          16      0.3376           0.010050    03/10/2021
# 1                         16      0.3168           0.005025    02/10/2021
# 2           Cash          16      0.3792           0.010050    03/10/2021
# 3           Card          16      0.3360           0.010050    03/10/2021
# 4           Cash          16      0.3696           0.010050    03/10/2021
#
#   labelling_date   sell_date  sold   type  selling_square_ft district new_pvp  \
# 0     2021-10-01  2021-10-02   1.0  Large             4762.0    Évora    2.11
# 1     2021-10-01         NaN   0.0  Large             4762.0    Évora    1.98
# 2     2021-10-01  2021-10-03   1.0  Large             4762.0    Évora    2.37
# 3     2021-10-01  2021-10-02   1.0  Large             4762.0    Évora     2.1
# 4     2021-10-01  2021-10-03   NaN  Large             4762.0    Évora    2.31
#
#   discount
# 0     0.50
# 1     0.50
# 2     0.50
# 3     0.50
# 4     0.50

# %%
db['new_pvp'] = db['new_pvp'].str.replace(',', '.')
db['new_pvp'] = db['new_pvp'].astype(float).round(2)

# %%
def convert_discount(discount_str):
    if isinstance(discount_str, str):
        if '%' in discount_str:
            try:
                return float(discount_str.replace('%', '')) / 100
            except ValueError:
                return np.nan
        elif discount_str == 'nan':
            return np.nan
        else:
          try:
            return float(discount_str)
          except:
            return np.nan
    elif pd.isna(discount_str):
      return np.nan
    else:
        return discount_str

db['discount'] = db['discount'].apply(convert_discount)
db['discount'] = db['discount'].astype(float).round(2)

# %%
db = db.drop('new_pvp (discount)', axis=1)

# %%
db['discount'].describe()
# Out:
# count    150026.000000
# mean          0.302269
# std           0.036940
# min           0.010000
# 25%           0.300000
# 50%           0.300000
# 75%           0.300000
# max           0.990000
# Name: discount, dtype: float64

# %%
db.columns
# Out:
# Index(['idstore', 'sku', 'brand', 'oldpvp', 'labelqty', 'weight (g)',
#        'Payment_method', 'Margin (%)', 'Profit (€)', 'perc_expiring_sku',
#        'expiring_date', 'labelling_date', 'sell_date', 'sold', 'type',
#        'selling_square_ft', 'district', 'new_pvp', 'discount'],
#       dtype='object')

# %% [markdown]
# ### 2.1.4. Profit (€)

# %%
db['Profit (€)'] = db['Profit (€)'].astype(float).round(2)

# %% [markdown]
# ### 2.1.5. Margin (%)

# %%
db['Margem_num']=db['Margin (%)']/100
db = db.drop('Margin (%)', axis=1)

# %%
db.head()
# Out:
#    idstore  sku   brand  oldpvp  labelqty weight (g) Payment_method  \
# 0        1    1  marca1    4.22         1        260           Card
# 1        1    1  marca1    3.96         1        260
# 2        1    1  marca1    4.74         1        260           Cash
# 3        1    1  marca1    4.20         1        260           Card
# 4        1    1  marca1    4.62         1        260           Cash
#
#    Profit (€)  perc_expiring_sku expiring_date labelling_date   sell_date  \
# 0        0.34           0.010050    03/10/2021     2021-10-01  2021-10-02
# 1        0.32           0.005025    02/10/2021     2021-10-01         NaN
# 2        0.38           0.010050    03/10/2021     2021-10-01  2021-10-03
# 3        0.34           0.010050    03/10/2021     2021-10-01  2021-10-02
# 4        0.37           0.010050    03/10/2021     2021-10-01  2021-10-03
#
#    sold   type  selling_square_ft district  new_pvp  discount  Margem_num
# 0   1.0  Large             4762.0    Évora     2.11       0.5        0.16
# 1   0.0  Large             4762.0    Évora     1.98       0.5        0.16
# 2   1.0  Large             4762.0    Évora     2.37       0.5        0.16
# 3   1.0  Large             4762.0    Évora     2.10       0.5        0.16
# 4   NaN  Large             4762.0    Évora     2.31       0.5        0.16

# %% [markdown]
# ### 2.1.6. perc_expiring_sku

# %%
db['perc_expiring_sku'].unique()
# Out:
# array([0.01005025, 0.00502513, 0.12121212, 0.11111111, 0.1010101 ,
#        0.04040404, 0.06060606, 0.13131313, 0.25      , 0.        ,
#        0.5       , 0.14285714, 0.125     , 0.66666667, 0.33333333,
#        0.2       , 0.4       , 0.34482759, 0.37931034, 0.0754717 ,
#        0.12578616, 0.06289308, 0.03351955, 0.02892562, 0.0292887 ,
#        0.0334728 , 2.        , 0.05405405, 0.0472973 , 0.03378378,
#        0.08264463, 0.05050505, 0.00413223, 0.09090909, 0.08176101,
#        0.02515723, 0.02479339, 1.8       , 1.        , 0.01515152,
#        0.06818182, 0.08333333, 0.07575758, 0.1875    , 0.08080808,
#        0.03144654, 0.04469274, 0.03910615, 0.16      , 0.28      ,
#        0.32      , 0.09352518, 0.07913669, 0.01438849, 0.08633094,
#        0.05035971, 0.05755396, 0.18461538, 0.03076923, 0.01538462,
#        0.16923077, 0.06918239, 0.03773585, 0.06703911, 0.0726257 ,
#        0.02234637, 0.01675978, 0.04545455, 0.01886792, 0.05660377,
#        0.03305785, 0.07878788, 0.07272727, 0.13836478, 0.01257862,
#        0.10062893, 0.00628931, 0.10691824, 0.05263158, 0.04590164,
#        0.09243697, 0.07563025, 0.10126582, 0.07070707, 0.05936073,
#        0.09848485, 0.02020202, 0.13207547, 0.11320755, 0.10330579,
#        0.05586592, 0.05027933, 0.03125   , 0.03719008, 0.04109589,
#        0.05022831, 0.02066116, 0.01652893, 0.13333333, 0.04054054,
#        0.00826446, 0.1242236 , 0.02484472, 0.04075235, 0.04388715,
#        0.08      , 0.03064067, 0.26666667, 0.00558659, 0.0041841 ,
#        0.01117318, 0.05479452, 0.01369863, 0.01826484, 0.02283105,
#        0.03652968, 0.04395604, 0.03846154, 0.02      , 0.07333333,
#        0.08666667, 0.06      , 0.04666667, 0.02666667, 0.06666667,
#        0.0530303 , 0.03030303, 0.04201681, 0.03361345, 0.02793296,
#        0.03787879, 0.28571429, 0.02521008, 0.0209205 , 0.05128205,
#        0.07692308, 0.16666667, 0.05333333, 0.03333333, 0.04020101,
#               nan, 0.22222222, 0.05031447, 0.08403361, 0.0201005 ,
#        0.03517588, 0.03015075, 0.06722689, 0.05882353, 0.05042017,
#        0.01680672, 0.10759494, 0.01239669, 0.04402516])

# %% [markdown]
# Após análise verificámos que existem valores incorrectos (>1) no per_expering_sku. Estes valores estão associados a 2 tipos de Sku (122 e 134). Desta forma decidimos alterar o per_expering_sku pela média de todos os produtos. Não foi possível fazer a média por produto, visto que todas as observações destes sku's estavam mapeadas com valores incorrectos.

# %%
# Para db['perc_expiring_sku'] acima de 1, substituímo-los pela média da coluna
mean_perc_expiring_sku = db[db['perc_expiring_sku'] <= 1]['perc_expiring_sku'].mean()
db.loc[db['perc_expiring_sku'] > 1, 'perc_expiring_sku'] = mean_perc_expiring_sku

# %%
db['perc_expiring_sku'].describe()
# Out:
# count    149929.000000
# mean          0.384977
# std           0.222661
# min           0.000000
# 25%           0.200000
# 50%           0.333333
# 75%           0.666667
# max           1.000000
# Name: perc_expiring_sku, dtype: float64

# %% [markdown]
# ### 2.1.7. Expiring_date, labelling_date, sell_date

# %%
# Replace '-' with '/' in 'expiring_date', 'labelling_date', and 'sell_date' columns
for col in ['expiring_date', 'labelling_date', 'sell_date']:
    if col in db.columns:  # Check if the column exists
        db[col] = db[col].astype(str).str.replace('-', '/', regex=False)

# %%
db.head()
# Out:
#    idstore  sku   brand  oldpvp  labelqty weight (g) Payment_method  \
# 0        1    1  marca1    4.22         1        260           Card
# 1        1    1  marca1    3.96         1        260
# 2        1    1  marca1    4.74         1        260           Cash
# 3        1    1  marca1    4.20         1        260           Card
# 4        1    1  marca1    4.62         1        260           Cash
#
#    Profit (€)  perc_expiring_sku expiring_date labelling_date   sell_date  \
# 0        0.34           0.010050    03/10/2021     2021/10/01  2021/10/02
# 1        0.32           0.005025    02/10/2021     2021/10/01         nan
# 2        0.38           0.010050    03/10/2021     2021/10/01  2021/10/03
# 3        0.34           0.010050    03/10/2021     2021/10/01  2021/10/02
# 4        0.37           0.010050    03/10/2021     2021/10/01  2021/10/03
#
#    sold   type  selling_square_ft district  new_pvp  discount  Margem_num
# 0   1.0  Large             4762.0    Évora     2.11       0.5        0.16
# 1   0.0  Large             4762.0    Évora     1.98       0.5        0.16
# 2   1.0  Large             4762.0    Évora     2.37       0.5        0.16
# 3   1.0  Large             4762.0    Évora     2.10       0.5        0.16
# 4   NaN  Large             4762.0    Évora     2.31       0.5        0.16

# %%
def convert_date(date_str):
    if pd.isna(date_str):
        return pd.NaT
    elif isinstance(date_str, str):
        try:
            return pd.to_datetime(date_str, format='%Y/%m/%d', errors='raise')
        except ValueError:
            try:
                return pd.to_datetime(date_str, format='%d/%m/%Y', errors='raise')
            except ValueError:
              try:
                return pd.to_datetime(date_str, format='%m/%d/%Y', errors='raise')
              except ValueError:
                return pd.NaT # Return Not a Time if format is invalid
    return pd.NaT

for col in ['expiring_date', 'labelling_date', 'sell_date']:
    if col in db.columns:
        db[col] = db[col].apply(convert_date)
        db[col] = db[col].dt.strftime('%Y/%m/%d')

# %%
# Convert 'labelling_date' and 'sell_date' to datetime objects
db['labelling_date'] = pd.to_datetime(db['labelling_date'])
db['expiring_date'] = pd.to_datetime(db['expiring_date'])
db['sell_date'] = pd.to_datetime(db['sell_date'])

# %%
db.head()
# Out:
#    idstore  sku   brand  oldpvp  labelqty weight (g) Payment_method  \
# 0        1    1  marca1    4.22         1        260           Card
# 1        1    1  marca1    3.96         1        260
# 2        1    1  marca1    4.74         1        260           Cash
# 3        1    1  marca1    4.20         1        260           Card
# 4        1    1  marca1    4.62         1        260           Cash
#
#    Profit (€)  perc_expiring_sku expiring_date labelling_date  sell_date  \
# 0        0.34           0.010050    2021-10-03     2021-10-01 2021-10-02
# 1        0.32           0.005025    2021-10-02     2021-10-01        NaT
# 2        0.38           0.010050    2021-10-03     2021-10-01 2021-10-03
# 3        0.34           0.010050    2021-10-03     2021-10-01 2021-10-02
# 4        0.37           0.010050    2021-10-03     2021-10-01 2021-10-03
#
#    sold   type  selling_square_ft district  new_pvp  discount  Margem_num
# 0   1.0  Large             4762.0    Évora     2.11       0.5        0.16
# 1   0.0  Large             4762.0    Évora     1.98       0.5        0.16
# 2   1.0  Large             4762.0    Évora     2.37       0.5        0.16
# 3   1.0  Large             4762.0    Évora     2.10       0.5        0.16
# 4   NaN  Large             4762.0    Évora     2.31       0.5        0.16

# %% [markdown]
# ### 2.1.8. Sold

# %%
db['sold']=db['sold'].astype(bool)

# %%
db.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150054 entries, 0 to 150053
# Data columns (total 19 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   idstore            150054 non-null  int64
#  1   sku                150054 non-null  int64
#  2   brand              150054 non-null  object
#  3   oldpvp             150032 non-null  float64
#  4   labelqty           150054 non-null  int64
#  5   weight (g)         150050 non-null  object
#  6   Payment_method     150054 non-null  object
#  7   Profit (€)         150054 non-null  float64
#  8   perc_expiring_sku  149929 non-null  float64
#  9   expiring_date      150054 non-null  datetime64[ns]
#  10  labelling_date     150054 non-null  datetime64[ns]
#  11  sell_date          80511 non-null   datetime64[ns]
#  12  sold               150054 non-null  bool
#  13  type               150054 non-null  object
#  14  selling_square_ft  139275 non-null  float64
#  15  district           150054 non-null  object
#  16  new_pvp            150026 non-null  float64
#  17  discount           150026 non-null  float64
#  18  Margem_num         150054 non-null  float64
# dtypes: bool(1), datetime64[ns](3), float64(7), int64(3), object(5)
# memory usage: 20.8+ MB

# %%
db['sold'].value_counts()
# Out:
# sold
# True     80567
# False    69487
# Name: count, dtype: int64

# %%
# Verificar se existem produtos com sell date e sold = 0
filtered_db_sellnulo = db[db['sell_date'] != "nan"]
filtered_db_sellnulo
# Out:
#         idstore  sku    brand  oldpvp  labelqty weight (g) Payment_method  \
# 0             1    1   marca1    4.22         1        260           Card
# 1             1    1   marca1    3.96         1        260
# 2             1    1   marca1    4.74         1        260           Cash
# 3             1    1   marca1    4.20         1        260           Card
# 4             1    1   marca1    4.62         1        260           Cash
# ...         ...  ...      ...     ...       ...        ...            ...
# 150049      193  318   marca2    2.49         1         97
# 150050      203  318   marca2    2.49         1         97           Cash
# 150051      203  318   marca2    2.49         1         97           Cash
# 150052      139  319  marca24    3.49         1        141           Cash
# 150053      139  319  marca24    3.49         1        141
#
#         Profit (€)  perc_expiring_sku expiring_date labelling_date  sell_date  \
# 0             0.34           0.010050    2021-10-03     2021-10-01 2021-10-02
# 1             0.32           0.005025    2021-10-02     2021-10-01        NaT
# 2             0.38           0.010050    2021-10-03     2021-10-01 2021-10-03
# 3             0.34           0.010050    2021-10-03     2021-10-01 2021-10-02
# 4             0.37           0.010050    2021-10-03     2021-10-01 2021-10-03
# ...            ...                ...           ...            ...        ...
# 150049        0.14           0.100629    2021-10-19     2021-10-03        NaT
# 150050        0.14           0.113208    2021-10-19     2021-10-01 2021-10-02
# 150051        0.14           0.113208    2021-10-19     2021-10-01 2021-10-02
# 150052        0.46           0.092437    2021-10-17     2021-10-06 2021-10-11
# 150053        0.46           0.092437    2021-10-17     2021-10-06        NaT
#
#          sold    type  selling_square_ft    district  new_pvp  discount  \
# 0        True   Large             4762.0       Évora     2.11       0.5
# 1       False   Large             4762.0       Évora     1.98       0.5
# 2        True   Large             4762.0       Évora     2.37       0.5
# 3        True   Large             4762.0       Évora     2.10       0.5
# 4        True   Large             4762.0       Évora     2.31       0.5
# ...       ...     ...                ...         ...      ...       ...
# 150049  False  Medium             5048.0       Viseu     1.24       0.5
# 150050   True  Medium             9370.0        Faro     1.24       0.5
# 150051   True  Medium             9370.0        Faro     1.24       0.5
# 150052   True   Small             1061.0  Portalegre     2.44       0.3
# 150053  False   Small             1061.0  Portalegre     2.44       0.3
#
#         Margem_num
# 0             0.16
# 1             0.16
# 2             0.16
# 3             0.16
# 4             0.16
# ...            ...
# 150049        0.11
# 150050        0.11
# 150051        0.11
# 150052        0.19
# 150053        0.19
#
# [150054 rows x 19 columns]

# %%
filtered_db_sellnulo['sold'].value_counts()
# Todos os produtos que têm sell date, têm o sold =True
# Out:
# sold
# True     80567
# False    69487
# Name: count, dtype: int64

# %%
filtered_db_sellvalue = db[db['sell_date'] == "nan"]
filtered_db_sellvalue
# Out:
# Empty DataFrame
# Columns: [idstore, sku, brand, oldpvp, labelqty, weight (g), Payment_method, Profit (€), perc_expiring_sku, expiring_date, labelling_date, sell_date, sold, type, selling_square_ft, district, new_pvp, discount, Margem_num]
# Index: []

# %%
db.head()
# Out:
#    idstore  sku   brand  oldpvp  labelqty weight (g) Payment_method  \
# 0        1    1  marca1    4.22         1        260           Card
# 1        1    1  marca1    3.96         1        260
# 2        1    1  marca1    4.74         1        260           Cash
# 3        1    1  marca1    4.20         1        260           Card
# 4        1    1  marca1    4.62         1        260           Cash
#
#    Profit (€)  perc_expiring_sku expiring_date labelling_date  sell_date  \
# 0        0.34           0.010050    2021-10-03     2021-10-01 2021-10-02
# 1        0.32           0.005025    2021-10-02     2021-10-01        NaT
# 2        0.38           0.010050    2021-10-03     2021-10-01 2021-10-03
# 3        0.34           0.010050    2021-10-03     2021-10-01 2021-10-02
# 4        0.37           0.010050    2021-10-03     2021-10-01 2021-10-03
#
#     sold   type  selling_square_ft district  new_pvp  discount  Margem_num
# 0   True  Large             4762.0    Évora     2.11       0.5        0.16
# 1  False  Large             4762.0    Évora     1.98       0.5        0.16
# 2   True  Large             4762.0    Évora     2.37       0.5        0.16
# 3   True  Large             4762.0    Évora     2.10       0.5        0.16
# 4   True  Large             4762.0    Évora     2.31       0.5        0.16

# %% [markdown]
# ### 2.1.9. Payment_method

# %%
db['Payment_method'] = db['Payment_method'].replace(r'^\s*$', 'not_sell', regex=True)

# %%
db['Payment_method'].value_counts()
# Out:
# Payment_method
# not_sell    69543
# Card        40398
# Cash        40113
# Name: count, dtype: int64

# %% [markdown]
# ### 2.1.10. District

# %%
db['district'].unique()
# Out:
# array(['Évora', 'Bragança', 'Lisboa', 'Porto', 'Coimbra', 'Guarda',
#        'Vila Real', 'Faro', 'Beja', 'Leiria', 'Viana do Castelo',
#        'Castelo Branco', 'Santarém', 'Setúbal', 'Portalegre', 'Aveiro',
#        'Braga', 'Viseu'], dtype=object)

# %% [markdown]
# ### 2.1.11. Weight (g)

# %%
# Convert 'weight (g)' to float64
db['weight (g)'] = pd.to_numeric(db['weight (g)'], errors='coerce').astype('float64')

# %% [markdown]
# ### 2.1.12. IdStore

# %%
db['idstore'] = db['idstore'].astype('object')

# %% [markdown]
# ### 2.1.13. Sku

# %%
db['sku'] = db['sku'].astype('object')

# %%
db.head()
# Out:
#   idstore sku   brand  oldpvp  labelqty  weight (g) Payment_method  \
# 0       1   1  marca1    4.22         1       260.0           Card
# 1       1   1  marca1    3.96         1       260.0       not_sell
# 2       1   1  marca1    4.74         1       260.0           Cash
# 3       1   1  marca1    4.20         1       260.0           Card
# 4       1   1  marca1    4.62         1       260.0           Cash
#
#    Profit (€)  perc_expiring_sku expiring_date labelling_date  sell_date  \
# 0        0.34           0.010050    2021-10-03     2021-10-01 2021-10-02
# 1        0.32           0.005025    2021-10-02     2021-10-01        NaT
# 2        0.38           0.010050    2021-10-03     2021-10-01 2021-10-03
# 3        0.34           0.010050    2021-10-03     2021-10-01 2021-10-02
# 4        0.37           0.010050    2021-10-03     2021-10-01 2021-10-03
#
#     sold   type  selling_square_ft district  new_pvp  discount  Margem_num
# 0   True  Large             4762.0    Évora     2.11       0.5        0.16
# 1  False  Large             4762.0    Évora     1.98       0.5        0.16
# 2   True  Large             4762.0    Évora     2.37       0.5        0.16
# 3   True  Large             4762.0    Évora     2.10       0.5        0.16
# 4   True  Large             4762.0    Évora     2.31       0.5        0.16

# %% [markdown]
# ## 2.2. Exploração Estatística

# %%
db_numeric = db.select_dtypes(include=np.number)
db_categoric = db.select_dtypes(include='object')
db_dates = db.select_dtypes(include='datetime64')

# %% [markdown]
# ### 2.2.1. Variáveis Numéricas

# %%
db_numeric.describe()
# Out:
#               oldpvp  labelqty     weight (g)     Profit (€)  \
# count  150032.000000  150054.0  149626.000000  150054.000000
# mean        1.583495       1.0     163.482369       0.175200
# std         2.936689       0.0      57.755830       0.268484
# min         0.590000       1.0       1.000000       0.030000
# 25%         1.190000       1.0     123.000000       0.120000
# 50%         1.590000       1.0     167.000000       0.150000
# 75%         1.890000       1.0     192.000000       0.220000
# max       999.000000       1.0     410.000000      99.900000
#
#        perc_expiring_sku  selling_square_ft        new_pvp       discount  \
# count      149929.000000      139275.000000  150026.000000  150026.000000
# mean            0.384977        5978.197487       1.100699       0.302269
# std             0.222661        5533.809602       1.491332       0.036940
# min             0.000000          10.000000       0.030000       0.010000
# 25%             0.200000        1218.000000       0.830000       0.300000
# 50%             0.333333        4982.000000       1.110000       0.300000
# 75%             0.666667        8671.000000       1.320000       0.300000
# max             1.000000       25258.000000     499.500000       0.990000
#
#           Margem_num
# count  150054.000000
# mean        0.158249
# std         0.033036
# min         0.100000
# 25%         0.130000
# 50%         0.170000
# 75%         0.190000
# max         0.200000

# %% [markdown]
# **ALTERAR**
# From the above table, we can get some conclusions. Some examples are:
# - `count`- The income variable has 2431 valid values. We have a problem of missing values in here.
# - `mean`- In average, my customers spent on my store 654 monetary units;
# - `std`- The standard deviation of Income is quite high. This indicates that the values are spread out over a wider range.
# - `min`- All the customers have bought in my store at least 3 times.
# - `50%`- Half of my customers spend till 402 monetary units on my store.
# - `max`- The maximum value for recommendation is 6. This is an incoherence - according to the business needs, the range is between 1 and 5.
#
# The `describe()` method provides the main descriptive statistics: count, mean, standard deviation, minimum value, 25 percentile, 50 percentile or median, 75 percentile and maximum value.
# <br>
# However, you can call directly other measures, such as the skewness or the kurtosis.

# %%
db_numeric.skew()
# Out:
# oldpvp               293.769518
# labelqty               0.000000
# weight (g)             0.524027
# Profit (€)           341.546171
# perc_expiring_sku      0.205440
# selling_square_ft      1.091003
# new_pvp              279.813269
# discount               3.291943
# Margem_num            -0.374411
# dtype: float64

# %% [markdown]
# *  possibilidade de grandes outliers em oldpvp, profit e new_pvp;
# *  discount também com alguma possibilidade (um pouco acima de 1) e selling talvez mas pouco

# %%
db_numeric.kurt()
# Out:
# oldpvp                94225.456797
# labelqty                  0.000000
# weight (g)                2.306941
# Profit (€)           126853.607828
# perc_expiring_sku        -0.423220
# selling_square_ft         0.693269
# new_pvp               88319.704828
# discount                 24.133569
# Margem_num               -1.260135
# dtype: float64

# %% [markdown]
# *   oldpvp, profit, new_pvp com kurt superior a 3, indicando uma distribuição bastante anormal, todas positivas e com a cauda para a direita

# %% [markdown]
# ### 2.2.2. Variáveis Categóricas

# %%
db_categoric.describe()
# Out:
#         idstore     sku   brand Payment_method    type district
# count    150054  150054  150054         150054  150054   150054
# unique      332     319      42              3       4       18
# top         217     227  marca2       not_sell  Medium   Lisboa
# freq       2443    8971  106163          69543   62590    14888

# %% [markdown]
# #### Payment_method

# %%
db['Payment_method'].value_counts()
# Out:
# Payment_method
# not_sell    69543
# Card        40398
# Cash        40113
# Name: count, dtype: int64

# %%
# Verificar se quando o Payment_method está vazio, se existe uma sell_date
empty_payment_with_sell_date = db[(db['Payment_method'].isnull()) & (db['sell_date'].notnull())]
empty_payment_with_sell_date
# Out:
# Empty DataFrame
# Columns: [idstore, sku, brand, oldpvp, labelqty, weight (g), Payment_method, Profit (€), perc_expiring_sku, expiring_date, labelling_date, sell_date, sold, type, selling_square_ft, district, new_pvp, discount, Margem_num]
# Index: []

# %% [markdown]
# #### Type

# %%
db['type'].value_counts()
# Out:
# type
# Medium    62590
# Small     60599
# Large     26219
# 0           646
# Name: count, dtype: int64

# %% [markdown]
# #### District

# %%
db['district'].value_counts()
# Out:
# district
# Lisboa              14888
# Porto               12018
# Coimbra             10694
# Braga               10050
# Guarda               9699
# Viana do Castelo     8943
# Aveiro               8650
# Viseu                8421
# Castelo Branco       7770
# Beja                 7664
# Bragança             7230
# Setúbal              7207
# Évora                6975
# Portalegre           6857
# Vila Real            6820
# Faro                 6432
# Santarém             5946
# Leiria               3790
# Name: count, dtype: int64

# %% [markdown]
# ## 2.3. Exploração Visual

# %% [markdown]
# ### 2.3.1 Variáveis Numéricas

# %%
db_numeric.columns
# Out:
# Index(['oldpvp', 'labelqty', 'weight (g)', 'Profit (€)', 'perc_expiring_sku',
#        'selling_square_ft', 'new_pvp', 'discount', 'Margem_num'],
#       dtype='object')

# %% [markdown]
# #### Correlação

# %%
db_numeric = db_numeric.drop(columns=['labelqty'])
db_numeric_corr = db_numeric.corr(method = 'spearman',numeric_only=True)
figure = plt.figure(figsize=(16,10))
sns.heatmap(db_numeric_corr, annot=True, fmt = '.1g',cmap='Blues')
# Out:
# <Axes: >

# %% [markdown]
# #### Distribuição das Variáveis Numéricas

# %%
#Box plot para as numéricas

#Selecicionar apenas as variáveis numéricas
numerical_cols = db_numeric.select_dtypes(include=np.number).columns
num_plots = len(numerical_cols)

# Definir número de colunas e calcular número de linhas
plots_per_row = 4
num_rows = int(np.ceil(num_plots / plots_per_row))

#Criar subplots
fig, axes = plt.subplots(num_rows, plots_per_row, figsize=(plots_per_row * 4, num_rows * 4))

axes = axes.flatten()

#Criar boxplots
for i, col in enumerate(numerical_cols):
    sns.boxplot(x=db[col], ax=axes[i], color='steelblue')
    axes[i].set_title(f'{col}', fontsize=12)
    axes[i].tick_params(axis='x', rotation=45)

# Remover eixos vazios (se houver)
for j in range(i + 1, len(axes)):
    fig.delaxes(axes[j])

#Adjustar layout
plt.tight_layout()
plt.show()

# %%
# Selecionar apenas as variáveis numéricas
numerical_cols = db_numeric.select_dtypes(include=np.number).columns
num_plots = len(numerical_cols)

# Definir número de colunas e calcular número de linhas
plots_per_row = 4
num_rows = int(np.ceil(num_plots / plots_per_row))

# Criar subplots
fig, axes = plt.subplots(num_rows, plots_per_row, figsize=(plots_per_row * 4, num_rows * 4))
axes = axes.flatten()

# Criar histogramas
for i, col in enumerate(numerical_cols):
    sns.histplot(data=db, x=col, bins=10, color='g', ax=axes[i])
    axes[i].set_title(f'{col}', fontsize=12)
    axes[i].tick_params(axis='x', rotation=45)

# Remover eixos vazios (se houver)
for j in range(i + 1, len(axes)):
    fig.delaxes(axes[j])

# Ajustar layout
plt.tight_layout()
plt.show()

# %% [markdown]
# Nota:
#
# Com base na análise dos boxplots e histogramas, observou-se a presença de outliers significativos nas variáveis oldpvp, Profit (€) e new_pvp. Esses valores extremos podem influenciar métricas estatísticas e distorcer interpretações, sendo que iremos tratá-los posteriormente.

# %% [markdown]
# #### Relação entre perc_expiring_sku e discount

# %%
sns.scatterplot(data = db, x = 'perc_expiring_sku', y= 'discount')
# Out:
# <Axes: xlabel='perc_expiring_sku', ylabel='discount'>

# %% [markdown]
# ### 2.3.2 Variáveis Categóricas

# %%
db_categoric.columns
# Out:
# Index(['idstore', 'sku', 'brand', 'Payment_method', 'type', 'district'], dtype='object')

# %%
sns.countplot(y = 'district', hue = 'sold', data = db, order=db['district'].value_counts().index)
# Out:
# <Axes: xlabel='count', ylabel='district'>

# %%
plt.figure(figsize=(10, 12))
sns.countplot(y = 'brand', hue = 'sold', data = db, order=db['brand'].value_counts().index)
plt.show()

# %%
sold_items = db[db['sold'] == 1]
top_brands = sold_items['brand'].value_counts().nlargest(10)
plt.figure(figsize=(10, 6))
plt.bar(top_brands.index, top_brands.values, color='skyblue')
plt.xlabel("Brand")
plt.ylabel("Number of Items Sold")
plt.title("Top 10 Best-Selling Brands")
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %%
sold_items = db[db['sold'] == 1]

top_artigos = (
    sold_items['sku']
    .value_counts(ascending=False)
    .head(20)
    .reset_index()
)
top_artigos.columns = ['sku', 'Quantidade']
top_artigos = top_artigos.sort_values('Quantidade', ascending=False)
top_artigos
# Out:
#     sku  Quantidade
# 0   227        6902
# 1   105        5158
# 2     8        3588
# 3   198        3482
# 4    99        3430
# 5   251        3383
# 6   293        3030
# 7   302        2859
# 8   200        2845
# 9   139        2789
# 10   65        2531
# 11  156        1867
# 12   61        1863
# 13  291        1845
# 14  104        1700
# 15  131        1341
# 16   46        1301
# 17   92        1268
# 18   54        1156
# 19  213        1092

# %%
plt.figure(figsize=(10, 5))
sns.barplot(x="sku", y="Quantidade", data=top_artigos, order=top_artigos['sku'])
plt.title("Quantidade de produtos vendidos por SKU")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# #### Selling_day

# %%
db['selling_day'] = db['sell_date'].dt.day
db.head()
# Out:
#   idstore sku   brand  oldpvp  labelqty  weight (g) Payment_method  \
# 0       1   1  marca1    4.22         1       260.0           Card
# 1       1   1  marca1    3.96         1       260.0       not_sell
# 2       1   1  marca1    4.74         1       260.0           Cash
# 3       1   1  marca1    4.20         1       260.0           Card
# 4       1   1  marca1    4.62         1       260.0           Cash
#
#    Profit (€)  perc_expiring_sku expiring_date labelling_date  sell_date  \
# 0        0.34           0.010050    2021-10-03     2021-10-01 2021-10-02
# 1        0.32           0.005025    2021-10-02     2021-10-01        NaT
# 2        0.38           0.010050    2021-10-03     2021-10-01 2021-10-03
# 3        0.34           0.010050    2021-10-03     2021-10-01 2021-10-02
# 4        0.37           0.010050    2021-10-03     2021-10-01 2021-10-03
#
#     sold   type  selling_square_ft district  new_pvp  discount  Margem_num  \
# 0   True  Large             4762.0    Évora     2.11       0.5        0.16
# 1  False  Large             4762.0    Évora     1.98       0.5        0.16
# 2   True  Large             4762.0    Évora     2.37       0.5        0.16
# 3   True  Large             4762.0    Évora     2.10       0.5        0.16
# 4   True  Large             4762.0    Évora     2.31       0.5        0.16
#
#    selling_day
# 0          2.0
# 1          NaN
# 2          3.0
# 3          2.0
# 4          3.0

# %%
sold_counts_by_day = db[db['sold'] == 1].groupby('selling_day')['sold'].count()
plt.figure(figsize=(10, 6))
plt.bar(sold_counts_by_day.index, sold_counts_by_day.values, color='skyblue')
plt.xlabel("Selling Day of the Month")
plt.ylabel("Number of Items Sold")
plt.title("Histogram of Items Sold per Selling Day")
plt.xticks(sold_counts_by_day.index)
plt.tight_layout()
plt.show()

# %% [markdown]
# #### Selling_day_of_week

# %%
db['selling_day_of_week'] = db['sell_date'].dt.day_name()
db.head()
# Out:
#   idstore sku   brand  oldpvp  labelqty  weight (g) Payment_method  \
# 0       1   1  marca1    4.22         1       260.0           Card
# 1       1   1  marca1    3.96         1       260.0       not_sell
# 2       1   1  marca1    4.74         1       260.0           Cash
# 3       1   1  marca1    4.20         1       260.0           Card
# 4       1   1  marca1    4.62         1       260.0           Cash
#
#    Profit (€)  perc_expiring_sku expiring_date  ...  sell_date   sold   type  \
# 0        0.34           0.010050    2021-10-03  ... 2021-10-02   True  Large
# 1        0.32           0.005025    2021-10-02  ...        NaT  False  Large
# 2        0.38           0.010050    2021-10-03  ... 2021-10-03   True  Large
# 3        0.34           0.010050    2021-10-03  ... 2021-10-02   True  Large
# 4        0.37           0.010050    2021-10-03  ... 2021-10-03   True  Large
#
#   selling_square_ft  district new_pvp  discount  Margem_num  selling_day  \
# 0            4762.0     Évora    2.11       0.5        0.16          2.0
# 1            4762.0     Évora    1.98       0.5        0.16          NaN
# 2            4762.0     Évora    2.37       0.5        0.16          3.0
# 3            4762.0     Évora    2.10       0.5        0.16          2.0
# 4            4762.0     Évora    2.31       0.5        0.16          3.0
#
#    selling_day_of_week
# 0             Saturday
# 1                  NaN
# 2               Sunday
# 3             Saturday
# 4               Sunday
#
# [5 rows x 21 columns]

# %%
dias_ordem = ['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday']
sold_counts_by_day_of_week = (
    db[db['sold'] == 1]
    .groupby('selling_day_of_week')['sold']
    .count()
    .reindex(dias_ordem)
)
plt.figure(figsize=(10, 6))
plt.bar(sold_counts_by_day_of_week.index, sold_counts_by_day_of_week.values, color='skyblue')
plt.xlabel("Dia da semana")
plt.ylabel("Quantidade de produtos vendidos ")
plt.title("Quantidade de produtos vendidos por dia da semana")
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %% [markdown]
# # 3. Data Cleaning

# %% [markdown]
# ## 3.1 Outliers

# %% [markdown]
# Com base na kurtosis, reparámos que deviamos prestar especial atenção a estes: oldpvp, profit, new_pvp, discount com kurt superior a 3, indicando uma distribuição bastante anormal, todas positivas e com a cauda para a direita

# %% [markdown]
# ### oldpvp

# %%
plt.figure(figsize=(8, 6))
sns.boxplot(x=db['oldpvp'])
plt.title('Boxplot of oldpvp')
plt.show()

# %% [markdown]
# #### Oldpvp > 400

# %%
filtered_db = db[db['oldpvp'] > 400]
filtered_db
# Out:
#       idstore  sku    brand  oldpvp  labelqty  weight (g) Payment_method  \
# 452        64    4   marca3   500.0         1       134.0           Card
# 50171     289  108  marca20   999.0         1       227.0       not_sell
#
#        Profit (€)  perc_expiring_sku expiring_date  ...  sell_date   sold  \
# 452          0.33           0.250000    2021-10-30  ... 2021-10-29   True
# 50171       99.90           0.101266    2021-10-10  ...        NaT  False
#
#          type selling_square_ft          district new_pvp  discount  \
# 452    Medium            7879.0          Santarém   250.0       0.5
# 50171   Small             342.0  Viana do Castelo   499.5       0.5
#
#        Margem_num  selling_day  selling_day_of_week
# 452          0.17         29.0               Friday
# 50171        0.20          NaN                  NaN
#
# [2 rows x 21 columns]

# %% [markdown]
# ##### Sku = 108

# %%
avg_oldpvp_sku108 = db[db['sku'] == 108]['oldpvp'].mean()
print(f"Average 'oldpvp' for SKU 108: {avg_oldpvp_sku108}")
# Out:
# Average 'oldpvp' for SKU 108: 999.0

# %%
display(db[db['sku'] == 108])
# Out:
#       idstore  sku    brand  oldpvp  labelqty  weight (g) Payment_method  \
# 50171     289  108  marca20   999.0         1       227.0       not_sell
#
#        Profit (€)  perc_expiring_sku expiring_date  ... sell_date   sold  \
# 50171        99.9           0.101266    2021-10-10  ...       NaT  False
#
#         type selling_square_ft          district new_pvp  discount  \
# 50171  Small             342.0  Viana do Castelo   499.5       0.5
#
#        Margem_num  selling_day  selling_day_of_week
# 50171         0.2          NaN                  NaN
#
# [1 rows x 21 columns]

# %% [markdown]
# Uma vez que só existe um valor com deste produto (SKU), vamos eliminar esta linha, pois distorce a distribuição dos valores e aparenta ser um erro - etiquetas cor-de-rosa são geralmente aplicadas a produtos perecíveis e não parece que um produto deste género (preço) possa ter um valor tão elevado

# %%
db = db[db['sku'] != 108]

# %% [markdown]
# ##### sku=4

# %%
avg_oldpvp_sku4 = db[db['sku'] == 4]['oldpvp'].mean()
print(f"Average 'oldpvp' for SKU 4: {avg_oldpvp_sku4}")
# Out:
# Average 'oldpvp' for SKU 4: 3.975131578947368

# %%
average_oldpvp_by_brand = db[db['sku'] == 4].groupby('brand')['oldpvp'].mean()
average_oldpvp_by_brand
# Out:
# brand
# marca3    3.975132
# Name: oldpvp, dtype: float64

# %%
display(db[db['sku'] == 4])
# Out:
#     idstore sku   brand  oldpvp  labelqty  weight (g) Payment_method  \
# 121      13   4  marca3    2.79         1       134.0           Card
# 122      13   4  marca3    2.79         1       134.0           Cash
# 123      13   4  marca3    2.79         1       134.0           Cash
# 124      13   4  marca3    2.79         1       134.0           Cash
# 125      13   4  marca3    2.79         1       134.0           Card
# ..      ...  ..     ...     ...       ...         ...            ...
# 572      87   4  marca3    2.79         1       134.0           Cash
# 573      87   4  marca3    2.79         1       134.0       not_sell
# 574      87   4  marca3    2.79         1       134.0       not_sell
# 575      88   4  marca3    2.79         1       134.0           Cash
# 576      88   4  marca3    2.79         1       134.0           Card
#
#      Profit (€)  perc_expiring_sku expiring_date  ...  sell_date   sold  \
# 121        0.33               0.25    2021-10-16  ... 2021-10-16   True
# 122        0.33               0.25    2021-10-16  ... 2021-10-16   True
# 123        0.33               0.25    2021-10-16  ... 2021-10-16   True
# 124        0.33               0.25    2021-10-16  ... 2021-10-16   True
# 125        0.33               0.25    2021-10-16  ... 2021-10-16   True
# ..          ...                ...           ...  ...        ...    ...
# 572        0.33               0.25    2021-10-07  ... 2021-10-07   True
# 573        0.33               0.25    2021-10-07  ...        NaT  False
# 574        0.33               0.25    2021-10-07  ...        NaT  False
# 575        0.33               0.50    2021-10-05  ... 2021-10-04   True
# 576        0.33               0.50    2021-10-12  ... 2021-10-12   True
#
#        type selling_square_ft  district new_pvp  discount  Margem_num  \
# 121   Large           11925.0      Faro    1.95       0.3        0.17
# 122   Large           11925.0      Faro    1.95       0.3        0.17
# 123   Large           11925.0      Faro    1.95       0.3        0.17
# 124   Large           11925.0      Faro    1.95       0.3        0.17
# 125   Large           11925.0      Faro    1.95       0.3        0.17
# ..      ...               ...       ...     ...       ...         ...
# 572  Medium            8009.0   Setúbal    1.95       0.3        0.17
# 573  Medium            8009.0   Setúbal    1.95       0.3        0.17
# 574  Medium            8009.0   Setúbal    1.95       0.3        0.17
# 575  Medium            4854.0    Lisboa    1.95       0.3        0.17
# 576  Medium            4854.0    Lisboa    1.95       0.3        0.17
#
#      selling_day  selling_day_of_week
# 121         16.0             Saturday
# 122         16.0             Saturday
# 123         16.0             Saturday
# 124         16.0             Saturday
# 125         16.0             Saturday
# ..           ...                  ...
# 572          7.0             Thursday
# 573          NaN                  NaN
# 574          NaN                  NaN
# 575          4.0               Monday
# 576         12.0              Tuesday
#
# [456 rows x 21 columns]

# %%
sku4_data = db[db['sku'] == 4]
oldpvp_value_counts = sku4_data['oldpvp'].value_counts()
oldpvp_value_counts
# Out:
# oldpvp
# 2.79      454
# 500.00      1
# 46.00       1
# Name: count, dtype: int64

# %%
# Calcular a moda de 'oldpvp' e 'new_pvp' para produtos com sku = 4
mode_oldpvp_sku4 = db[db['sku'] == 4]['oldpvp'].mode()[0]
# Guardar a condição antes de alterar
cond = (db['sku'] == 4) & (db['oldpvp'].isin([500, 46]))
# Substituir os valores
db.loc[cond, 'oldpvp'] = mode_oldpvp_sku4

# %%
oldpvp_value_counts = db[db['sku'] == 4]['oldpvp'].value_counts()
oldpvp_value_counts
# Out:
# oldpvp
# 2.79    456
# Name: count, dtype: int64

# %%
plt.figure(figsize=(8, 6))
sns.boxplot(x=db['oldpvp'])
plt.title('Boxplot of oldpvp')
plt.show()

# %% [markdown]
# #### Oldpvp > 12.5

# %%
filtered_db2 = db[db['oldpvp'] > 12.5]
filtered_db2
# Out:
#       idstore  sku    brand  oldpvp  labelqty  weight (g) Payment_method  \
# 11030      14   33  marca14   17.99         1       266.0           Cash
# 11031      14   33  marca14   17.99         1       266.0       not_sell
# 94319       7  201   marca5   14.99         1       166.0       not_sell
# 94320       7  201   marca5   14.99         1       166.0           Cash
# 94321       7  201   marca5   14.99         1       166.0           Cash
# 94322       7  201   marca5   14.99         1       166.0       not_sell
# 94323       7  201   marca5   14.99         1       166.0       not_sell
# 94324       7  201   marca5   14.99         1       166.0       not_sell
# 94325       7  201   marca5   14.99         1       166.0       not_sell
# 94326       7  201   marca5   14.99         1       166.0       not_sell
# 94327       7  201   marca5   14.99         1       166.0       not_sell
# 94328       7  201   marca5   14.99         1       166.0       not_sell
# 94329       7  201   marca5   14.99         1       166.0       not_sell
#
#        Profit (€)  perc_expiring_sku expiring_date  ...  sell_date   sold  \
# 11030        1.44           0.050505    2021-10-27  ... 2021-10-23   True
# 11031        1.44           0.050505    2021-10-27  ...        NaT  False
# 94319        0.97           0.030641    2021-10-28  ...        NaT  False
# 94320        0.97           0.030641    2021-10-28  ... 2021-10-19   True
# 94321        0.97           0.030641    2021-10-28  ... 2021-10-19   True
# 94322        0.97           0.030641    2021-10-28  ...        NaT  False
# 94323        0.97           0.030641    2021-10-28  ...        NaT  False
# 94324        0.97           0.030641    2021-10-28  ...        NaT  False
# 94325        0.97           0.030641    2021-10-28  ...        NaT  False
# 94326        0.97           0.030641    2021-10-28  ...        NaT  False
# 94327        0.97           0.030641    2021-10-28  ...        NaT  False
# 94328        0.97           0.030641    2021-10-28  ...        NaT  False
# 94329        0.97           0.030641    2021-10-28  ...        NaT  False
#
#         type selling_square_ft  district new_pvp  discount  Margem_num  \
# 11030  Large           21275.0      Beja    8.99       0.5        0.16
# 11031  Large           21275.0      Beja    8.99       0.5        0.16
# 94319  Large           13618.0    Guarda    7.49       0.5        0.13
# 94320  Large           13618.0    Guarda    7.49       0.5        0.13
# 94321  Large           13618.0    Guarda    7.49       0.5        0.13
# 94322  Large           13618.0    Guarda    7.49       0.5        0.13
# 94323  Large           13618.0    Guarda    7.49       0.5        0.13
# 94324  Large           13618.0    Guarda    7.49       0.5        0.13
# 94325  Large           13618.0    Guarda    7.49       0.5        0.13
# 94326  Large           13618.0    Guarda    7.49       0.5        0.13
# 94327  Large           13618.0    Guarda    7.49       0.5        0.13
# 94328  Large           13618.0    Guarda    7.49       0.5        0.13
# 94329  Large           13618.0    Guarda    7.49       0.5        0.13
#
#        selling_day  selling_day_of_week
# 11030         23.0             Saturday
# 11031          NaN                  NaN
# 94319          NaN                  NaN
# 94320         19.0              Tuesday
# 94321         19.0              Tuesday
# 94322          NaN                  NaN
# 94323          NaN                  NaN
# 94324          NaN                  NaN
# 94325          NaN                  NaN
# 94326          NaN                  NaN
# 94327          NaN                  NaN
# 94328          NaN                  NaN
# 94329          NaN                  NaN
#
# [13 rows x 21 columns]

# %% [markdown]
# ##### sku=33

# %%
sku33_data = db[db['sku'] == 33]
oldpvp_value_counts_sku33 = sku33_data['oldpvp'].value_counts()
oldpvp_value_counts_sku33
# Out:
# oldpvp
# 17.99    2
# Name: count, dtype: int64

# %% [markdown]
# ##### sku=201

# %%
sku201_data = db[db['sku'] == 201]
oldpvp_value_counts_sku201 = sku201_data['oldpvp'].value_counts()
oldpvp_value_counts_sku201
# Out:
# oldpvp
# 14.99    11
# Name: count, dtype: int64

# %% [markdown]
# #### Análise mais profunda

# %%
oldpvp_counts = db.groupby(['sku','brand'])['oldpvp'].value_counts()
skus_with_multiple_oldpvps = oldpvp_counts[oldpvp_counts > 1]
skus_with_multiple_oldpvps
# Out:
# sku  brand    oldpvp
# 1    marca1   4.62        3
# 2    marca2   3.19      101
# 3    marca2   2.65        5
# 4    marca3   2.79      456
# 5    marca4   2.79       37
#                        ...
# 315  marca2   2.99        4
# 316  marca2   0.69        7
# 317  marca22  0.99       16
# 318  marca2   2.49       73
# 319  marca24  3.49        2
# Name: count, Length: 368, dtype: int64

# %%
filtered_df4 = db[(db['sku'] == 1) & (db['brand'] == 'marca1')]
filtered_df4
# Out:
#    idstore sku   brand  oldpvp  labelqty  weight (g) Payment_method  \
# 0        1   1  marca1    4.22         1       260.0           Card
# 1        1   1  marca1    3.96         1       260.0       not_sell
# 2        1   1  marca1    4.74         1       260.0           Cash
# 3        1   1  marca1    4.20         1       260.0           Card
# 4        1   1  marca1    4.62         1       260.0           Cash
# 5        1   1  marca1    4.62         1       260.0           Cash
# 6        1   1  marca1    3.42         1       260.0           Cash
# 7        1   1  marca1    3.62         1       260.0           Card
# 8        1   1  marca1    4.62         1       260.0       not_sell
# 9        1   1  marca1    4.38         1       260.0           Card
# 10       1   1  marca1    5.23         1       260.0           Card
# 11       1   1  marca1    5.89         1       260.0           Cash
# 12       1   1  marca1    3.78         1       260.0           Cash
# 13       1   1  marca1    4.76         1       260.0       not_sell
#
#     Profit (€)  perc_expiring_sku expiring_date  ...  sell_date   sold   type  \
# 0         0.34           0.010050    2021-10-03  ... 2021-10-02   True  Large
# 1         0.32           0.005025    2021-10-02  ...        NaT  False  Large
# 2         0.38           0.010050    2021-10-03  ... 2021-10-03   True  Large
# 3         0.34           0.010050    2021-10-03  ... 2021-10-02   True  Large
# 4         0.37           0.010050    2021-10-03  ... 2021-10-03   True  Large
# 5         0.37           0.010050    2021-10-03  ... 2021-10-03   True  Large
# 6         0.27           0.005025    2021-10-02  ... 2021-10-02   True  Large
# 7         0.29           0.005025    2021-10-02  ... 2021-10-02   True  Large
# 8         0.37           0.005025    2021-10-02  ...        NaT  False  Large
# 9         0.35           0.010050    2021-10-03  ... 2021-10-02   True  Large
# 10        0.42           0.010050    2021-10-03  ... 2021-10-03   True  Large
# 11        0.47           0.010050    2021-10-03  ... 2021-10-02   True  Large
# 12        0.30           0.010050    2021-10-03  ... 2021-10-02   True  Large
# 13        0.38           0.010050    2021-10-03  ...        NaT  False  Large
#
#    selling_square_ft  district new_pvp  discount  Margem_num  selling_day  \
# 0             4762.0     Évora    2.11       0.5        0.16          2.0
# 1             4762.0     Évora    1.98       0.5        0.16          NaN
# 2             4762.0     Évora    2.37       0.5        0.16          3.0
# 3             4762.0     Évora    2.10       0.5        0.16          2.0
# 4             4762.0     Évora    2.31       0.5        0.16          3.0
# 5             4762.0     Évora    2.31       0.5        0.16          3.0
# 6             4762.0     Évora    1.71       0.5        0.16          2.0
# 7             4762.0     Évora    1.81       0.5        0.16          2.0
# 8             4762.0     Évora    2.31       0.5        0.16          NaN
# 9             4762.0     Évora    2.19       0.5        0.16          2.0
# 10            4762.0     Évora     NaN       NaN        0.16          3.0
# 11            4762.0     Évora    2.94       0.5        0.16          2.0
# 12            4762.0     Évora    1.89       0.5        0.16          2.0
# 13            4762.0     Évora    2.38       0.5        0.16          NaN
#
#     selling_day_of_week
# 0              Saturday
# 1                   NaN
# 2                Sunday
# 3              Saturday
# 4                Sunday
# 5                Sunday
# 6              Saturday
# 7              Saturday
# 8                   NaN
# 9              Saturday
# 10               Sunday
# 11             Saturday
# 12             Saturday
# 13                  NaN
#
# [14 rows x 21 columns]

# %%
precos_por_sku_brand = db.groupby(['sku', 'brand'])['oldpvp'].unique().reset_index()
precos_por_sku_brand.columns = ['SKU', 'Brand', 'Valores de Preço']
print(precos_por_sku_brand)
# Out:
#      SKU    Brand                                   Valores de Preço
# 0      1   marca1  [4.22, 3.96, 4.74, 4.2, 4.62, 3.42, 3.62, 4.38...
# 1      2   marca2                                        [3.19, nan]
# 2      3   marca2                                             [2.65]
# 3      4   marca3                                             [2.79]
# 4      5   marca4                                       [2.79, 2.99]
# ..   ...      ...                                                ...
# 313  315   marca2                                       [2.99, 3.09]
# 314  316   marca2                                       [0.69, 0.89]
# 315  317  marca22                                             [0.99]
# 316  318   marca2                                             [2.49]
# 317  319  marca24                                             [3.49]
#
# [318 rows x 3 columns]

# %%
precos_por_sku_brand['Amplitude de Preço'] = precos_por_sku_brand['Valores de Preço'].apply(lambda x: np.max(x) - np.min(x) if len(x) > 1 else 0)
precos_por_sku_brand = precos_por_sku_brand.sort_values('Amplitude de Preço', ascending=False)
precos_por_sku_brand
# Out:
#      SKU    Brand                                   Valores de Preço  \
# 120  122   marca2          [0.96, 0.98, 0.97, 0.99, 0.95, 1.0, 4.29]
# 0      1   marca1  [4.22, 3.96, 4.74, 4.2, 4.62, 3.42, 3.62, 4.38...
# 174  176  marca10  [1.12, 1.47, 1.22, 1.71, 1.36, 1.68, 1.05, 1.7...
# 91    92   marca2                                       [2.89, 1.69]
# 68    69   marca7                                        [1.99, 2.8]
# ..   ...      ...                                                ...
# 133  135   marca2                                        [2.99, nan]
# 289  291   marca2                            [1.29, 0.99, 1.44, nan]
# 291  293   marca2                                        [1.69, nan]
# 292  294  marca15                                        [1.99, nan]
# 300  302   marca2                                  [1.19, nan, 1.29]
#
#      Amplitude de Preço
# 120                3.34
# 0                  2.47
# 174                1.26
# 91                 1.20
# 68                 0.81
# ..                  ...
# 133                 NaN
# 289                 NaN
# 291                 NaN
# 292                 NaN
# 300                 NaN
#
# [318 rows x 4 columns]

# %% [markdown]
# ### newpvp

# %%
plt.figure(figsize=(8, 6))
sns.boxplot(x=db['new_pvp'])
plt.title('Boxplot of newpvp')
plt.show()

# %%
# Calcular a moda de 'oldpvp' e 'new_pvp' para produtos com sku = 4
mode_new_pvp_sku4 = db[db['sku'] == 4]['new_pvp'].mode()[0]

# Substituir os valores
db.loc[cond, 'new_pvp'] = mode_new_pvp_sku4

# %%
plt.figure(figsize=(8, 6))
sns.boxplot(x=db['new_pvp'])
plt.title('Boxplot of newpvp')
plt.show()

# %%
filtered_db_new_pvp_6 = db[db['new_pvp'] > 6]
filtered_db_new_pvp_6
# Out:
#       idstore  sku    brand  oldpvp  labelqty  weight (g) Payment_method  \
# 11030      14   33  marca14   17.99         1       266.0           Cash
# 11031      14   33  marca14   17.99         1       266.0       not_sell
# 94319       7  201   marca5   14.99         1       166.0       not_sell
# 94320       7  201   marca5   14.99         1       166.0           Cash
# 94321       7  201   marca5   14.99         1       166.0           Cash
# 94322       7  201   marca5   14.99         1       166.0       not_sell
# 94323       7  201   marca5   14.99         1       166.0       not_sell
# 94324       7  201   marca5   14.99         1       166.0       not_sell
# 94325       7  201   marca5   14.99         1       166.0       not_sell
# 94326       7  201   marca5   14.99         1       166.0       not_sell
# 94327       7  201   marca5   14.99         1       166.0       not_sell
# 94328       7  201   marca5   14.99         1       166.0       not_sell
# 94329       7  201   marca5   14.99         1       166.0       not_sell
#
#        Profit (€)  perc_expiring_sku expiring_date  ...  sell_date   sold  \
# 11030        1.44           0.050505    2021-10-27  ... 2021-10-23   True
# 11031        1.44           0.050505    2021-10-27  ...        NaT  False
# 94319        0.97           0.030641    2021-10-28  ...        NaT  False
# 94320        0.97           0.030641    2021-10-28  ... 2021-10-19   True
# 94321        0.97           0.030641    2021-10-28  ... 2021-10-19   True
# 94322        0.97           0.030641    2021-10-28  ...        NaT  False
# 94323        0.97           0.030641    2021-10-28  ...        NaT  False
# 94324        0.97           0.030641    2021-10-28  ...        NaT  False
# 94325        0.97           0.030641    2021-10-28  ...        NaT  False
# 94326        0.97           0.030641    2021-10-28  ...        NaT  False
# 94327        0.97           0.030641    2021-10-28  ...        NaT  False
# 94328        0.97           0.030641    2021-10-28  ...        NaT  False
# 94329        0.97           0.030641    2021-10-28  ...        NaT  False
#
#         type selling_square_ft  district new_pvp  discount  Margem_num  \
# 11030  Large           21275.0      Beja    8.99       0.5        0.16
# 11031  Large           21275.0      Beja    8.99       0.5        0.16
# 94319  Large           13618.0    Guarda    7.49       0.5        0.13
# 94320  Large           13618.0    Guarda    7.49       0.5        0.13
# 94321  Large           13618.0    Guarda    7.49       0.5        0.13
# 94322  Large           13618.0    Guarda    7.49       0.5        0.13
# 94323  Large           13618.0    Guarda    7.49       0.5        0.13
# 94324  Large           13618.0    Guarda    7.49       0.5        0.13
# 94325  Large           13618.0    Guarda    7.49       0.5        0.13
# 94326  Large           13618.0    Guarda    7.49       0.5        0.13
# 94327  Large           13618.0    Guarda    7.49       0.5        0.13
# 94328  Large           13618.0    Guarda    7.49       0.5        0.13
# 94329  Large           13618.0    Guarda    7.49       0.5        0.13
#
#        selling_day  selling_day_of_week
# 11030         23.0             Saturday
# 11031          NaN                  NaN
# 94319          NaN                  NaN
# 94320         19.0              Tuesday
# 94321         19.0              Tuesday
# 94322          NaN                  NaN
# 94323          NaN                  NaN
# 94324          NaN                  NaN
# 94325          NaN                  NaN
# 94326          NaN                  NaN
# 94327          NaN                  NaN
# 94328          NaN                  NaN
# 94329          NaN                  NaN
#
# [13 rows x 21 columns]

# %% [markdown]
# ### profit

# %%
# prompt: faz-me um boxplot de profit

plt.figure(figsize=(8, 6))
sns.boxplot(x=db['Profit (€)'])
plt.title('Boxplot of Profit (€)')
plt.show()

# %%
profit_greater_than_08 = db[db['Profit (€)'] > 0.8]
profit_greater_than_08
# Out:
#       idstore  sku    brand  oldpvp  labelqty  weight (g) Payment_method  \
# 11030      14   33  marca14   17.99         1       266.0           Cash
# 11031      14   33  marca14   17.99         1       266.0       not_sell
# 94319       7  201   marca5   14.99         1       166.0       not_sell
# 94320       7  201   marca5   14.99         1       166.0           Cash
# 94321       7  201   marca5   14.99         1       166.0           Cash
# 94322       7  201   marca5   14.99         1       166.0       not_sell
# 94323       7  201   marca5   14.99         1       166.0       not_sell
# 94324       7  201   marca5   14.99         1       166.0       not_sell
# 94325       7  201   marca5   14.99         1       166.0       not_sell
# 94326       7  201   marca5   14.99         1       166.0       not_sell
# 94327       7  201   marca5   14.99         1       166.0       not_sell
# 94328       7  201   marca5   14.99         1       166.0       not_sell
# 94329       7  201   marca5   14.99         1       166.0       not_sell
#
#        Profit (€)  perc_expiring_sku expiring_date  ...  sell_date   sold  \
# 11030        1.44           0.050505    2021-10-27  ... 2021-10-23   True
# 11031        1.44           0.050505    2021-10-27  ...        NaT  False
# 94319        0.97           0.030641    2021-10-28  ...        NaT  False
# 94320        0.97           0.030641    2021-10-28  ... 2021-10-19   True
# 94321        0.97           0.030641    2021-10-28  ... 2021-10-19   True
# 94322        0.97           0.030641    2021-10-28  ...        NaT  False
# 94323        0.97           0.030641    2021-10-28  ...        NaT  False
# 94324        0.97           0.030641    2021-10-28  ...        NaT  False
# 94325        0.97           0.030641    2021-10-28  ...        NaT  False
# 94326        0.97           0.030641    2021-10-28  ...        NaT  False
# 94327        0.97           0.030641    2021-10-28  ...        NaT  False
# 94328        0.97           0.030641    2021-10-28  ...        NaT  False
# 94329        0.97           0.030641    2021-10-28  ...        NaT  False
#
#         type selling_square_ft  district new_pvp  discount  Margem_num  \
# 11030  Large           21275.0      Beja    8.99       0.5        0.16
# 11031  Large           21275.0      Beja    8.99       0.5        0.16
# 94319  Large           13618.0    Guarda    7.49       0.5        0.13
# 94320  Large           13618.0    Guarda    7.49       0.5        0.13
# 94321  Large           13618.0    Guarda    7.49       0.5        0.13
# 94322  Large           13618.0    Guarda    7.49       0.5        0.13
# 94323  Large           13618.0    Guarda    7.49       0.5        0.13
# 94324  Large           13618.0    Guarda    7.49       0.5        0.13
# 94325  Large           13618.0    Guarda    7.49       0.5        0.13
# 94326  Large           13618.0    Guarda    7.49       0.5        0.13
# 94327  Large           13618.0    Guarda    7.49       0.5        0.13
# 94328  Large           13618.0    Guarda    7.49       0.5        0.13
# 94329  Large           13618.0    Guarda    7.49       0.5        0.13
#
#        selling_day  selling_day_of_week
# 11030         23.0             Saturday
# 11031          NaN                  NaN
# 94319          NaN                  NaN
# 94320         19.0              Tuesday
# 94321         19.0              Tuesday
# 94322          NaN                  NaN
# 94323          NaN                  NaN
# 94324          NaN                  NaN
# 94325          NaN                  NaN
# 94326          NaN                  NaN
# 94327          NaN                  NaN
# 94328          NaN                  NaN
# 94329          NaN                  NaN
#
# [13 rows x 21 columns]

# %%
profit_por_sku_brand = db.groupby(['sku', 'brand'])['Profit (€)'].unique().reset_index()
profit_por_sku_brand.columns = ['SKU', 'Brand', 'Profit (€)']
print(profit_por_sku_brand)
# Out:
#      SKU    Brand                                         Profit (€)
# 0      1   marca1  [0.34, 0.32, 0.38, 0.37, 0.27, 0.29, 0.35, 0.4...
# 1      2   marca2                                 [0.24, 0.36, 0.38]
# 2      3   marca2                                             [0.24]
# 3      4   marca3                                       [0.33, 0.36]
# 4      5   marca4                                 [0.33, 0.36, 0.38]
# ..   ...      ...                                                ...
# 313  315   marca2                                             [0.18]
# 314  316   marca2                                       [0.04, 0.08]
# 315  317  marca22                                        [0.14, 0.1]
# 316  318   marca2                                       [0.14, 0.19]
# 317  319  marca24                                             [0.46]
#
# [318 rows x 3 columns]

# %%
profit_por_sku_brand['Amplitude de Preço'] = profit_por_sku_brand['Profit (€)'].apply(lambda x: np.max(x) - np.min(x) if len(x) > 1 else 0)
profit_por_sku_brand = profit_por_sku_brand.sort_values('Amplitude de Preço', ascending=False)
profit_por_sku_brand
# Out:
#      SKU    Brand                                         Profit (€)  \
# 120  122   marca2                                       [0.13, 0.57]
# 91    92   marca2                     [0.38, 0.41, 0.47, 0.49, 0.22]
# 77    78   marca2                                  [0.3, 0.42, 0.56]
# 112  114   marca2                                   [0.4, 0.56, 0.6]
# 0      1   marca1  [0.34, 0.32, 0.38, 0.37, 0.27, 0.29, 0.35, 0.4...
# ..   ...      ...                                                ...
# 311  313   marca2                                             [0.12]
# 313  315   marca2                                             [0.18]
# 312  314   marca2                                             [0.12]
# 2      3   marca2                                             [0.24]
# 317  319  marca24                                             [0.46]
#
#      Amplitude de Preço
# 120                0.44
# 91                 0.27
# 77                 0.26
# 112                0.20
# 0                  0.20
# ..                  ...
# 311                0.00
# 313                0.00
# 312                0.00
# 2                  0.00
# 317                0.00
#
# [318 rows x 4 columns]

# %% [markdown]
# ### discount

# %%
plt.figure(figsize=(8, 6))
sns.boxplot(x=db['discount'])
plt.title('Boxplot of Discount')
plt.show()

# %%
display(db[db['discount'] > 0.8])
# Out:
#     idstore sku   brand  oldpvp  labelqty  weight (g) Payment_method  \
# 550      83   4  marca3    2.79         1       134.0       not_sell
#
#      Profit (€)  perc_expiring_sku expiring_date  ... sell_date   sold  \
# 550        0.33                0.5    2021-10-09  ...       NaT  False
#
#        type selling_square_ft  district new_pvp  discount  Margem_num  \
# 550  Medium            4330.0     Braga    0.03      0.99        0.17
#
#      selling_day  selling_day_of_week
# 550          NaN                  NaN
#
# [1 rows x 21 columns]

# %%
products_sku4_marca3 = db[(db['sku'] == 4) & (db['brand'] == 'marca3')]
products_sku4_marca3
# Out:
#     idstore sku   brand  oldpvp  labelqty  weight (g) Payment_method  \
# 121      13   4  marca3    2.79         1       134.0           Card
# 122      13   4  marca3    2.79         1       134.0           Cash
# 123      13   4  marca3    2.79         1       134.0           Cash
# 124      13   4  marca3    2.79         1       134.0           Cash
# 125      13   4  marca3    2.79         1       134.0           Card
# ..      ...  ..     ...     ...       ...         ...            ...
# 572      87   4  marca3    2.79         1       134.0           Cash
# 573      87   4  marca3    2.79         1       134.0       not_sell
# 574      87   4  marca3    2.79         1       134.0       not_sell
# 575      88   4  marca3    2.79         1       134.0           Cash
# 576      88   4  marca3    2.79         1       134.0           Card
#
#      Profit (€)  perc_expiring_sku expiring_date  ...  sell_date   sold  \
# 121        0.33               0.25    2021-10-16  ... 2021-10-16   True
# 122        0.33               0.25    2021-10-16  ... 2021-10-16   True
# 123        0.33               0.25    2021-10-16  ... 2021-10-16   True
# 124        0.33               0.25    2021-10-16  ... 2021-10-16   True
# 125        0.33               0.25    2021-10-16  ... 2021-10-16   True
# ..          ...                ...           ...  ...        ...    ...
# 572        0.33               0.25    2021-10-07  ... 2021-10-07   True
# 573        0.33               0.25    2021-10-07  ...        NaT  False
# 574        0.33               0.25    2021-10-07  ...        NaT  False
# 575        0.33               0.50    2021-10-05  ... 2021-10-04   True
# 576        0.33               0.50    2021-10-12  ... 2021-10-12   True
#
#        type selling_square_ft  district new_pvp  discount  Margem_num  \
# 121   Large           11925.0      Faro    1.95       0.3        0.17
# 122   Large           11925.0      Faro    1.95       0.3        0.17
# 123   Large           11925.0      Faro    1.95       0.3        0.17
# 124   Large           11925.0      Faro    1.95       0.3        0.17
# 125   Large           11925.0      Faro    1.95       0.3        0.17
# ..      ...               ...       ...     ...       ...         ...
# 572  Medium            8009.0   Setúbal    1.95       0.3        0.17
# 573  Medium            8009.0   Setúbal    1.95       0.3        0.17
# 574  Medium            8009.0   Setúbal    1.95       0.3        0.17
# 575  Medium            4854.0    Lisboa    1.95       0.3        0.17
# 576  Medium            4854.0    Lisboa    1.95       0.3        0.17
#
#      selling_day  selling_day_of_week
# 121         16.0             Saturday
# 122         16.0             Saturday
# 123         16.0             Saturday
# 124         16.0             Saturday
# 125         16.0             Saturday
# ..           ...                  ...
# 572          7.0             Thursday
# 573          NaN                  NaN
# 574          NaN                  NaN
# 575          4.0               Monday
# 576         12.0              Tuesday
#
# [456 rows x 21 columns]

# %%
products_sku4_marca3['Profit (€)'].value_counts()
# Out:
# Profit (€)
# 0.33    429
# 0.36     27
# Name: count, dtype: int64

# %%
products_sku4_marca3['oldpvp'].value_counts()
# Out:
# oldpvp
# 2.79    456
# Name: count, dtype: int64

# %%
products_sku4_marca3['discount'].value_counts()
# Out:
# discount
# 0.30    427
# 0.25     27
# 0.50      1
# 0.99      1
# Name: count, dtype: int64

# %%
profitestranho = products_sku4_marca3[
    (products_sku4_marca3['discount'] == 0.50) |
    (products_sku4_marca3['discount'] == 0.99)
]
profitestranho
# Out:
#     idstore sku   brand  oldpvp  labelqty  weight (g) Payment_method  \
# 452      64   4  marca3    2.79         1       134.0           Card
# 550      83   4  marca3    2.79         1       134.0       not_sell
#
#      Profit (€)  perc_expiring_sku expiring_date  ...  sell_date   sold  \
# 452        0.33               0.25    2021-10-30  ... 2021-10-29   True
# 550        0.33               0.50    2021-10-09  ...        NaT  False
#
#        type selling_square_ft  district new_pvp  discount  Margem_num  \
# 452  Medium            7879.0  Santarém    1.95      0.50        0.17
# 550  Medium            4330.0     Braga    0.03      0.99        0.17
#
#      selling_day  selling_day_of_week
# 452         29.0               Friday
# 550          NaN                  NaN
#
# [2 rows x 21 columns]

# %%
db.loc[profitestranho.index, 'discount'] = 0.30
db.loc[profitestranho.index]
# Out:
#     idstore sku   brand  oldpvp  labelqty  weight (g) Payment_method  \
# 452      64   4  marca3    2.79         1       134.0           Card
# 550      83   4  marca3    2.79         1       134.0       not_sell
#
#      Profit (€)  perc_expiring_sku expiring_date  ...  sell_date   sold  \
# 452        0.33               0.25    2021-10-30  ... 2021-10-29   True
# 550        0.33               0.50    2021-10-09  ...        NaT  False
#
#        type selling_square_ft  district new_pvp  discount  Margem_num  \
# 452  Medium            7879.0  Santarém    1.95       0.3        0.17
# 550  Medium            4330.0     Braga    0.03       0.3        0.17
#
#      selling_day  selling_day_of_week
# 452         29.0               Friday
# 550          NaN                  NaN
#
# [2 rows x 21 columns]

# %%
# Calcular o novo 'new_pvp' após alterar o oldpvp
db.loc[profitestranho.index, 'new_pvp'] = (db.loc[profitestranho.index, 'oldpvp'] -
                                        (db.loc[profitestranho.index, 'oldpvp'] * db.loc[profitestranho.index, 'discount'])).round(2)
db.loc[profitestranho.index]
# Out:
#     idstore sku   brand  oldpvp  labelqty  weight (g) Payment_method  \
# 452      64   4  marca3    2.79         1       134.0           Card
# 550      83   4  marca3    2.79         1       134.0       not_sell
#
#      Profit (€)  perc_expiring_sku expiring_date  ...  sell_date   sold  \
# 452        0.33               0.25    2021-10-30  ... 2021-10-29   True
# 550        0.33               0.50    2021-10-09  ...        NaT  False
#
#        type selling_square_ft  district new_pvp  discount  Margem_num  \
# 452  Medium            7879.0  Santarém    1.95       0.3        0.17
# 550  Medium            4330.0     Braga    1.95       0.3        0.17
#
#      selling_day  selling_day_of_week
# 452         29.0               Friday
# 550          NaN                  NaN
#
# [2 rows x 21 columns]

# %% [markdown]
# Considerando o sku4 e marca3 verificámos que havia apenas duas possibilidades de profit. Desta forma, só seria possível duas opções de discount visto que o preço do sku4 e marca 3 é único. Concluímos então que o discount 0.5 e 0.99 não estavam correctos. O profit 0.33 tinha 429 obsesrvações e o 0.36 tinha 27 observações. Como o discount 0.25 tinha 29 observações e o discount 0.30 tinha apenas 427, considerámos que as duas observações com discount 0.5 e 0.99 deviam ser substituidos por 0.3 para prefazer os 429 .

# %% [markdown]
# ### weight

# %%
plt.figure(figsize=(8, 6))
sns.boxplot(x=db['weight (g)'])
plt.title('Boxplot of weight (g)')
plt.show()

# %%
filtered_db_weight = db[db['weight (g)'] > 350]
filtered_db_weight
# Out:
#        idstore  sku   brand  oldpvp  labelqty  weight (g) Payment_method  \
# 70212       14  247  marca7    1.99         1       410.0           Card
# 70213       14  247  marca7    1.99         1       410.0           Cash
# 70214       14  247  marca7    1.99         1       410.0           Card
# 70215       14  247  marca7    1.99         1       410.0       not_sell
# 70216       14  247  marca7    1.99         1       410.0       not_sell
# ...        ...  ...     ...     ...       ...         ...            ...
# 116411     284  247  marca7    1.99         1       410.0       not_sell
# 116412     284  247  marca7    1.99         1       410.0       not_sell
# 116413     284  247  marca7    1.99         1       410.0       not_sell
# 116414     284  247  marca7    1.99         1       410.0       not_sell
# 116415     284  247  marca7    1.99         1       410.0       not_sell
#
#         Profit (€)  perc_expiring_sku expiring_date  ...  sell_date   sold  \
# 70212         0.28                1.0    2021-10-08  ... 2021-10-07   True
# 70213         0.28                1.0    2021-10-18  ... 2021-10-17   True
# 70214         0.28                1.0    2021-10-18  ... 2021-10-18   True
# 70215         0.28                1.0    2021-10-18  ...        NaT  False
# 70216         0.28                1.0    2021-10-18  ...        NaT  False
# ...            ...                ...           ...  ...        ...    ...
# 116411        0.28                0.5    2021-10-28  ...        NaT  False
# 116412        0.28                0.5    2021-10-28  ...        NaT  False
# 116413        0.28                0.5    2021-10-28  ...        NaT  False
# 116414        0.28                0.5    2021-10-28  ...        NaT  False
# 116415        0.28                0.5    2021-10-28  ...        NaT  False
#
#          type selling_square_ft  district new_pvp  discount  Margem_num  \
# 70212   Large           21275.0      Beja    1.39       0.3         0.2
# 70213   Large           21275.0      Beja    1.39       0.3         0.2
# 70214   Large           21275.0      Beja    1.39       0.3         0.2
# 70215   Large           21275.0      Beja    1.39       0.3         0.2
# 70216   Large           21275.0      Beja    1.39       0.3         0.2
# ...       ...               ...       ...     ...       ...         ...
# 116411  Small              46.0    Aveiro    1.39       0.3         0.2
# 116412  Small              46.0    Aveiro    1.39       0.3         0.2
# 116413  Small              46.0    Aveiro    1.39       0.3         0.2
# 116414  Small              46.0    Aveiro    1.39       0.3         0.2
# 116415  Small              46.0    Aveiro    1.39       0.3         0.2
#
#         selling_day  selling_day_of_week
# 70212           7.0             Thursday
# 70213          17.0               Sunday
# 70214          18.0               Monday
# 70215           NaN                  NaN
# 70216           NaN                  NaN
# ...             ...                  ...
# 116411          NaN                  NaN
# 116412          NaN                  NaN
# 116413          NaN                  NaN
# 116414          NaN                  NaN
# 116415          NaN                  NaN
#
# [1491 rows x 21 columns]

# %%
filtered_db_weight['sku'].value_counts()
# Out:
# sku
# 247    1491
# Name: count, dtype: int64

# %%
db[db['sku'] == 247]['weight (g)'].value_counts()
# Out:
# weight (g)
# 410.0    1491
# Name: count, dtype: int64

# %% [markdown]
# Tendo em consideração que todos os produtos com sku=247 têm o mesmo peso, não aparenta ser um erro, pelo que não será tratado

# %%
filtered_db_weight2 = db[db['weight (g)'] < 20]
filtered_db_weight2
# Out:
#        idstore  sku    brand  oldpvp  labelqty  weight (g) Payment_method  \
# 57860      127  125   marca5    4.29         1         9.0           Cash
# 57861      127  125   marca5    4.29         1         9.0           Cash
# 57862      127  125   marca5    4.29         1         9.0           Card
# 57863      127  125   marca5    4.29         1         9.0       not_sell
# 57864      101  125   marca5    4.29         1         9.0           Cash
# ...        ...  ...      ...     ...       ...         ...            ...
# 149524     152  308  marca16    1.99         1        12.0           Card
# 149525     152  308  marca16    1.99         1        12.0           Cash
# 149526     185  308  marca16    1.99         1        12.0       not_sell
# 149527     185  308  marca16    1.99         1        12.0       not_sell
# 149528     185  308  marca16    1.99         1        12.0       not_sell
#
#         Profit (€)  perc_expiring_sku expiring_date  ...  sell_date   sold  \
# 57860         0.24           0.040404    2021-10-27  ... 2021-10-23   True
# 57861         0.24           0.040404    2021-10-27  ... 2021-10-27   True
# 57862         0.24           0.040404    2021-10-27  ... 2021-10-27   True
# 57863         0.24           0.040404    2021-10-27  ...        NaT  False
# 57864         0.24           0.080808    2021-10-26  ... 2021-10-19   True
# ...            ...                ...           ...  ...        ...    ...
# 149524        0.16           0.020661    2021-10-26  ... 2021-10-25   True
# 149525        0.16           0.020661    2021-10-26  ... 2021-10-25   True
# 149526        0.16           0.000000    2021-10-27  ...        NaT  False
# 149527        0.16           0.000000    2021-10-27  ...        NaT  False
# 149528        0.16           0.000000    2021-10-27  ...        NaT  False
#
#           type selling_square_ft  district new_pvp  discount  Margem_num  \
# 57860   Medium            6748.0      Faro    2.14       0.5        0.11
# 57861   Medium            6748.0      Faro    2.14       0.5        0.11
# 57862   Medium            6748.0      Faro    2.14       0.5        0.11
# 57863   Medium            6748.0      Faro    2.14       0.5        0.11
# 57864   Medium            5223.0  Santarém    2.14       0.5        0.11
# ...        ...               ...       ...     ...       ...         ...
# 149524   Small             686.0     Évora    0.99       0.5        0.16
# 149525   Small             686.0     Évora    0.99       0.5        0.16
# 149526   Small             136.0   Setúbal    0.99       0.5        0.16
# 149527   Small             136.0   Setúbal    0.99       0.5        0.16
# 149528   Small             136.0   Setúbal    0.99       0.5        0.16
#
#         selling_day  selling_day_of_week
# 57860          23.0             Saturday
# 57861          27.0            Wednesday
# 57862          27.0            Wednesday
# 57863           NaN                  NaN
# 57864          19.0              Tuesday
# ...             ...                  ...
# 149524         25.0               Monday
# 149525         25.0               Monday
# 149526          NaN                  NaN
# 149527          NaN                  NaN
# 149528          NaN                  NaN
#
# [62 rows x 21 columns]

# %%
filtered_db_weight2['sku'].value_counts()
# Out:
# sku
# 308    34
# 125    24
# 260     3
# 178     1
# Name: count, dtype: int64

# %%
filtrado308 = db[db['sku'] == 308]
filtrado308['weight (g)'].value_counts()
# Out:
# weight (g)
# 12.0    34
# Name: count, dtype: int64

# %%
filtrado125 = db[db['sku'] == 125]
filtrado125['weight (g)'].value_counts()
# Out:
# weight (g)
# 9.0    24
# Name: count, dtype: int64

# %%
filtrado260 = db[db['sku'] == 260]
filtrado260['weight (g)'].value_counts()
# Out:
# weight (g)
# 2.0    3
# Name: count, dtype: int64

# %% [markdown]
# ## 3.2 Missing Values

# %%
db.isna().sum()
# Out:
# idstore                    0
# sku                        0
# brand                      0
# oldpvp                    22
# labelqty                   0
# weight (g)               428
# Payment_method             0
# Profit (€)                 0
# perc_expiring_sku        125
# expiring_date              0
# labelling_date             0
# sell_date              69542
# sold                       0
# type                       0
# selling_square_ft      10779
# district                   0
# new_pvp                   28
# discount                  28
# Margem_num                 0
# selling_day            69542
# selling_day_of_week    69542
# dtype: int64

# %% [markdown]
# ### sold

# %%
soldnulo = db[db['sold'].isnull()]
soldnulo.head()
# Out:
# Empty DataFrame
# Columns: [idstore, sku, brand, oldpvp, labelqty, weight (g), Payment_method, Profit (€), perc_expiring_sku, expiring_date, labelling_date, sell_date, sold, type, selling_square_ft, district, new_pvp, discount, Margem_num, selling_day, selling_day_of_week]
# Index: []
#
# [0 rows x 21 columns]

# %%
db['sold'].value_counts()
# Out:
# sold
# True     80567
# False    69486
# Name: count, dtype: int64

# %%
db[(db['sell_date'].notna()) & (db['sold'] == False)]
# Out:
# Empty DataFrame
# Columns: [idstore, sku, brand, oldpvp, labelqty, weight (g), Payment_method, Profit (€), perc_expiring_sku, expiring_date, labelling_date, sell_date, sold, type, selling_square_ft, district, new_pvp, discount, Margem_num, selling_day, selling_day_of_week]
# Index: []
#
# [0 rows x 21 columns]

# %%
db[(db['sell_date'].isna()) & (db['sold'] == True)]
# Out:
#        idstore  sku    brand  oldpvp  labelqty  weight (g) Payment_method  \
# 124492      67  254   marca8    1.29         1       309.0       not_sell
# 124494      67  254   marca8    1.29         1       309.0       not_sell
# 124725      25  257   marca2    0.79         1       260.0       not_sell
# 124732      27  257   marca2    0.79         1       260.0       not_sell
# 124737      27  257   marca2    0.79         1       260.0       not_sell
# 124928      48  257   marca2    0.79         1       260.0       not_sell
# 124931      48  257   marca2    0.79         1       260.0       not_sell
# 124934      48  257   marca2    0.79         1       260.0       not_sell
# 125351      18  259  marca15    1.69         1       166.0       not_sell
# 125356      18  259  marca15    1.69         1       166.0       not_sell
# 125612     109  259  marca15    1.69         1       166.0       not_sell
# 125615     109  259  marca15    1.69         1       166.0       not_sell
# 126416      45  259  marca15    1.69         1       166.0       not_sell
# 126417      45  259  marca15    1.69         1       166.0       not_sell
# 126418      45  259  marca15    1.69         1       166.0       not_sell
# 126419      45  259  marca15    1.69         1       166.0       not_sell
# 126420      45  259  marca15    1.69         1       166.0       not_sell
# 126421      45  259  marca15    1.69         1       166.0       not_sell
# 126422      45  259  marca15    1.69         1       166.0       not_sell
# 126423      45  259  marca15    1.69         1       166.0       not_sell
# 127236     204  259  marca15    1.69         1       166.0       not_sell
# 127237     204  259  marca15    1.69         1       166.0       not_sell
# 127238     204  259  marca15    1.69         1       166.0       not_sell
# 127239      67  259  marca15    1.69         1       166.0       not_sell
# 127240      67  259  marca15    1.69         1       166.0       not_sell
# 127241      67  259  marca15    1.69         1       166.0       not_sell
# 127242      67  259  marca15    1.69         1       166.0       not_sell
# 127243      67  259  marca15    1.69         1       166.0       not_sell
# 127244      67  259  marca15    1.69         1       166.0       not_sell
# 127245      67  259  marca15    1.69         1       166.0       not_sell
# 128374     192  263  marca23    4.99         1       221.0       not_sell
# 128375     192  263  marca23    4.99         1       221.0       not_sell
# 128376      94  263  marca23    4.99         1       221.0       not_sell
# 128508      27  264   marca2    2.49         1        29.0       not_sell
# 128509      27  264   marca2    2.49         1        29.0       not_sell
# 128510      27  264   marca2    2.49         1        29.0       not_sell
# 128511      28  264   marca2    2.49         1        29.0       not_sell
# 129452      49  277  marca33    1.79         1       155.0       not_sell
# 129455       5  277  marca33    1.79         1       155.0       not_sell
# 129458      52  277  marca33    1.79         1       155.0       not_sell
# 129738     152  278  marca12    0.99         1        85.0       not_sell
# 130601      42  284  marca15    1.69         1       265.0       not_sell
# 148651     284  302   marca2    1.19         1       147.0       not_sell
# 148652     284  302   marca2    1.19         1       147.0       not_sell
# 149180      74  303   marca9    2.99         1       190.0       not_sell
# 149181      74  303   marca9    2.99         1       190.0       not_sell
# 149182      74  303   marca9    2.99         1       190.0       not_sell
# 149406     216  304  marca25    1.99         1       156.0       not_sell
# 149407     216  304  marca25    1.99         1       156.0       not_sell
# 149408     216  304  marca25    1.99         1       156.0       not_sell
# 149409     216  304  marca25    1.99         1       156.0       not_sell
# 149746      14  310   marca7    1.99         1       172.0       not_sell
# 149747      14  310   marca7    1.99         1       172.0       not_sell
# 149748      14  310   marca7    1.99         1       172.0       not_sell
# 149749      14  310   marca7    1.99         1       172.0       not_sell
# 149750      14  310   marca7    1.99         1       172.0       not_sell
#
#         Profit (€)  perc_expiring_sku expiring_date  ... sell_date  sold  \
# 124492        0.15           0.500000    2021-10-30  ...       NaT  True
# 124494        0.15           0.500000    2021-10-30  ...       NaT  True
# 124725        0.07           0.285714    2021-10-08  ...       NaT  True
# 124732        0.07           0.142857    2021-10-29  ...       NaT  True
# 124737        0.07           0.142857    2021-10-30  ...       NaT  True
# 124928        0.07           0.285714    2021-10-16  ...       NaT  True
# 124931        0.07           0.142857    2021-10-07  ...       NaT  True
# 124934        0.07           0.142857    2021-10-28  ...       NaT  True
# 125351        0.14           0.666667    2021-10-03  ...       NaT  True
# 125356        0.14           0.333333    2021-10-24  ...       NaT  True
# 125612        0.14           0.666667    2021-10-03  ...       NaT  True
# 125615        0.14           0.666667    2021-10-10  ...       NaT  True
# 126416        0.14           0.666667    2021-10-15  ...       NaT  True
# 126417        0.14           0.333333    2021-10-22  ...       NaT  True
# 126418        0.14           0.000000    2021-10-12  ...       NaT  True
# 126419        0.14           0.000000    2021-10-12  ...       NaT  True
# 126420        0.14           0.000000    2021-10-12  ...       NaT  True
# 126421        0.14           0.000000    2021-10-12  ...       NaT  True
# 126422        0.14           0.333333    2021-10-22  ...       NaT  True
# 126423        0.14           0.333333    2021-10-22  ...       NaT  True
# 127236        0.14           0.666667    2021-10-15  ...       NaT  True
# 127237        0.14           0.666667    2021-10-15  ...       NaT  True
# 127238        0.14           0.666667    2021-10-15  ...       NaT  True
# 127239        0.15           0.666667    2021-10-11  ...       NaT  True
# 127240        0.15           0.666667    2021-10-11  ...       NaT  True
# 127241        0.15           0.666667    2021-10-11  ...       NaT  True
# 127242        0.15           0.666667    2021-10-11  ...       NaT  True
# 127243        0.15           0.666667    2021-10-11  ...       NaT  True
# 127244        0.15           0.666667    2021-10-11  ...       NaT  True
# 127245        0.15           0.333333    2021-10-15  ...       NaT  True
# 128374        0.38           0.076923    2021-10-17  ...       NaT  True
# 128375        0.38           0.076923    2021-10-17  ...       NaT  True
# 128376        0.38           0.076923    2021-10-25  ...       NaT  True
# 128508        0.31           0.166667    2021-10-30  ...       NaT  True
# 128509        0.31           0.166667    2021-10-30  ...       NaT  True
# 128510        0.31           0.166667    2021-10-22  ...       NaT  True
# 128511        0.31           0.333333    2021-10-04  ...       NaT  True
# 129452        0.21           0.000000    2021-10-25  ...       NaT  True
# 129455        0.21           0.666667    2021-10-20  ...       NaT  True
# 129458        0.21           0.333333    2021-10-15  ...       NaT  True
# 129738        0.08           0.500000    2021-10-14  ...       NaT  True
# 130601        0.25           0.000000    2021-10-26  ...       NaT  True
# 148651        0.17           0.400000    2021-10-13  ...       NaT  True
# 148652        0.17           0.400000    2021-10-14  ...       NaT  True
# 149180        0.40           0.333333    2021-10-28  ...       NaT  True
# 149181        0.40           0.333333    2021-10-28  ...       NaT  True
# 149182        0.40           0.333333    2021-10-28  ...       NaT  True
# 149406        0.15           0.500000    2021-10-12  ...       NaT  True
# 149407        0.15           0.500000    2021-10-12  ...       NaT  True
# 149408        0.15           0.500000    2021-10-12  ...       NaT  True
# 149409        0.15           0.500000    2021-10-12  ...       NaT  True
# 149746        0.19           0.200000    2021-10-04  ...       NaT  True
# 149747        0.19           0.000000    2021-10-21  ...       NaT  True
# 149748        0.19           0.000000    2021-10-21  ...       NaT  True
# 149749        0.19           0.000000    2021-10-21  ...       NaT  True
# 149750        0.19           0.000000    2021-10-21  ...       NaT  True
#
#           type selling_square_ft          district new_pvp  discount  \
# 124492  Medium           10084.0    Castelo Branco    0.96      0.26
# 124494  Medium           10084.0    Castelo Branco    0.96      0.26
# 124725   Large           14855.0             Porto    0.55      0.30
# 124732   Large           21060.0    Castelo Branco    0.55      0.30
# 124737   Large           21060.0    Castelo Branco    0.55      0.30
# 124928  Medium            7997.0          Bragança    0.55      0.30
# 124931  Medium            7997.0          Bragança    0.55      0.30
# 124934  Medium            7997.0          Bragança    0.55      0.30
# 125351   Large           12373.0            Leiria    1.18      0.30
# 125356   Large           12373.0            Leiria    1.18      0.30
# 125612  Medium            6273.0  Viana do Castelo    1.18      0.30
# 125615  Medium            6273.0  Viana do Castelo    1.18      0.30
# 126416  Medium               NaN           Setúbal    1.18      0.30
# 126417  Medium               NaN           Setúbal    1.18      0.30
# 126418  Medium               NaN           Setúbal    1.18      0.30
# 126419  Medium               NaN           Setúbal    1.18      0.30
# 126420  Medium               NaN           Setúbal    1.18      0.30
# 126421  Medium               NaN           Setúbal    1.18      0.30
# 126422  Medium               NaN           Setúbal    1.18      0.30
# 126423  Medium               NaN           Setúbal    1.18      0.30
# 127236  Medium             524.0            Lisboa    1.18      0.30
# 127237  Medium             524.0            Lisboa    1.18      0.30
# 127238  Medium             524.0            Lisboa    1.18      0.30
# 127239  Medium           10084.0    Castelo Branco    1.26      0.25
# 127240  Medium           10084.0    Castelo Branco    1.26      0.25
# 127241  Medium           10084.0    Castelo Branco    1.26      0.25
# 127242  Medium           10084.0    Castelo Branco    1.26      0.25
# 127243  Medium           10084.0    Castelo Branco    1.26      0.25
# 127244  Medium           10084.0    Castelo Branco    1.26      0.25
# 127245  Medium           10084.0    Castelo Branco    1.26      0.25
# 128374   Small            1031.0            Guarda    3.49      0.30
# 128375   Small            1031.0            Guarda    3.49      0.30
# 128376  Medium            8045.0            Leiria    3.44      0.31
# 128508   Large           21060.0    Castelo Branco    1.74      0.30
# 128509   Large           21060.0    Castelo Branco    1.74      0.30
# 128510   Large           21060.0    Castelo Branco    1.74      0.30
# 128511   Large           15263.0             Porto    1.74      0.30
# 129452  Medium            1677.0        Portalegre    1.25      0.30
# 129455   Large           16179.0           Coimbra    1.25      0.30
# 129458  Medium            8883.0             Braga    1.25      0.30
# 129738   Small             686.0             Évora    0.49      0.51
# 130601  Medium           10790.0        Portalegre    1.26      0.25
# 148651   Small              46.0            Aveiro    0.83      0.30
# 148652   Small              46.0            Aveiro    0.83      0.30
# 149180  Medium            7016.0             Braga    2.09      0.30
# 149181  Medium            7016.0             Braga    2.09      0.30
# 149182  Medium            7016.0             Braga    2.09      0.30
# 149406   Small               NaN           Setúbal    1.39      0.30
# 149407   Small               NaN           Setúbal    1.39      0.30
# 149408   Small               NaN           Setúbal    1.39      0.30
# 149409   Small               NaN           Setúbal    1.39      0.30
# 149746   Large           21275.0              Beja    1.39      0.30
# 149747   Large           21275.0              Beja    1.39      0.30
# 149748   Large           21275.0              Beja    1.39      0.30
# 149749   Large           21275.0              Beja    1.39      0.30
# 149750   Large           21275.0              Beja    1.39      0.30
#
#         Margem_num  selling_day  selling_day_of_week
# 124492        0.16          NaN                  NaN
# 124494        0.16          NaN                  NaN
# 124725        0.13          NaN                  NaN
# 124732        0.13          NaN                  NaN
# 124737        0.13          NaN                  NaN
# 124928        0.13          NaN                  NaN
# 124931        0.13          NaN                  NaN
# 124934        0.13          NaN                  NaN
# 125351        0.12          NaN                  NaN
# 125356        0.12          NaN                  NaN
# 125612        0.12          NaN                  NaN
# 125615        0.12          NaN                  NaN
# 126416        0.12          NaN                  NaN
# 126417        0.12          NaN                  NaN
# 126418        0.12          NaN                  NaN
# 126419        0.12          NaN                  NaN
# 126420        0.12          NaN                  NaN
# 126421        0.12          NaN                  NaN
# 126422        0.12          NaN                  NaN
# 126423        0.12          NaN                  NaN
# 127236        0.12          NaN                  NaN
# 127237        0.12          NaN                  NaN
# 127238        0.12          NaN                  NaN
# 127239        0.12          NaN                  NaN
# 127240        0.12          NaN                  NaN
# 127241        0.12          NaN                  NaN
# 127242        0.12          NaN                  NaN
# 127243        0.12          NaN                  NaN
# 127244        0.12          NaN                  NaN
# 127245        0.12          NaN                  NaN
# 128374        0.11          NaN                  NaN
# 128375        0.11          NaN                  NaN
# 128376        0.11          NaN                  NaN
# 128508        0.18          NaN                  NaN
# 128509        0.18          NaN                  NaN
# 128510        0.18          NaN                  NaN
# 128511        0.18          NaN                  NaN
# 129452        0.17          NaN                  NaN
# 129455        0.17          NaN                  NaN
# 129458        0.17          NaN                  NaN
# 129738        0.17          NaN                  NaN
# 130601        0.20          NaN                  NaN
# 148651        0.20          NaN                  NaN
# 148652        0.20          NaN                  NaN
# 149180        0.19          NaN                  NaN
# 149181        0.19          NaN                  NaN
# 149182        0.19          NaN                  NaN
# 149406        0.11          NaN                  NaN
# 149407        0.11          NaN                  NaN
# 149408        0.11          NaN                  NaN
# 149409        0.11          NaN                  NaN
# 149746        0.14          NaN                  NaN
# 149747        0.14          NaN                  NaN
# 149748        0.14          NaN                  NaN
# 149749        0.14          NaN                  NaN
# 149750        0.14          NaN                  NaN
#
# [56 rows x 21 columns]

# %% [markdown]
# Existem produtos que não têm data de venda, mas que estão considerados como vendidos. Assim iremos alterar o valor do sold para False.

# %%
db.loc[db['sell_date'].isna() & (db['sold'] == True), 'sold'] = False

# %%
db['sold'].value_counts()
# Out:
# sold
# True     80511
# False    69542
# Name: count, dtype: int64

# %% [markdown]
# ### sell_date, selling_day e selling_day_of_week

# %%
db.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 150053 entries, 0 to 150053
# Data columns (total 21 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   idstore              150053 non-null  object
#  1   sku                  150053 non-null  object
#  2   brand                150053 non-null  object
#  3   oldpvp               150031 non-null  float64
#  4   labelqty             150053 non-null  int64
#  5   weight (g)           149625 non-null  float64
#  6   Payment_method       150053 non-null  object
#  7   Profit (€)           150053 non-null  float64
#  8   perc_expiring_sku    149928 non-null  float64
#  9   expiring_date        150053 non-null  datetime64[ns]
#  10  labelling_date       150053 non-null  datetime64[ns]
#  11  sell_date            80511 non-null   datetime64[ns]
#  12  sold                 150053 non-null  bool
#  13  type                 150053 non-null  object
#  14  selling_square_ft    139274 non-null  float64
#  15  district             150053 non-null  object
#  16  new_pvp              150025 non-null  float64
#  17  discount             150025 non-null  float64
#  18  Margem_num           150053 non-null  float64
#  19  selling_day          80511 non-null   float64
#  20  selling_day_of_week  80511 non-null   object
# dtypes: bool(1), datetime64[ns](3), float64(9), int64(1), object(7)
# memory usage: 28.2+ MB

# %%
db.isna().sum()
# Out:
# idstore                    0
# sku                        0
# brand                      0
# oldpvp                    22
# labelqty                   0
# weight (g)               428
# Payment_method             0
# Profit (€)                 0
# perc_expiring_sku        125
# expiring_date              0
# labelling_date             0
# sell_date              69542
# sold                       0
# type                       0
# selling_square_ft      10779
# district                   0
# new_pvp                   28
# discount                  28
# Margem_num                 0
# selling_day            69542
# selling_day_of_week    69542
# dtype: int64

# %% [markdown]
# Os valores nulos nas variaveis sell_date, selling_day e selling_day_of_week fazem sentido, pois os produtos ainda não foram vendidos e não temos essas datas.

# %% [markdown]
# ### perc_expiring_sku

# %%
percnulo = db[db['perc_expiring_sku'].isnull()]
percnulo
# Out:
#        idstore  sku    brand  oldpvp  labelqty  weight (g) Payment_method  \
# 132821      89   45  marca18    2.19         1       300.0           Card
# 132822      89   45  marca18    2.19         1       300.0           Cash
# 132825      89   45  marca18    2.19         1       300.0       not_sell
# 132826      89   45  marca18    2.19         1       300.0           Cash
# 132827      89   45  marca18    2.19         1       300.0       not_sell
# ...        ...  ...      ...     ...       ...         ...            ...
# 133051      92  176  marca10    1.26         1       193.0           Card
# 133052      92  176  marca10    1.47         1       193.0           Cash
# 133065      92  176  marca10    1.12         1       193.0           Cash
# 133066      92  176  marca10    0.84         1       193.0           Card
# 133067      92  176  marca10    0.94         1       193.0           Card
#
#         Profit (€)  perc_expiring_sku expiring_date  ...  sell_date   sold  \
# 132821        0.31                NaN    2021-10-27  ... 2021-10-26   True
# 132822        0.31                NaN    2021-10-27  ... 2021-10-26   True
# 132825        0.31                NaN    2021-10-27  ...        NaT  False
# 132826        0.31                NaN    2021-10-23  ... 2021-10-23   True
# 132827        0.31                NaN    2021-10-23  ...        NaT  False
# ...            ...                ...           ...  ...        ...    ...
# 133051        0.12                NaN    2021-10-25  ... 2021-10-25   True
# 133052        0.14                NaN    2021-10-29  ... 2021-10-29   True
# 133065        0.11                NaN    2021-10-29  ... 2021-10-29   True
# 133066        0.08                NaN    2021-10-29  ... 2021-10-29   True
# 133067        0.09                NaN    2021-10-29  ... 2021-10-29   True
#
#           type selling_square_ft  district new_pvp  discount  Margem_num  \
# 132821  Medium            5829.0    Lisboa    1.53      0.30        0.20
# 132822  Medium            5829.0    Lisboa    1.53      0.30        0.20
# 132825  Medium            5829.0    Lisboa    1.53      0.30        0.20
# 132826  Medium            5829.0    Lisboa    1.53      0.30        0.20
# 132827  Medium            5829.0    Lisboa    1.53      0.30        0.20
# ...        ...               ...       ...     ...       ...         ...
# 133051  Medium            7230.0      Beja    0.94      0.25        0.13
# 133052  Medium            7230.0      Beja    1.10      0.25        0.13
# 133065  Medium            7230.0      Beja    0.84      0.25        0.13
# 133066  Medium            7230.0      Beja    0.63      0.25        0.13
# 133067  Medium            7230.0      Beja    0.70      0.26        0.13
#
#         selling_day  selling_day_of_week
# 132821         26.0              Tuesday
# 132822         26.0              Tuesday
# 132825          NaN                  NaN
# 132826         23.0             Saturday
# 132827          NaN                  NaN
# ...             ...                  ...
# 133051         25.0               Monday
# 133052         29.0               Friday
# 133065         29.0               Friday
# 133066         29.0               Friday
# 133067         29.0               Friday
#
# [125 rows x 21 columns]

# %%
sns.boxplot(y = 'perc_expiring_sku', x = 'sold', data = db)
# Out:
# <Axes: xlabel='sold', ylabel='perc_expiring_sku'>

# %%
percnulo[['sku', 'brand']].value_counts()
# Out:
# sku  brand
# 176  marca10    73
# 149  marca12    47
# 45   marca18     5
# Name: count, dtype: int64

# %%
sku176marca10 = db[(db['sku'] == 176) & (db['brand'] == 'marca10')]
sku176marca10
# Out:
#        idstore  sku    brand  oldpvp  labelqty  weight (g) Payment_method  \
# 132955      91  176  marca10    1.12         1       193.0       not_sell
# 132956      91  176  marca10    1.47         1       193.0       not_sell
# 132957      91  176  marca10    1.47         1       193.0       not_sell
# 132958      91  176  marca10    1.22         1       193.0           Card
# 132959      91  176  marca10    1.22         1       193.0       not_sell
# ...        ...  ...      ...     ...       ...         ...            ...
# 133051      92  176  marca10    1.26         1       193.0           Card
# 133052      92  176  marca10    1.47         1       193.0           Cash
# 133065      92  176  marca10    1.12         1       193.0           Cash
# 133066      92  176  marca10    0.84         1       193.0           Card
# 133067      92  176  marca10    0.94         1       193.0           Card
#
#         Profit (€)  perc_expiring_sku expiring_date  ...  sell_date   sold  \
# 132955        0.11                NaN    2021-10-31  ...        NaT  False
# 132956        0.13                NaN    2021-10-27  ...        NaT  False
# 132957        0.13                NaN    2021-10-27  ...        NaT  False
# 132958        0.11                NaN    2021-10-27  ... 2021-10-27   True
# 132959        0.11                NaN    2021-10-27  ...        NaT  False
# ...            ...                ...           ...  ...        ...    ...
# 133051        0.12                NaN    2021-10-25  ... 2021-10-25   True
# 133052        0.14                NaN    2021-10-29  ... 2021-10-29   True
# 133065        0.11                NaN    2021-10-29  ... 2021-10-29   True
# 133066        0.08                NaN    2021-10-29  ... 2021-10-29   True
# 133067        0.09                NaN    2021-10-29  ... 2021-10-29   True
#
#           type selling_square_ft  district new_pvp  discount  Margem_num  \
# 132955  Medium            8952.0    Aveiro    0.84      0.25        0.13
# 132956  Medium            8952.0    Aveiro    1.02      0.31        0.13
# 132957  Medium            8952.0    Aveiro    1.02      0.31        0.13
# 132958  Medium            8952.0    Aveiro    0.85      0.30        0.13
# 132959  Medium            8952.0    Aveiro    0.85      0.30        0.13
# ...        ...               ...       ...     ...       ...         ...
# 133051  Medium            7230.0      Beja    0.94      0.25        0.13
# 133052  Medium            7230.0      Beja    1.10      0.25        0.13
# 133065  Medium            7230.0      Beja    0.84      0.25        0.13
# 133066  Medium            7230.0      Beja    0.63      0.25        0.13
# 133067  Medium            7230.0      Beja    0.70      0.26        0.13
#
#         selling_day  selling_day_of_week
# 132955          NaN                  NaN
# 132956          NaN                  NaN
# 132957          NaN                  NaN
# 132958         27.0            Wednesday
# 132959          NaN                  NaN
# ...             ...                  ...
# 133051         25.0               Monday
# 133052         29.0               Friday
# 133065         29.0               Friday
# 133066         29.0               Friday
# 133067         29.0               Friday
#
# [73 rows x 21 columns]

# %%
marca10 = db[ (db['brand'] == 'marca10')]
marca10.describe()
# Out:
#            oldpvp  labelqty  weight (g)  Profit (€)  perc_expiring_sku  \
# count  101.000000     101.0  101.000000  101.000000          28.000000
# mean     1.616337       1.0  208.801980    0.147921           0.267857
# min      0.840000       1.0  193.000000    0.080000           0.000000
# 25%      1.290000       1.0  193.000000    0.120000           0.000000
# 50%      1.500000       1.0  193.000000    0.140000           0.500000
# 75%      2.190000       1.0  250.000000    0.180000           0.500000
# max      2.190000       1.0  250.000000    0.220000           0.500000
# std      0.417020       0.0   25.642161    0.033891           0.253937
#
#                        expiring_date                 labelling_date  \
# count                            101                            101
# mean   2021-10-20 07:50:29.702970368  2021-10-19 23:17:13.663366400
# min              2021-10-03 00:00:00            2021-10-02 00:00:00
# 25%              2021-10-15 00:00:00            2021-10-14 00:00:00
# 50%              2021-10-24 00:00:00            2021-10-23 00:00:00
# 75%              2021-10-27 00:00:00            2021-10-27 00:00:00
# max              2021-10-31 00:00:00            2021-10-31 00:00:00
# std                              NaN                            NaN
#
#                            sell_date  selling_square_ft     new_pvp  \
# count                             67         101.000000  101.000000
# mean   2021-10-17 12:10:44.776119296        7560.059406    1.177723
# min              2021-10-02 00:00:00        5829.000000    0.630000
# 25%              2021-10-05 00:00:00        7230.000000    0.940000
# 50%              2021-10-19 00:00:00        7230.000000    1.090000
# 75%              2021-10-27 12:00:00        8952.000000    1.530000
# max              2021-10-31 00:00:00        8952.000000    1.860000
# std                              NaN        1191.331716    0.314073
#
#          discount  Margem_num  selling_day
# count  101.000000  101.000000    67.000000
# mean     0.270000    0.127228    17.507463
# min      0.150000    0.120000     2.000000
# 25%      0.250000    0.120000     5.000000
# 50%      0.260000    0.130000    19.000000
# 75%      0.300000    0.130000    27.500000
# max      0.310000    0.130000    31.000000
# std      0.036986    0.004499    10.518920

# %%
sku45marca18 = db[(db['sku'] == 45) & (db['brand'] == 'marca18')]
sku45marca18
# Out:
#        idstore sku    brand  oldpvp  labelqty  weight (g) Payment_method  \
# 132821      89  45  marca18    2.19         1       300.0           Card
# 132822      89  45  marca18    2.19         1       300.0           Cash
# 132825      89  45  marca18    2.19         1       300.0       not_sell
# 132826      89  45  marca18    2.19         1       300.0           Cash
# 132827      89  45  marca18    2.19         1       300.0       not_sell
#
#         Profit (€)  perc_expiring_sku expiring_date  ...  sell_date   sold  \
# 132821        0.31                NaN    2021-10-27  ... 2021-10-26   True
# 132822        0.31                NaN    2021-10-27  ... 2021-10-26   True
# 132825        0.31                NaN    2021-10-27  ...        NaT  False
# 132826        0.31                NaN    2021-10-23  ... 2021-10-23   True
# 132827        0.31                NaN    2021-10-23  ...        NaT  False
#
#           type selling_square_ft  district new_pvp  discount  Margem_num  \
# 132821  Medium            5829.0    Lisboa    1.53       0.3         0.2
# 132822  Medium            5829.0    Lisboa    1.53       0.3         0.2
# 132825  Medium            5829.0    Lisboa    1.53       0.3         0.2
# 132826  Medium            5829.0    Lisboa    1.53       0.3         0.2
# 132827  Medium            5829.0    Lisboa    1.53       0.3         0.2
#
#         selling_day  selling_day_of_week
# 132821         26.0              Tuesday
# 132822         26.0              Tuesday
# 132825          NaN                  NaN
# 132826         23.0             Saturday
# 132827          NaN                  NaN
#
# [5 rows x 21 columns]

# %%
marca18 = db[ (db['brand'] == 'marca18')]
marca18.describe()
# Out:
#           oldpvp  labelqty  weight (g)  Profit (€)  perc_expiring_sku  \
# count  86.000000      86.0   86.000000   86.000000          81.000000
# mean    2.671047       1.0  169.244186    0.297326           0.265138
# min     1.590000       1.0   45.000000    0.120000           0.000000
# 25%     2.190000       1.0  118.000000    0.230000           0.333333
# 50%     2.990000       1.0  148.000000    0.310000           0.333333
# 75%     2.990000       1.0  216.000000    0.390000           0.333333
# max     3.490000       1.0  303.000000    0.420000           0.333333
# std     0.621486       0.0   77.410128    0.098105           0.134041
#
#                        expiring_date                 labelling_date  \
# count                             86                             86
# mean   2021-10-08 22:36:16.744186112  2021-10-08 03:37:40.465116160
# min              2021-10-03 00:00:00            2021-10-02 00:00:00
# 25%              2021-10-03 00:00:00            2021-10-02 00:00:00
# 50%              2021-10-05 00:00:00            2021-10-04 00:00:00
# 75%              2021-10-15 00:00:00            2021-10-14 00:00:00
# max              2021-10-27 00:00:00            2021-10-26 00:00:00
# std                              NaN                            NaN
#
#                            sell_date  selling_square_ft    new_pvp   discount  \
# count                             46          86.000000  86.000000  86.000000
# mean   2021-10-09 21:23:28.695652096        6371.302326   1.867907   0.299767
# min              2021-10-02 00:00:00        5829.000000   1.110000   0.250000
# 25%              2021-10-02 00:00:00        5829.000000   1.530000   0.300000
# 50%              2021-10-03 00:00:00        5829.000000   2.090000   0.300000
# 75%              2021-10-16 18:00:00        7230.000000   2.090000   0.300000
# max              2021-10-26 00:00:00        8045.000000   2.510000   0.310000
# std                              NaN         712.313729   0.437439   0.005735
#
#        Margem_num  selling_day
# count   86.000000    46.000000
# mean     0.156279     9.891304
# min      0.110000     2.000000
# 25%      0.132500     2.000000
# 50%      0.160000     3.000000
# 75%      0.160000    16.750000
# max      0.200000    26.000000
# std      0.029627     9.461567

# %%
sku149marca12 = db[(db['sku'] == 149) & (db['brand'] == 'marca12')]
sku149marca12
# Out:
#        idstore  sku    brand  oldpvp  labelqty  weight (g) Payment_method  \
# 132828     182  149  marca12    2.65         1       202.0       not_sell
# 132829     182  149  marca12    2.65         1       202.0           Cash
# 132830     182  149  marca12    2.65         1       202.0           Card
# 132855     182  149  marca12    2.65         1       202.0           Cash
# 132856     182  149  marca12    2.65         1       202.0           Card
# 132857     182  149  marca12    2.65         1       202.0           Card
# 132858     182  149  marca12    2.65         1       202.0       not_sell
# 132859     182  149  marca12    2.65         1       202.0       not_sell
# 132860     182  149  marca12    2.65         1       202.0       not_sell
# 132861     182  149  marca12    2.65         1       202.0       not_sell
# 132862     182  149  marca12    2.65         1       202.0           Cash
# 132863     182  149  marca12    2.65         1       202.0           Card
# 132864     182  149  marca12    2.65         1       202.0           Cash
# 132865     182  149  marca12    2.65         1       202.0       not_sell
# 132866     182  149  marca12    2.65         1       202.0       not_sell
# 132867     182  149  marca12    2.65         1       202.0       not_sell
# 132868     182  149  marca12    2.65         1       202.0       not_sell
# 132869     182  149  marca12    2.65         1       202.0       not_sell
# 132870     182  149  marca12    2.65         1       202.0       not_sell
# 132871     182  149  marca12    2.65         1       202.0       not_sell
# 132872     182  149  marca12    2.65         1       202.0       not_sell
# 132873     182  149  marca12    2.65         1       202.0       not_sell
# 132874     182  149  marca12    2.65         1       202.0       not_sell
# 132875     217  149  marca12    2.65         1       202.0       not_sell
# 132876     217  149  marca12    2.65         1       202.0       not_sell
# 132877     217  149  marca12    2.65         1       202.0       not_sell
# 132878     217  149  marca12    2.65         1       202.0       not_sell
# 132879     217  149  marca12    2.65         1       202.0       not_sell
# 132880     217  149  marca12    2.65         1       202.0       not_sell
# 132902     217  149  marca12    2.65         1       202.0       not_sell
# 132927     217  149  marca12    2.65         1       202.0       not_sell
# 132928     217  149  marca12    2.65         1       202.0       not_sell
# 132929     217  149  marca12    2.65         1       202.0       not_sell
# 132930     217  149  marca12    2.65         1       202.0           Cash
# 132931     217  149  marca12    2.65         1       202.0           Cash
# 132932     217  149  marca12    2.65         1       202.0           Cash
# 132933     217  149  marca12    2.65         1       202.0           Card
# 132934     217  149  marca12    2.65         1       202.0           Cash
# 132935     217  149  marca12    2.65         1       202.0           Cash
# 132936     217  149  marca12    2.65         1       202.0           Card
# 132937     217  149  marca12    2.65         1       202.0           Card
# 132944     217  149  marca12    2.65         1       202.0           Cash
# 132949     217  149  marca12    2.65         1       202.0           Card
# 132950     217  149  marca12    2.65         1       202.0       not_sell
# 132951     217  149  marca12    2.65         1       202.0       not_sell
# 132953     217  149  marca12    2.65         1       202.0       not_sell
# 132954     217  149  marca12    2.65         1       202.0       not_sell
#
#         Profit (€)  perc_expiring_sku expiring_date  ...  sell_date   sold  \
# 132828        0.22                NaN    2021-10-02  ...        NaT  False
# 132829        0.22                NaN    2021-10-02  ... 2021-10-01   True
# 132830        0.22                NaN    2021-10-02  ... 2021-10-01   True
# 132855        0.22                NaN    2021-10-02  ... 2021-10-01   True
# 132856        0.22                NaN    2021-10-02  ... 2021-10-01   True
# 132857        0.22                NaN    2021-10-02  ... 2021-10-02   True
# 132858        0.22                NaN    2021-10-02  ...        NaT  False
# 132859        0.22                NaN    2021-10-02  ...        NaT  False
# 132860        0.22                NaN    2021-10-02  ...        NaT  False
# 132861        0.22                NaN    2021-10-02  ...        NaT  False
# 132862        0.22                NaN    2021-10-05  ... 2021-10-05   True
# 132863        0.22                NaN    2021-10-05  ... 2021-10-05   True
# 132864        0.22                NaN    2021-10-05  ... 2021-10-05   True
# 132865        0.22                NaN    2021-10-05  ...        NaT  False
# 132866        0.22                NaN    2021-10-05  ...        NaT  False
# 132867        0.22                NaN    2021-10-05  ...        NaT  False
# 132868        0.22                NaN    2021-10-05  ...        NaT  False
# 132869        0.22                NaN    2021-10-05  ...        NaT  False
# 132870        0.22                NaN    2021-10-05  ...        NaT  False
# 132871        0.22                NaN    2021-10-05  ...        NaT  False
# 132872        0.22                NaN    2021-10-05  ...        NaT  False
# 132873        0.22                NaN    2021-10-05  ...        NaT  False
# 132874        0.22                NaN    2021-10-05  ...        NaT  False
# 132875        0.22                NaN    2021-10-05  ...        NaT  False
# 132876        0.22                NaN    2021-10-05  ...        NaT  False
# 132877        0.22                NaN    2021-10-05  ...        NaT  False
# 132878        0.22                NaN    2021-10-05  ...        NaT  False
# 132879        0.22                NaN    2021-10-05  ...        NaT  False
# 132880        0.22                NaN    2021-10-05  ...        NaT  False
# 132902        0.22                NaN    2021-10-05  ...        NaT  False
# 132927        0.22                NaN    2021-10-05  ...        NaT  False
# 132928        0.22                NaN    2021-10-05  ...        NaT  False
# 132929        0.22                NaN    2021-10-05  ...        NaT  False
# 132930        0.22                NaN    2021-10-19  ... 2021-10-19   True
# 132931        0.22                NaN    2021-10-19  ... 2021-10-19   True
# 132932        0.22                NaN    2021-10-19  ... 2021-10-19   True
# 132933        0.22                NaN    2021-10-23  ... 2021-10-22   True
# 132934        0.22                NaN    2021-10-23  ... 2021-10-22   True
# 132935        0.22                NaN    2021-10-23  ... 2021-10-22   True
# 132936        0.22                NaN    2021-10-23  ... 2021-10-22   True
# 132937        0.22                NaN    2021-10-23  ... 2021-10-22   True
# 132944        0.22                NaN    2021-10-23  ... 2021-10-22   True
# 132949        0.22                NaN    2021-10-23  ... 2021-10-22   True
# 132950        0.22                NaN    2021-10-23  ...        NaT  False
# 132951        0.22                NaN    2021-10-23  ...        NaT  False
# 132953        0.22                NaN    2021-10-23  ...        NaT  False
# 132954        0.22                NaN    2021-10-23  ...        NaT  False
#
#          type selling_square_ft  district new_pvp  discount  Margem_num  \
# 132828  Small             703.0     Viseu    1.85       0.3        0.12
# 132829  Small             703.0     Viseu    1.85       0.3        0.12
# 132830  Small             703.0     Viseu    1.85       0.3        0.12
# 132855  Small             703.0     Viseu    1.85       0.3        0.12
# 132856  Small             703.0     Viseu    1.85       0.3        0.12
# 132857  Small             703.0     Viseu    1.85       0.3        0.12
# 132858  Small             703.0     Viseu    1.85       0.3        0.12
# 132859  Small             703.0     Viseu    1.85       0.3        0.12
# 132860  Small             703.0     Viseu    1.85       0.3        0.12
# 132861  Small             703.0     Viseu    1.85       0.3        0.12
# 132862  Small             703.0     Viseu    1.85       0.3        0.12
# 132863  Small             703.0     Viseu    1.85       0.3        0.12
# 132864  Small             703.0     Viseu    1.85       0.3        0.12
# 132865  Small             703.0     Viseu    1.85       0.3        0.12
# 132866  Small             703.0     Viseu    1.85       0.3        0.12
# 132867  Small             703.0     Viseu    1.85       0.3        0.12
# 132868  Small             703.0     Viseu    1.85       0.3        0.12
# 132869  Small             703.0     Viseu    1.85       0.3        0.12
# 132870  Small             703.0     Viseu    1.85       0.3        0.12
# 132871  Small             703.0     Viseu    1.85       0.3        0.12
# 132872  Small             703.0     Viseu    1.85       0.3        0.12
# 132873  Small             703.0     Viseu    1.85       0.3        0.12
# 132874  Small             703.0     Viseu    1.85       0.3        0.12
# 132875  Small             115.0    Lisboa    1.85       0.3        0.12
# 132876  Small             115.0    Lisboa    1.85       0.3        0.12
# 132877  Small             115.0    Lisboa    1.85       0.3        0.12
# 132878  Small             115.0    Lisboa    1.85       0.3        0.12
# 132879  Small             115.0    Lisboa    1.85       0.3        0.12
# 132880  Small             115.0    Lisboa    1.85       0.3        0.12
# 132902  Small             115.0    Lisboa    1.85       0.3        0.12
# 132927  Small             115.0    Lisboa    1.85       0.3        0.12
# 132928  Small             115.0    Lisboa    1.85       0.3        0.12
# 132929  Small             115.0    Lisboa    1.85       0.3        0.12
# 132930  Small             115.0    Lisboa    1.85       0.3        0.12
# 132931  Small             115.0    Lisboa    1.85       0.3        0.12
# 132932  Small             115.0    Lisboa    1.85       0.3        0.12
# 132933  Small             115.0    Lisboa    1.85       0.3        0.12
# 132934  Small             115.0    Lisboa    1.85       0.3        0.12
# 132935  Small             115.0    Lisboa    1.85       0.3        0.12
# 132936  Small             115.0    Lisboa    1.85       0.3        0.12
# 132937  Small             115.0    Lisboa    1.85       0.3        0.12
# 132944  Small             115.0    Lisboa    1.85       0.3        0.12
# 132949  Small             115.0    Lisboa    1.85       0.3        0.12
# 132950  Small             115.0    Lisboa    1.85       0.3        0.12
# 132951  Small             115.0    Lisboa    1.85       0.3        0.12
# 132953  Small             115.0    Lisboa    1.85       0.3        0.12
# 132954  Small             115.0    Lisboa    1.85       0.3        0.12
#
#         selling_day  selling_day_of_week
# 132828          NaN                  NaN
# 132829          1.0               Friday
# 132830          1.0               Friday
# 132855          1.0               Friday
# 132856          1.0               Friday
# 132857          2.0             Saturday
# 132858          NaN                  NaN
# 132859          NaN                  NaN
# 132860          NaN                  NaN
# 132861          NaN                  NaN
# 132862          5.0              Tuesday
# 132863          5.0              Tuesday
# 132864          5.0              Tuesday
# 132865          NaN                  NaN
# 132866          NaN                  NaN
# 132867          NaN                  NaN
# 132868          NaN                  NaN
# 132869          NaN                  NaN
# 132870          NaN                  NaN
# 132871          NaN                  NaN
# 132872          NaN                  NaN
# 132873          NaN                  NaN
# 132874          NaN                  NaN
# 132875          NaN                  NaN
# 132876          NaN                  NaN
# 132877          NaN                  NaN
# 132878          NaN                  NaN
# 132879          NaN                  NaN
# 132880          NaN                  NaN
# 132902          NaN                  NaN
# 132927          NaN                  NaN
# 132928          NaN                  NaN
# 132929          NaN                  NaN
# 132930         19.0              Tuesday
# 132931         19.0              Tuesday
# 132932         19.0              Tuesday
# 132933         22.0               Friday
# 132934         22.0               Friday
# 132935         22.0               Friday
# 132936         22.0               Friday
# 132937         22.0               Friday
# 132944         22.0               Friday
# 132949         22.0               Friday
# 132950          NaN                  NaN
# 132951          NaN                  NaN
# 132953          NaN                  NaN
# 132954          NaN                  NaN
#
# [47 rows x 21 columns]

# %%
marca12 = db[ (db['brand'] == 'marca12')]
marca12.describe()
# Out:
#             oldpvp  labelqty   weight (g)   Profit (€)  perc_expiring_sku  \
# count  1760.000000    1760.0  1760.000000  1760.000000        1713.000000
# mean      1.047170       1.0   143.814773     0.087625           0.610663
# min       0.990000       1.0    51.000000     0.060000           0.000000
# 25%       0.990000       1.0    85.000000     0.070000           0.250000
# 50%       0.990000       1.0   121.000000     0.080000           0.500000
# 75%       0.990000       1.0   232.000000     0.090000           1.000000
# max       2.650000       1.0   278.000000     0.230000           1.000000
# std       0.291378       0.0    72.148754     0.030682           0.375597
#
#                        expiring_date                 labelling_date  \
# count                           1760                           1760
# mean   2021-10-16 00:16:21.818181888  2021-10-14 14:46:54.545454336
# min              2021-10-02 00:00:00            2021-10-01 00:00:00
# 25%              2021-10-07 00:00:00            2021-10-06 00:00:00
# 50%              2021-10-14 00:00:00            2021-10-13 00:00:00
# 75%              2021-10-21 00:00:00            2021-10-21 00:00:00
# max              2021-10-31 00:00:00            2021-10-31 00:00:00
# std                              NaN                            NaN
#
#                            sell_date  selling_square_ft      new_pvp  \
# count                            922        1694.000000  1760.000000
# mean   2021-10-15 16:08:19.783080448        2816.324675     0.554352
# min              2021-10-01 00:00:00         115.000000     0.490000
# 25%              2021-10-07 06:00:00         686.000000     0.490000
# 50%              2021-10-14 00:00:00         703.000000     0.490000
# 75%              2021-10-21 00:00:00        4762.000000     0.490000
# max              2021-10-31 00:00:00       13480.000000     1.850000
# std                              NaN        3710.636055     0.235370
#
#           discount   Margem_num  selling_day
# count  1760.000000  1760.000000   922.000000
# mean      0.482477     0.161477    15.672451
# min       0.300000     0.120000     1.000000
# 25%       0.510000     0.140000     7.250000
# 50%       0.510000     0.170000    14.000000
# 75%       0.510000     0.190000    21.000000
# max       0.510000     0.200000    31.000000
# std       0.070776     0.024929     8.409258

# %%
same_date_count = len(percnulo[percnulo['labelling_date'] == percnulo['expiring_date']])
same_date_count
# Out:
# 54

# %%
null_perc_expiring_date = db[db['perc_expiring_sku'].isnull()]
matching_dates = null_perc_expiring_date[null_perc_expiring_date['expiring_date'] == null_perc_expiring_date['labelling_date']]
matching_dates
# Out:
#        idstore  sku    brand  oldpvp  labelqty  weight (g) Payment_method  \
# 132826      89   45  marca18    2.19         1       300.0           Cash
# 132827      89   45  marca18    2.19         1       300.0       not_sell
# 132955      91  176  marca10    1.12         1       193.0       not_sell
# 132956      91  176  marca10    1.47         1       193.0       not_sell
# 132957      91  176  marca10    1.47         1       193.0       not_sell
# 132958      91  176  marca10    1.22         1       193.0           Card
# 132959      91  176  marca10    1.22         1       193.0       not_sell
# 132960      91  176  marca10    1.71         1       193.0       not_sell
# 132961      91  176  marca10    1.36         1       193.0       not_sell
# 132962      91  176  marca10    1.68         1       193.0       not_sell
# 132963      91  176  marca10    1.68         1       193.0       not_sell
# 132964      91  176  marca10    1.68         1       193.0       not_sell
# 132965      91  176  marca10    1.68         1       193.0       not_sell
# 132966      91  176  marca10    1.05         1       193.0       not_sell
# 132967      91  176  marca10    1.78         1       193.0       not_sell
# 132968      91  176  marca10    1.78         1       193.0       not_sell
# 132969      91  176  marca10    1.78         1       193.0       not_sell
# 132970      91  176  marca10    1.50         1       193.0       not_sell
# 132971      91  176  marca10    1.54         1       193.0           Card
# 132972      91  176  marca10    1.61         1       193.0       not_sell
# 132973      91  176  marca10    1.33         1       193.0       not_sell
# 132974      91  176  marca10    1.57         1       193.0       not_sell
# 132975      91  176  marca10    1.57         1       193.0       not_sell
# 132976      91  176  marca10    1.71         1       193.0           Card
# 132977      91  176  marca10    1.29         1       193.0       not_sell
# 132978      91  176  marca10    1.29         1       193.0       not_sell
# 132979      91  176  marca10    1.29         1       193.0       not_sell
# 132980      91  176  marca10    1.26         1       193.0       not_sell
# 132981      91  176  marca10    1.43         1       193.0           Card
# 132983      91  176  marca10    1.29         1       193.0           Card
# 132984      91  176  marca10    1.33         1       193.0           Card
# 132985      91  176  marca10    1.50         1       193.0       not_sell
# 132986      91  176  marca10    1.15         1       193.0           Card
# 132987      91  176  marca10    1.22         1       193.0           Card
# 132988      91  176  marca10    1.36         1       193.0           Card
# 132989      91  176  marca10    1.19         1       193.0           Cash
# 132990      91  176  marca10    1.19         1       193.0           Cash
# 132991      91  176  marca10    1.08         1       193.0           Cash
# 132992      91  176  marca10    2.10         1       193.0       not_sell
# 132993      92  176  marca10    1.19         1       193.0           Card
# 133006      92  176  marca10    0.91         1       193.0           Card
# 133027      92  176  marca10    1.40         1       193.0           Cash
# 133028      92  176  marca10    1.22         1       193.0           Cash
# 133029      92  176  marca10    1.40         1       193.0           Card
# 133030      92  176  marca10    0.98         1       193.0           Card
# 133031      92  176  marca10    1.29         1       193.0           Cash
# 133039      92  176  marca10    1.40         1       193.0           Card
# 133040      92  176  marca10    1.54         1       193.0           Cash
# 133041      92  176  marca10    1.43         1       193.0           Card
# 133051      92  176  marca10    1.26         1       193.0           Card
# 133052      92  176  marca10    1.47         1       193.0           Cash
# 133065      92  176  marca10    1.12         1       193.0           Cash
# 133066      92  176  marca10    0.84         1       193.0           Card
# 133067      92  176  marca10    0.94         1       193.0           Card
#
#         Profit (€)  perc_expiring_sku expiring_date  ...  sell_date   sold  \
# 132826        0.31                NaN    2021-10-23  ... 2021-10-23   True
# 132827        0.31                NaN    2021-10-23  ...        NaT  False
# 132955        0.11                NaN    2021-10-31  ...        NaT  False
# 132956        0.13                NaN    2021-10-27  ...        NaT  False
# 132957        0.13                NaN    2021-10-27  ...        NaT  False
# 132958        0.11                NaN    2021-10-27  ... 2021-10-27   True
# 132959        0.11                NaN    2021-10-27  ...        NaT  False
# 132960        0.15                NaN    2021-10-27  ...        NaT  False
# 132961        0.12                NaN    2021-10-27  ...        NaT  False
# 132962        0.15                NaN    2021-10-27  ...        NaT  False
# 132963        0.15                NaN    2021-10-27  ...        NaT  False
# 132964        0.15                NaN    2021-10-27  ...        NaT  False
# 132965        0.15                NaN    2021-10-27  ...        NaT  False
# 132966        0.09                NaN    2021-10-27  ...        NaT  False
# 132967        0.16                NaN    2021-10-27  ...        NaT  False
# 132968        0.16                NaN    2021-10-27  ...        NaT  False
# 132969        0.16                NaN    2021-10-27  ...        NaT  False
# 132970        0.14                NaN    2021-10-27  ...        NaT  False
# 132971        0.14                NaN    2021-10-27  ... 2021-10-27   True
# 132972        0.15                NaN    2021-10-27  ...        NaT  False
# 132973        0.12                NaN    2021-10-27  ...        NaT  False
# 132974        0.14                NaN    2021-10-27  ...        NaT  False
# 132975        0.14                NaN    2021-10-27  ...        NaT  False
# 132976        0.15                NaN    2021-10-27  ... 2021-10-27   True
# 132977        0.12                NaN    2021-10-27  ...        NaT  False
# 132978        0.12                NaN    2021-10-27  ...        NaT  False
# 132979        0.12                NaN    2021-10-27  ...        NaT  False
# 132980        0.11                NaN    2021-10-27  ...        NaT  False
# 132981        0.13                NaN    2021-10-27  ... 2021-10-27   True
# 132983        0.12                NaN    2021-10-31  ... 2021-10-31   True
# 132984        0.13                NaN    2021-10-31  ... 2021-10-31   True
# 132985        0.15                NaN    2021-10-31  ...        NaT  False
# 132986        0.11                NaN    2021-10-31  ... 2021-10-31   True
# 132987        0.12                NaN    2021-10-31  ... 2021-10-31   True
# 132988        0.13                NaN    2021-10-31  ... 2021-10-31   True
# 132989        0.12                NaN    2021-10-31  ... 2021-10-31   True
# 132990        0.12                NaN    2021-10-31  ... 2021-10-31   True
# 132991        0.11                NaN    2021-10-31  ... 2021-10-31   True
# 132992        0.20                NaN    2021-10-31  ...        NaT  False
# 132993        0.12                NaN    2021-10-04  ... 2021-10-04   True
# 133006        0.09                NaN    2021-10-29  ... 2021-10-29   True
# 133027        0.14                NaN    2021-10-04  ... 2021-10-04   True
# 133028        0.12                NaN    2021-10-04  ... 2021-10-04   True
# 133029        0.14                NaN    2021-10-04  ... 2021-10-04   True
# 133030        0.09                NaN    2021-10-04  ... 2021-10-04   True
# 133031        0.12                NaN    2021-10-04  ... 2021-10-04   True
# 133039        0.13                NaN    2021-10-11  ... 2021-10-11   True
# 133040        0.14                NaN    2021-10-11  ... 2021-10-11   True
# 133041        0.13                NaN    2021-10-11  ... 2021-10-11   True
# 133051        0.12                NaN    2021-10-25  ... 2021-10-25   True
# 133052        0.14                NaN    2021-10-29  ... 2021-10-29   True
# 133065        0.11                NaN    2021-10-29  ... 2021-10-29   True
# 133066        0.08                NaN    2021-10-29  ... 2021-10-29   True
# 133067        0.09                NaN    2021-10-29  ... 2021-10-29   True
#
#           type selling_square_ft  district new_pvp  discount  Margem_num  \
# 132826  Medium            5829.0    Lisboa    1.53      0.30        0.20
# 132827  Medium            5829.0    Lisboa    1.53      0.30        0.20
# 132955  Medium            8952.0    Aveiro    0.84      0.25        0.13
# 132956  Medium            8952.0    Aveiro    1.02      0.31        0.13
# 132957  Medium            8952.0    Aveiro    1.02      0.31        0.13
# 132958  Medium            8952.0    Aveiro    0.85      0.30        0.13
# 132959  Medium            8952.0    Aveiro    0.85      0.30        0.13
# 132960  Medium            8952.0    Aveiro    1.19      0.30        0.13
# 132961  Medium            8952.0    Aveiro    0.95      0.30        0.13
# 132962  Medium            8952.0    Aveiro    1.17      0.30        0.13
# 132963  Medium            8952.0    Aveiro    1.17      0.30        0.13
# 132964  Medium            8952.0    Aveiro    1.17      0.30        0.13
# 132965  Medium            8952.0    Aveiro    1.17      0.30        0.13
# 132966  Medium            8952.0    Aveiro    0.73      0.30        0.13
# 132967  Medium            8952.0    Aveiro    1.24      0.30        0.13
# 132968  Medium            8952.0    Aveiro    1.24      0.30        0.13
# 132969  Medium            8952.0    Aveiro    1.24      0.30        0.13
# 132970  Medium            8952.0    Aveiro    1.05      0.30        0.13
# 132971  Medium            8952.0    Aveiro    1.07      0.31        0.13
# 132972  Medium            8952.0    Aveiro    1.12      0.30        0.13
# 132973  Medium            8952.0    Aveiro    0.93      0.30        0.13
# 132974  Medium            8952.0    Aveiro    1.09      0.31        0.13
# 132975  Medium            8952.0    Aveiro    1.09      0.31        0.13
# 132976  Medium            8952.0    Aveiro    1.19      0.30        0.13
# 132977  Medium            8952.0    Aveiro    0.90      0.30        0.13
# 132978  Medium            8952.0    Aveiro    0.90      0.30        0.13
# 132979  Medium            8952.0    Aveiro    0.90      0.30        0.13
# 132980  Medium            8952.0    Aveiro    0.88      0.30        0.13
# 132981  Medium            8952.0    Aveiro    1.00      0.30        0.13
# 132983  Medium            8952.0    Aveiro    0.96      0.26        0.13
# 132984  Medium            8952.0    Aveiro    0.99      0.26        0.13
# 132985  Medium            8952.0    Aveiro    1.12      0.25        0.13
# 132986  Medium            8952.0    Aveiro    0.86      0.25        0.13
# 132987  Medium            8952.0    Aveiro    0.91      0.25        0.13
# 132988  Medium            8952.0    Aveiro    1.02      0.25        0.13
# 132989  Medium            8952.0    Aveiro    0.89      0.25        0.13
# 132990  Medium            8952.0    Aveiro    0.89      0.25        0.13
# 132991  Medium            8952.0    Aveiro    0.81      0.25        0.13
# 132992  Medium            8952.0    Aveiro    1.57      0.25        0.13
# 132993  Medium            7230.0      Beja    0.89      0.25        0.13
# 133006  Medium            7230.0      Beja    0.68      0.25        0.13
# 133027  Medium            7230.0      Beja    1.05      0.25        0.13
# 133028  Medium            7230.0      Beja    0.91      0.25        0.13
# 133029  Medium            7230.0      Beja    1.05      0.25        0.13
# 133030  Medium            7230.0      Beja    0.73      0.26        0.13
# 133031  Medium            7230.0      Beja    0.96      0.26        0.13
# 133039  Medium            7230.0      Beja    0.98      0.30        0.13
# 133040  Medium            7230.0      Beja    1.07      0.31        0.13
# 133041  Medium            7230.0      Beja    1.00      0.30        0.13
# 133051  Medium            7230.0      Beja    0.94      0.25        0.13
# 133052  Medium            7230.0      Beja    1.10      0.25        0.13
# 133065  Medium            7230.0      Beja    0.84      0.25        0.13
# 133066  Medium            7230.0      Beja    0.63      0.25        0.13
# 133067  Medium            7230.0      Beja    0.70      0.26        0.13
#
#         selling_day  selling_day_of_week
# 132826         23.0             Saturday
# 132827          NaN                  NaN
# 132955          NaN                  NaN
# 132956          NaN                  NaN
# 132957          NaN                  NaN
# 132958         27.0            Wednesday
# 132959          NaN                  NaN
# 132960          NaN                  NaN
# 132961          NaN                  NaN
# 132962          NaN                  NaN
# 132963          NaN                  NaN
# 132964          NaN                  NaN
# 132965          NaN                  NaN
# 132966          NaN                  NaN
# 132967          NaN                  NaN
# 132968          NaN                  NaN
# 132969          NaN                  NaN
# 132970          NaN                  NaN
# 132971         27.0            Wednesday
# 132972          NaN                  NaN
# 132973          NaN                  NaN
# 132974          NaN                  NaN
# 132975          NaN                  NaN
# 132976         27.0            Wednesday
# 132977          NaN                  NaN
# 132978          NaN                  NaN
# 132979          NaN                  NaN
# 132980          NaN                  NaN
# 132981         27.0            Wednesday
# 132983         31.0               Sunday
# 132984         31.0               Sunday
# 132985          NaN                  NaN
# 132986         31.0               Sunday
# 132987         31.0               Sunday
# 132988         31.0               Sunday
# 132989         31.0               Sunday
# 132990         31.0               Sunday
# 132991         31.0               Sunday
# 132992          NaN                  NaN
# 132993          4.0               Monday
# 133006         29.0               Friday
# 133027          4.0               Monday
# 133028          4.0               Monday
# 133029          4.0               Monday
# 133030          4.0               Monday
# 133031          4.0               Monday
# 133039         11.0               Monday
# 133040         11.0               Monday
# 133041         11.0               Monday
# 133051         25.0               Monday
# 133052         29.0               Friday
# 133065         29.0               Friday
# 133066         29.0               Friday
# 133067         29.0               Friday
#
# [54 rows x 21 columns]

# %%
db.loc[matching_dates.index, 'perc_expiring_sku'] = 0

# %%
percnulo = db[db['perc_expiring_sku'].isnull()]
percnulo
# Out:
#        idstore  sku    brand  oldpvp  labelqty  weight (g) Payment_method  \
# 132821      89   45  marca18    2.19         1       300.0           Card
# 132822      89   45  marca18    2.19         1       300.0           Cash
# 132825      89   45  marca18    2.19         1       300.0       not_sell
# 132828     182  149  marca12    2.65         1       202.0       not_sell
# 132829     182  149  marca12    2.65         1       202.0           Cash
# ...        ...  ...      ...     ...       ...         ...            ...
# 133042      92  176  marca10    1.99         1       193.0           Card
# 133043      92  176  marca10    2.03         1       193.0           Card
# 133044      92  176  marca10    1.19         1       193.0           Cash
# 133049      92  176  marca10    1.43         1       193.0           Cash
# 133050      92  176  marca10    1.43         1       193.0           Cash
#
#         Profit (€)  perc_expiring_sku expiring_date  ...  sell_date   sold  \
# 132821        0.31                NaN    2021-10-27  ... 2021-10-26   True
# 132822        0.31                NaN    2021-10-27  ... 2021-10-26   True
# 132825        0.31                NaN    2021-10-27  ...        NaT  False
# 132828        0.22                NaN    2021-10-02  ...        NaT  False
# 132829        0.22                NaN    2021-10-02  ... 2021-10-01   True
# ...            ...                ...           ...  ...        ...    ...
# 133042        0.18                NaN    2021-10-17  ... 2021-10-16   True
# 133043        0.18                NaN    2021-10-17  ... 2021-10-16   True
# 133044        0.12                NaN    2021-10-24  ... 2021-10-23   True
# 133049        0.14                NaN    2021-10-24  ... 2021-10-23   True
# 133050        0.14                NaN    2021-10-24  ... 2021-10-23   True
#
#           type selling_square_ft  district new_pvp  discount  Margem_num  \
# 132821  Medium            5829.0    Lisboa    1.53      0.30        0.20
# 132822  Medium            5829.0    Lisboa    1.53      0.30        0.20
# 132825  Medium            5829.0    Lisboa    1.53      0.30        0.20
# 132828   Small             703.0     Viseu    1.85      0.30        0.12
# 132829   Small             703.0     Viseu    1.85      0.30        0.12
# ...        ...               ...       ...     ...       ...         ...
# 133042  Medium            7230.0      Beja    1.39      0.30        0.13
# 133043  Medium            7230.0      Beja    1.42      0.30        0.13
# 133044  Medium            7230.0      Beja    0.89      0.25        0.13
# 133049  Medium            7230.0      Beja    1.07      0.25        0.13
# 133050  Medium            7230.0      Beja    1.07      0.25        0.13
#
#         selling_day  selling_day_of_week
# 132821         26.0              Tuesday
# 132822         26.0              Tuesday
# 132825          NaN                  NaN
# 132828          NaN                  NaN
# 132829          1.0               Friday
# ...             ...                  ...
# 133042         16.0             Saturday
# 133043         16.0             Saturday
# 133044         23.0             Saturday
# 133049         23.0             Saturday
# 133050         23.0             Saturday
#
# [71 rows x 21 columns]

# %%
percnulo['sku'].value_counts()
# Out:
# sku
# 149    47
# 176    21
# 45      3
# Name: count, dtype: int64

# %%
percnulo['brand'].value_counts()
# Out:
# brand
# marca12    47
# marca10    21
# marca18     3
# Name: count, dtype: int64

# %%
db['perc_expiring_sku'].describe()
# Out:
# count    149982.000000
# mean          0.384840
# std           0.222740
# min           0.000000
# 25%           0.200000
# 50%           0.333333
# 75%           0.666667
# max           1.000000
# Name: perc_expiring_sku, dtype: float64

# %%
median_perc_expiring_sku = db['perc_expiring_sku'].median()
db['perc_expiring_sku']=db['perc_expiring_sku'].fillna(median_perc_expiring_sku)

# %%
db.isna().sum()
# Out:
# idstore                    0
# sku                        0
# brand                      0
# oldpvp                    22
# labelqty                   0
# weight (g)               428
# Payment_method             0
# Profit (€)                 0
# perc_expiring_sku          0
# expiring_date              0
# labelling_date             0
# sell_date              69542
# sold                       0
# type                       0
# selling_square_ft      10779
# district                   0
# new_pvp                   28
# discount                  28
# Margem_num                 0
# selling_day            69542
# selling_day_of_week    69542
# dtype: int64

# %% [markdown]
# ### weight

# %%
sempeso = db[db['weight (g)'].isnull()]
sempeso
# Out:
#       idstore  sku    brand  oldpvp  labelqty  weight (g) Payment_method  \
# 46          7    2   marca2    3.19         1         NaN       not_sell
# 147        14    4   marca3    2.79         1         NaN           Card
# 169        18    4   marca3    2.79         1         NaN       not_sell
# 180        21    4   marca3    2.79         1         NaN           Card
# 16381     199   47   marca2    2.95         1         NaN           Cash
# ...       ...  ...      ...     ...       ...         ...            ...
# 78923     217  181  marca25    1.29         1         NaN           Cash
# 78924     217  181  marca25    1.29         1         NaN           Cash
# 78925     217  181  marca25    1.29         1         NaN           Card
# 78926     217  181  marca25    1.29         1         NaN           Cash
# 78927     217  181  marca25    1.29         1         NaN       not_sell
#
#        Profit (€)  perc_expiring_sku expiring_date  ...  sell_date   sold  \
# 46           0.36           0.111111    2021-10-26  ...        NaT  False
# 147          0.33           0.250000    2021-10-28  ... 2021-10-27   True
# 169          0.33           0.250000    2021-10-21  ...        NaT  False
# 180          0.33           0.250000    2021-10-09  ... 2021-10-09   True
# 16381        0.25           0.060606    2021-10-25  ... 2021-10-19   True
# ...           ...                ...           ...  ...        ...    ...
# 78923        0.18           0.250000    2021-10-12  ... 2021-10-12   True
# 78924        0.18           0.250000    2021-10-12  ... 2021-10-12   True
# 78925        0.18           0.000000    2021-10-24  ... 2021-10-24   True
# 78926        0.18           0.000000    2021-10-24  ... 2021-10-24   True
# 78927        0.18           0.000000    2021-10-28  ...        NaT  False
#
#          type selling_square_ft        district new_pvp  discount  Margem_num  \
# 46      Large           13618.0          Guarda    2.39      0.25        0.15
# 147     Large           21275.0            Beja    1.95      0.30        0.17
# 169     Large           12373.0          Leiria    1.95      0.30        0.17
# 180     Large           17657.0          Guarda    1.95      0.30        0.17
# 16381  Medium           12009.0  Castelo Branco    1.47      0.50        0.17
# ...       ...               ...             ...     ...       ...         ...
# 78923   Small             115.0          Lisboa    0.90      0.30        0.20
# 78924   Small             115.0          Lisboa    0.90      0.30        0.20
# 78925   Small             115.0          Lisboa    0.90      0.30        0.20
# 78926   Small             115.0          Lisboa    0.90      0.30        0.20
# 78927   Small             115.0          Lisboa    0.90      0.30        0.20
#
#        selling_day  selling_day_of_week
# 46             NaN                  NaN
# 147           27.0            Wednesday
# 169            NaN                  NaN
# 180            9.0             Saturday
# 16381         19.0              Tuesday
# ...            ...                  ...
# 78923         12.0              Tuesday
# 78924         12.0              Tuesday
# 78925         24.0               Sunday
# 78926         24.0               Sunday
# 78927          NaN                  NaN
#
# [428 rows x 21 columns]

# %%
sempeso['sku'].value_counts()
# Out:
# sku
# 170    277
# 181     95
# 47      34
# 148     18
# 4        3
# 2        1
# Name: count, dtype: int64

# %%
weight_mode_by_sku = db.groupby('sku')['weight (g)'].agg(lambda x: x.mode()[0] if not x.mode().empty else np.nan)
weight_mode_by_sku
# Out:
# sku
# 1      260.0
# 2      222.0
# 3      194.0
# 4      134.0
# 5      219.0
#        ...
# 315    204.0
# 316    157.0
# 317    261.0
# 318     97.0
# 319    141.0
# Name: weight (g), Length: 318, dtype: float64

# %%
for sku in [2, 4]:
  db.loc[(db['sku'] == sku) & (db['weight (g)'].isnull()), 'weight (g)'] = weight_mode_by_sku.get(sku)

# %%
imputer = KNNImputer(n_neighbors=1)
cols_to_impute = ['weight (g)']
numeric_db = db[cols_to_impute]
db[cols_to_impute] = imputer.fit_transform(numeric_db)
print(db['weight (g)'].isna().sum())
# Out:
# 0

# %% [markdown]
# ### old_pvp

# %%
db[db['oldpvp'].isnull()]
# Out:
#        idstore  sku    brand  oldpvp  labelqty  weight (g) Payment_method  \
# 15           2    2   marca2     NaN         1       222.0           Cash
# 877         59    7   marca5     NaN         1       131.0       not_sell
# 959         14    8   marca2     NaN         1       174.0           Cash
# 7568       289   12   marca2     NaN         1       225.0           Card
# 7575       289   12   marca2     NaN         1       225.0           Card
# 7582        98   12   marca2     NaN         1       225.0       not_sell
# 21533       59   61   marca2     NaN         1       186.0           Cash
# 45357      128  105   marca2     NaN         1       152.0           Card
# 45368      128  105   marca2     NaN         1       152.0       not_sell
# 45377      128  105   marca2     NaN         1       152.0       not_sell
# 62534       50  135   marca2     NaN         1       130.0       not_sell
# 136206     268  291   marca2     NaN         1       165.0       not_sell
# 136207     268  291   marca2     NaN         1       165.0       not_sell
# 136208     268  291   marca2     NaN         1       165.0       not_sell
# 136209     268  291   marca2     NaN         1       165.0       not_sell
# 136210     268  291   marca2     NaN         1       165.0           Card
# 137996     128  293   marca2     NaN         1        52.0           Card
# 139317     177  293   marca2     NaN         1        52.0           Card
# 142085     268  293   marca2     NaN         1        52.0       not_sell
# 143582      78  294  marca15     NaN         1       123.0       not_sell
# 144418     109  302   marca2     NaN         1       147.0           Card
# 144604     116  302   marca2     NaN         1       147.0           Card
#
#         Profit (€)  perc_expiring_sku expiring_date  ...  sell_date   sold  \
# 15            0.24           0.121212    2021-10-25  ... 2021-10-14   True
# 877           0.15           0.666667    2021-10-17  ...        NaT  False
# 959           0.12           0.200000    2021-10-29  ... 2021-10-28   True
# 7568          0.18           0.666667    2021-10-16  ... 2021-10-15   True
# 7575          0.18           0.666667    2021-10-05  ... 2021-10-04   True
# 7582          0.18           0.333333    2021-10-29  ...        NaT  False
# 21533         0.06           0.666667    2021-10-13  ... 2021-10-12   True
# 45357         0.18           0.666667    2021-10-16  ... 2021-10-16   True
# 45368         0.18           0.333333    2021-10-16  ...        NaT  False
# 45377         0.18           0.333333    2021-10-16  ...        NaT  False
# 62534         0.40           0.666667    2021-10-09  ...        NaT  False
# 136206        0.10           0.200000    2021-10-23  ...        NaT  False
# 136207        0.10           0.200000    2021-10-23  ...        NaT  False
# 136208        0.10           0.200000    2021-10-23  ...        NaT  False
# 136209        0.10           0.200000    2021-10-23  ...        NaT  False
# 136210        0.10           0.200000    2021-10-26  ... 2021-10-26   True
# 137996        0.24           0.333333    2021-10-22  ... 2021-10-21   True
# 139317        0.24           0.333333    2021-10-25  ... 2021-10-25   True
# 142085        0.24           0.000000    2021-10-04  ...        NaT  False
# 143582        0.26           0.333333    2021-10-10  ...        NaT  False
# 144418        0.17           0.200000    2021-10-30  ... 2021-10-29   True
# 144604        0.17           0.400000    2021-10-09  ... 2021-10-09   True
#
#           type selling_square_ft          district new_pvp  discount  \
# 15       Large           12358.0          Bragança    1.59       0.5
# 877     Medium            6540.0            Guarda    1.53       0.3
# 959      Large           21275.0              Beja    0.83       0.3
# 7568     Small             342.0  Viana do Castelo    0.97       0.3
# 7575     Small             342.0  Viana do Castelo    0.97       0.3
# 7582    Medium            3344.0              Faro    0.97       0.3
# 21533   Medium            6540.0            Guarda    0.48       0.3
# 45357   Medium            5130.0            Aveiro    1.04       0.3
# 45368   Medium            5130.0            Aveiro    1.04       0.3
# 45377   Medium            5130.0            Aveiro    1.04       0.3
# 62534   Medium             833.0            Lisboa    2.09       0.3
# 136206   Small             808.0             Viseu    0.90       0.3
# 136207   Small             808.0             Viseu    0.90       0.3
# 136208   Small             808.0             Viseu    0.90       0.3
# 136209   Small             808.0             Viseu    0.90       0.3
# 136210   Small             808.0             Viseu    0.90       0.3
# 137996  Medium            5130.0            Aveiro    1.18       0.3
# 139317   Small             842.0             Porto    1.18       0.3
# 142085   Small             808.0             Viseu    1.18       0.3
# 143582  Medium            4600.0             Braga    1.39       0.3
# 144418  Medium            6273.0  Viana do Castelo    0.83       0.3
# 144604  Medium            4639.0           Coimbra    0.83       0.3
#
#         Margem_num  selling_day  selling_day_of_week
# 15            0.15         14.0             Thursday
# 877           0.10          NaN                  NaN
# 959           0.15         28.0             Thursday
# 7568          0.19         15.0               Friday
# 7575          0.19          4.0               Monday
# 7582          0.19          NaN                  NaN
# 21533         0.13         12.0              Tuesday
# 45357         0.17         16.0             Saturday
# 45368         0.17          NaN                  NaN
# 45377         0.17          NaN                  NaN
# 62534         0.19          NaN                  NaN
# 136206        0.11          NaN                  NaN
# 136207        0.11          NaN                  NaN
# 136208        0.11          NaN                  NaN
# 136209        0.11          NaN                  NaN
# 136210        0.11         26.0              Tuesday
# 137996        0.20         21.0             Thursday
# 139317        0.20         25.0               Monday
# 142085        0.20          NaN                  NaN
# 143582        0.19          NaN                  NaN
# 144418        0.20         29.0               Friday
# 144604        0.20          9.0             Saturday
#
# [22 rows x 21 columns]

# %%
db['oldpvp'] = np.where(db['oldpvp'].isnull(), db['new_pvp'] / (1-db['discount']), db['oldpvp'])

# %%
db[db['oldpvp'].isnull()]
# Out:
# Empty DataFrame
# Columns: [idstore, sku, brand, oldpvp, labelqty, weight (g), Payment_method, Profit (€), perc_expiring_sku, expiring_date, labelling_date, sell_date, sold, type, selling_square_ft, district, new_pvp, discount, Margem_num, selling_day, selling_day_of_week]
# Index: []
#
# [0 rows x 21 columns]

# %% [markdown]
# ### discount e new_pvp

# %%
null_discount_new_pvp = db[db['discount'].isnull() | db['new_pvp'].isnull()]
null_discount_new_pvp
# Out:
#        idstore  sku    brand  oldpvp  labelqty  weight (g) Payment_method  \
# 10           1    1   marca1    5.23         1       260.0           Card
# 875         59    7   marca5    2.19         1       131.0           Cash
# 955         14    8   marca2    1.19         1       174.0           Card
# 7564        14   12   marca2    1.39         1       225.0       not_sell
# 7572       289   12   marca2    1.39         1       225.0       not_sell
# 7578        98   12   marca2    1.39         1       225.0           Cash
# 7583        98   12   marca2    1.39         1       225.0           Card
# 7585        98   12   marca2    1.39         1       225.0       not_sell
# 21531       59   61   marca2    0.69         1       186.0           Cash
# 21539       59   61   marca2    0.69         1       186.0       not_sell
# 45363      128  105   marca2    1.49         1       152.0       not_sell
# 45375      128  105   marca2    1.49         1       152.0       not_sell
# 45379      128  105   marca2    1.49         1       152.0       not_sell
# 62530       50  135   marca2    2.99         1       130.0       not_sell
# 62541       50  135   marca2    2.99         1       130.0       not_sell
# 134858      61  291   marca2    1.29         1       165.0       not_sell
# 134859      61  291   marca2    1.29         1       165.0       not_sell
# 134860      61  291   marca2    1.29         1       165.0       not_sell
# 134861      61  291   marca2    1.29         1       165.0           Card
# 134862      61  291   marca2    1.29         1       165.0       not_sell
# 134863      61  291   marca2    1.29         1       165.0       not_sell
# 137336     108  293   marca2    1.69         1        52.0           Card
# 138552      44  293   marca2    1.69         1        52.0       not_sell
# 139814      58  293   marca2    1.69         1        52.0       not_sell
# 140225     199  293   marca2    1.69         1        52.0           Cash
# 140884      72  293   marca2    1.69         1        52.0       not_sell
# 143169      51  294  marca15    1.99         1       123.0           Card
# 143945      14  302   marca2    1.19         1       147.0           Cash
#
#         Profit (€)  perc_expiring_sku expiring_date  ...  sell_date   sold  \
# 10            0.42           0.010050    2021-10-03  ... 2021-10-03   True
# 875           0.15           0.666667    2021-10-17  ... 2021-10-16   True
# 955           0.12           0.200000    2021-10-29  ... 2021-10-28   True
# 7564          0.18           0.000000    2021-10-21  ...        NaT  False
# 7572          0.18           0.666667    2021-10-16  ...        NaT  False
# 7578          0.18           0.333333    2021-10-19  ... 2021-10-19   True
# 7583          0.18           0.333333    2021-10-15  ... 2021-10-14   True
# 7585          0.18           0.333333    2021-10-15  ...        NaT  False
# 21531         0.06           0.666667    2021-10-12  ... 2021-10-11   True
# 21539         0.06           0.666667    2021-10-14  ...        NaT  False
# 45363         0.18           0.333333    2021-10-16  ...        NaT  False
# 45375         0.18           0.333333    2021-10-16  ...        NaT  False
# 45379         0.18           0.333333    2021-10-16  ...        NaT  False
# 62530         0.40           0.666667    2021-10-09  ...        NaT  False
# 62541         0.40           0.666667    2021-10-09  ...        NaT  False
# 134858        0.10           0.400000    2021-10-13  ...        NaT  False
# 134859        0.10           0.400000    2021-10-13  ...        NaT  False
# 134860        0.10           0.400000    2021-10-13  ...        NaT  False
# 134861        0.10           0.400000    2021-10-14  ... 2021-10-14   True
# 134862        0.10           0.400000    2021-10-14  ...        NaT  False
# 134863        0.10           0.400000    2021-10-14  ...        NaT  False
# 137336        0.24           0.333333    2021-10-29  ... 2021-10-28   True
# 138552        0.24           0.000000    2021-10-22  ...        NaT  False
# 139814        0.24           0.333333    2021-10-22  ...        NaT  False
# 140225        0.24           0.666667    2021-10-22  ... 2021-10-22   True
# 140884        0.24           0.333333    2021-10-15  ...        NaT  False
# 143169        0.26           0.666667    2021-10-08  ... 2021-10-07   True
# 143945        0.17           0.400000    2021-10-08  ... 2021-10-08   True
#
#           type selling_square_ft          district new_pvp  discount  \
# 10       Large            4762.0             Évora     NaN       NaN
# 875     Medium            6540.0            Guarda     NaN       NaN
# 955      Large           21275.0              Beja     NaN       NaN
# 7564     Large           21275.0              Beja     NaN       NaN
# 7572     Small             342.0  Viana do Castelo     NaN       NaN
# 7578    Medium            3344.0              Faro     NaN       NaN
# 7583    Medium            3344.0              Faro     NaN       NaN
# 7585    Medium            3344.0              Faro     NaN       NaN
# 21531   Medium            6540.0            Guarda     NaN       NaN
# 21539   Medium            6540.0            Guarda     NaN       NaN
# 45363   Medium            5130.0            Aveiro     NaN       NaN
# 45375   Medium            5130.0            Aveiro     NaN       NaN
# 45379   Medium            5130.0            Aveiro     NaN       NaN
# 62530   Medium             833.0            Lisboa     NaN       NaN
# 62541   Medium             833.0            Lisboa     NaN       NaN
# 134858  Medium            7005.0            Lisboa     NaN       NaN
# 134859  Medium            7005.0            Lisboa     NaN       NaN
# 134860  Medium            7005.0            Lisboa     NaN       NaN
# 134861  Medium            7005.0            Lisboa     NaN       NaN
# 134862  Medium            7005.0            Lisboa     NaN       NaN
# 134863  Medium            7005.0            Lisboa     NaN       NaN
# 137336  Medium            6490.0              Faro     NaN       NaN
# 138552  Medium            6223.0          Bragança     NaN       NaN
# 139814  Medium            8306.0              Beja     NaN       NaN
# 140225  Medium           12009.0    Castelo Branco     NaN       NaN
# 140884  Medium             429.0         Vila Real     NaN       NaN
# 143169  Medium            4086.0            Leiria     NaN       NaN
# 143945   Large           21275.0              Beja     NaN       NaN
#
#         Margem_num  selling_day  selling_day_of_week
# 10            0.16          3.0               Sunday
# 875           0.10         16.0             Saturday
# 955           0.15         28.0             Thursday
# 7564          0.19          NaN                  NaN
# 7572          0.19          NaN                  NaN
# 7578          0.19         19.0              Tuesday
# 7583          0.19         14.0             Thursday
# 7585          0.19          NaN                  NaN
# 21531         0.13         11.0               Monday
# 21539         0.13          NaN                  NaN
# 45363         0.17          NaN                  NaN
# 45375         0.17          NaN                  NaN
# 45379         0.17          NaN                  NaN
# 62530         0.19          NaN                  NaN
# 62541         0.19          NaN                  NaN
# 134858        0.11          NaN                  NaN
# 134859        0.11          NaN                  NaN
# 134860        0.11          NaN                  NaN
# 134861        0.11         14.0             Thursday
# 134862        0.11          NaN                  NaN
# 134863        0.11          NaN                  NaN
# 137336        0.20         28.0             Thursday
# 138552        0.20          NaN                  NaN
# 139814        0.20          NaN                  NaN
# 140225        0.20         22.0               Friday
# 140884        0.20          NaN                  NaN
# 143169        0.19          7.0             Thursday
# 143945        0.20          8.0               Friday
#
# [28 rows x 21 columns]

# %%
db['new_pvp'] = np.where(db['new_pvp'].isnull(), db['Profit (€)'] / db['Margem_num'], db['new_pvp'])
db['discount'] = np.where(db['discount'].isnull(), 1 - (db['new_pvp'] / db['oldpvp']), db['discount'])

# %%
db.isna().sum()
# Out:
# idstore                    0
# sku                        0
# brand                      0
# oldpvp                     0
# labelqty                   0
# weight (g)                 0
# Payment_method             0
# Profit (€)                 0
# perc_expiring_sku          0
# expiring_date              0
# labelling_date             0
# sell_date              69542
# sold                       0
# type                       0
# selling_square_ft      10779
# district                   0
# new_pvp                    0
# discount                   0
# Margem_num                 0
# selling_day            69542
# selling_day_of_week    69542
# dtype: int64

# %% [markdown]
# ### selling_square_ft

# %%
mean_selling_square_ft = db.groupby(['type', 'district'])['selling_square_ft'].mean()
mean_selling_square_ft
# Out:
# type    district
# 0       Vila Real                    NaN
# Large   Aveiro              12280.375591
#         Beja                21275.000000
#         Bragança            14404.602714
#         Castelo Branco      21060.000000
#         Coimbra             13665.562942
#         Faro                14067.901431
#         Guarda              12906.919742
#         Leiria              20345.739026
#         Lisboa              10005.033223
#         Portalegre          10586.000000
#         Porto               13494.438141
#         Santarém            18100.000000
#         Setúbal             13480.000000
#         Viana do Castelo    18493.843015
#         Vila Real           17914.020225
#         Évora               11714.023121
# Medium  Aveiro               6083.968760
#         Beja                 7453.942308
#         Braga                5210.404864
#         Bragança             6957.251445
#         Castelo Branco       7836.934944
#         Coimbra              7797.401488
#         Faro                 6492.545366
#         Guarda               6564.866019
#         Leiria               6666.022398
#         Lisboa               4496.340101
#         Portalegre           6119.225166
#         Porto                7001.289432
#         Santarém             7397.800275
#         Setúbal              5678.853468
#         Viana do Castelo     8225.274427
#         Vila Real            4698.360563
#         Viseu                6095.381892
#         Évora                4806.859155
# Small   Aveiro               1034.742148
#         Beja                 1377.581365
#         Braga                1591.070662
#         Bragança             1120.833333
#         Castelo Branco        870.511515
#         Coimbra               900.856024
#         Faro                 1485.457224
#         Guarda               1363.555969
#         Leiria                695.195246
#         Lisboa                877.394903
#         Portalegre           1699.801715
#         Porto                1196.163082
#         Santarém             1308.000000
#         Setúbal               968.487794
#         Viana do Castelo      817.076433
#         Vila Real             456.469198
#         Viseu                1060.255647
#         Évora                1094.118616
# Name: selling_square_ft, dtype: float64

# %%
for (store_type, district), mean_value in mean_selling_square_ft.items():
    db.loc[(db['type'] == store_type) & (db['district'] == district) & (db['selling_square_ft'].isnull()), 'selling_square_ft'] = mean_value

# %%
db.isnull().sum()
# Out:
# idstore                    0
# sku                        0
# brand                      0
# oldpvp                     0
# labelqty                   0
# weight (g)                 0
# Payment_method             0
# Profit (€)                 0
# perc_expiring_sku          0
# expiring_date              0
# labelling_date             0
# sell_date              69542
# sold                       0
# type                       0
# selling_square_ft        646
# district                   0
# new_pvp                    0
# discount                   0
# Margem_num                 0
# selling_day            69542
# selling_day_of_week    69542
# dtype: int64

# %%
# prompt: mostra-me as linhas em que selling_square_ft está nulo

# Display rows where 'selling_square_ft' is null
aindanulo = db[db['selling_square_ft'].isnull()]
aindanulo
# Out:
#        idstore  sku   brand  oldpvp  labelqty  weight (g) Payment_method  \
# 3623       194    8  marca2    1.19         1       174.0           Cash
# 3624       194    8  marca2    1.19         1       174.0           Cash
# 3625       194    8  marca2    1.19         1       174.0           Card
# 3626       194    8  marca2    1.19         1       174.0           Cash
# 3627       194    8  marca2    1.19         1       174.0           Cash
# ...        ...  ...     ...     ...       ...         ...            ...
# 146747     194  302  marca2    1.19         1       147.0       not_sell
# 146748     194  302  marca2    1.19         1       147.0       not_sell
# 146749     194  302  marca2    1.19         1       147.0       not_sell
# 146750     194  302  marca2    1.19         1       147.0           Cash
# 146751     194  302  marca2    1.19         1       147.0       not_sell
#
#         Profit (€)  perc_expiring_sku expiring_date  ...  sell_date   sold  \
# 3623          0.12                0.4    2021-10-07  ... 2021-10-07   True
# 3624          0.12                0.4    2021-10-08  ... 2021-10-07   True
# 3625          0.12                0.4    2021-10-08  ... 2021-10-07   True
# 3626          0.12                0.4    2021-10-21  ... 2021-10-20   True
# 3627          0.12                0.4    2021-10-21  ... 2021-10-20   True
# ...            ...                ...           ...  ...        ...    ...
# 146747        0.17                0.0    2021-10-25  ...        NaT  False
# 146748        0.17                0.0    2021-10-25  ...        NaT  False
# 146749        0.17                0.0    2021-10-25  ...        NaT  False
# 146750        0.17                0.2    2021-10-26  ... 2021-10-26   True
# 146751        0.17                0.2    2021-10-26  ...        NaT  False
#
#         type selling_square_ft   district new_pvp  discount  Margem_num  \
# 3623       0               NaN  Vila Real    0.83       0.3        0.15
# 3624       0               NaN  Vila Real    0.83       0.3        0.15
# 3625       0               NaN  Vila Real    0.83       0.3        0.15
# 3626       0               NaN  Vila Real    0.83       0.3        0.15
# 3627       0               NaN  Vila Real    0.83       0.3        0.15
# ...      ...               ...        ...     ...       ...         ...
# 146747     0               NaN  Vila Real    0.83       0.3        0.20
# 146748     0               NaN  Vila Real    0.83       0.3        0.20
# 146749     0               NaN  Vila Real    0.83       0.3        0.20
# 146750     0               NaN  Vila Real    0.83       0.3        0.20
# 146751     0               NaN  Vila Real    0.83       0.3        0.20
#
#         selling_day  selling_day_of_week
# 3623            7.0             Thursday
# 3624            7.0             Thursday
# 3625            7.0             Thursday
# 3626           20.0            Wednesday
# 3627           20.0            Wednesday
# ...             ...                  ...
# 146747          NaN                  NaN
# 146748          NaN                  NaN
# 146749          NaN                  NaN
# 146750         26.0              Tuesday
# 146751          NaN                  NaN
#
# [646 rows x 21 columns]

# %%
aindanulo['idstore'].value_counts()
# Out:
# idstore
# 194    646
# Name: count, dtype: int64

# %%
db['type'].value_counts()
# Out:
# type
# Medium    62590
# Small     60598
# Large     26219
# 0           646
# Name: count, dtype: int64

# %%
db['type'] = db['type'].replace('0', 'Medium')

# %%
for (store_type, district), mean_value in mean_selling_square_ft.items():
    db.loc[(db['type'] == store_type) & (db['district'] == district) & (db['selling_square_ft'].isnull()), 'selling_square_ft'] = mean_value

# %%
db.isna().sum()
# Out:
# idstore                    0
# sku                        0
# brand                      0
# oldpvp                     0
# labelqty                   0
# weight (g)                 0
# Payment_method             0
# Profit (€)                 0
# perc_expiring_sku          0
# expiring_date              0
# labelling_date             0
# sell_date              69542
# sold                       0
# type                       0
# selling_square_ft          0
# district                   0
# new_pvp                    0
# discount                   0
# Margem_num                 0
# selling_day            69542
# selling_day_of_week    69542
# dtype: int64

# %% [markdown]
# ## 3.3 Data Transformation

# %% [markdown]
# ### 3.3.1. Criação de variáveis

# %%
db.columns
# Out:
# Index(['idstore', 'sku', 'brand', 'oldpvp', 'labelqty', 'weight (g)',
#        'Payment_method', 'Profit (€)', 'perc_expiring_sku', 'expiring_date',
#        'labelling_date', 'sell_date', 'sold', 'type', 'selling_square_ft',
#        'district', 'new_pvp', 'discount', 'Margem_num', 'selling_day',
#        'selling_day_of_week'],
#       dtype='object')

# %% [markdown]
# #### Vida util após labelling

# %%
db['vida_util_apos_label'] = (db['expiring_date'] - db['labelling_date']).dt.days

# %% [markdown]
# #### Numero de dias entre labelling date e sell_date

# %%
db['dias_sell_labelling'] = (db['sell_date'] - db['labelling_date']).dt.days
db
# Out:
#        idstore  sku    brand  oldpvp  labelqty  weight (g) Payment_method  \
# 0            1    1   marca1    4.22         1       260.0           Card
# 1            1    1   marca1    3.96         1       260.0       not_sell
# 2            1    1   marca1    4.74         1       260.0           Cash
# 3            1    1   marca1    4.20         1       260.0           Card
# 4            1    1   marca1    4.62         1       260.0           Cash
# ...        ...  ...      ...     ...       ...         ...            ...
# 150049     193  318   marca2    2.49         1        97.0       not_sell
# 150050     203  318   marca2    2.49         1        97.0           Cash
# 150051     203  318   marca2    2.49         1        97.0           Cash
# 150052     139  319  marca24    3.49         1       141.0           Cash
# 150053     139  319  marca24    3.49         1       141.0       not_sell
#
#         Profit (€)  perc_expiring_sku expiring_date  ...    type  \
# 0             0.34           0.010050    2021-10-03  ...   Large
# 1             0.32           0.005025    2021-10-02  ...   Large
# 2             0.38           0.010050    2021-10-03  ...   Large
# 3             0.34           0.010050    2021-10-03  ...   Large
# 4             0.37           0.010050    2021-10-03  ...   Large
# ...            ...                ...           ...  ...     ...
# 150049        0.14           0.100629    2021-10-19  ...  Medium
# 150050        0.14           0.113208    2021-10-19  ...  Medium
# 150051        0.14           0.113208    2021-10-19  ...  Medium
# 150052        0.46           0.092437    2021-10-17  ...   Small
# 150053        0.46           0.092437    2021-10-17  ...   Small
#
#        selling_square_ft    district new_pvp  discount Margem_num  \
# 0                 4762.0       Évora    2.11       0.5       0.16
# 1                 4762.0       Évora    1.98       0.5       0.16
# 2                 4762.0       Évora    2.37       0.5       0.16
# 3                 4762.0       Évora    2.10       0.5       0.16
# 4                 4762.0       Évora    2.31       0.5       0.16
# ...                  ...         ...     ...       ...        ...
# 150049            5048.0       Viseu    1.24       0.5       0.11
# 150050            9370.0        Faro    1.24       0.5       0.11
# 150051            9370.0        Faro    1.24       0.5       0.11
# 150052            1061.0  Portalegre    2.44       0.3       0.19
# 150053            1061.0  Portalegre    2.44       0.3       0.19
#
#         selling_day  selling_day_of_week  vida_util_apos_label  \
# 0               2.0             Saturday                     2
# 1               NaN                  NaN                     1
# 2               3.0               Sunday                     2
# 3               2.0             Saturday                     2
# 4               3.0               Sunday                     2
# ...             ...                  ...                   ...
# 150049          NaN                  NaN                    16
# 150050          2.0             Saturday                    18
# 150051          2.0             Saturday                    18
# 150052         11.0               Monday                    11
# 150053          NaN                  NaN                    11
#
#         dias_sell_labelling
# 0                       1.0
# 1                       NaN
# 2                       2.0
# 3                       1.0
# 4                       2.0
# ...                     ...
# 150049                  NaN
# 150050                  1.0
# 150051                  1.0
# 150052                  5.0
# 150053                  NaN
#
# [150053 rows x 23 columns]

# %% [markdown]
# #### labelling_day_of_week

# %%
db['labelling_day_of_week'] = db['labelling_date'].dt.day_name()
db.head()
# Out:
#   idstore sku   brand  oldpvp  labelqty  weight (g) Payment_method  \
# 0       1   1  marca1    4.22         1       260.0           Card
# 1       1   1  marca1    3.96         1       260.0       not_sell
# 2       1   1  marca1    4.74         1       260.0           Cash
# 3       1   1  marca1    4.20         1       260.0           Card
# 4       1   1  marca1    4.62         1       260.0           Cash
#
#    Profit (€)  perc_expiring_sku expiring_date  ... selling_square_ft  \
# 0        0.34           0.010050    2021-10-03  ...            4762.0
# 1        0.32           0.005025    2021-10-02  ...            4762.0
# 2        0.38           0.010050    2021-10-03  ...            4762.0
# 3        0.34           0.010050    2021-10-03  ...            4762.0
# 4        0.37           0.010050    2021-10-03  ...            4762.0
#
#   district  new_pvp discount  Margem_num selling_day  selling_day_of_week  \
# 0    Évora     2.11      0.5        0.16         2.0             Saturday
# 1    Évora     1.98      0.5        0.16         NaN                  NaN
# 2    Évora     2.37      0.5        0.16         3.0               Sunday
# 3    Évora     2.10      0.5        0.16         2.0             Saturday
# 4    Évora     2.31      0.5        0.16         3.0               Sunday
#
#    vida_util_apos_label  dias_sell_labelling  labelling_day_of_week
# 0                     2                  1.0                 Friday
# 1                     1                  NaN                 Friday
# 2                     2                  2.0                 Friday
# 3                     2                  1.0                 Friday
# 4                     2                  2.0                 Friday
#
# [5 rows x 24 columns]

# %% [markdown]
# #### labelling_day

# %%
db['labelling_day'] = db['labelling_date'].dt.day
db.head()
# Out:
#   idstore sku   brand  oldpvp  labelqty  weight (g) Payment_method  \
# 0       1   1  marca1    4.22         1       260.0           Card
# 1       1   1  marca1    3.96         1       260.0       not_sell
# 2       1   1  marca1    4.74         1       260.0           Cash
# 3       1   1  marca1    4.20         1       260.0           Card
# 4       1   1  marca1    4.62         1       260.0           Cash
#
#    Profit (€)  perc_expiring_sku expiring_date  ... district new_pvp  \
# 0        0.34           0.010050    2021-10-03  ...    Évora    2.11
# 1        0.32           0.005025    2021-10-02  ...    Évora    1.98
# 2        0.38           0.010050    2021-10-03  ...    Évora    2.37
# 3        0.34           0.010050    2021-10-03  ...    Évora    2.10
# 4        0.37           0.010050    2021-10-03  ...    Évora    2.31
#
#    discount Margem_num  selling_day selling_day_of_week  vida_util_apos_label  \
# 0       0.5       0.16          2.0            Saturday                     2
# 1       0.5       0.16          NaN                 NaN                     1
# 2       0.5       0.16          3.0              Sunday                     2
# 3       0.5       0.16          2.0            Saturday                     2
# 4       0.5       0.16          3.0              Sunday                     2
#
#    dias_sell_labelling  labelling_day_of_week  labelling_day
# 0                  1.0                 Friday              1
# 1                  NaN                 Friday              1
# 2                  2.0                 Friday              1
# 3                  1.0                 Friday              1
# 4                  2.0                 Friday              1
#
# [5 rows x 25 columns]

# %% [markdown]
# ### 3.3.2 Incoerências

# %% [markdown]
# #### Cálculo do old_pvp * (1 - desconto) = new_pvp

# %%
db['new_pvp_calculado']=(db['oldpvp']*(1-db['discount']))
db
# Out:
#        idstore  sku    brand  oldpvp  labelqty  weight (g) Payment_method  \
# 0            1    1   marca1    4.22         1       260.0           Card
# 1            1    1   marca1    3.96         1       260.0       not_sell
# 2            1    1   marca1    4.74         1       260.0           Cash
# 3            1    1   marca1    4.20         1       260.0           Card
# 4            1    1   marca1    4.62         1       260.0           Cash
# ...        ...  ...      ...     ...       ...         ...            ...
# 150049     193  318   marca2    2.49         1        97.0       not_sell
# 150050     203  318   marca2    2.49         1        97.0           Cash
# 150051     203  318   marca2    2.49         1        97.0           Cash
# 150052     139  319  marca24    3.49         1       141.0           Cash
# 150053     139  319  marca24    3.49         1       141.0       not_sell
#
#         Profit (€)  perc_expiring_sku expiring_date  ... new_pvp discount  \
# 0             0.34           0.010050    2021-10-03  ...    2.11      0.5
# 1             0.32           0.005025    2021-10-02  ...    1.98      0.5
# 2             0.38           0.010050    2021-10-03  ...    2.37      0.5
# 3             0.34           0.010050    2021-10-03  ...    2.10      0.5
# 4             0.37           0.010050    2021-10-03  ...    2.31      0.5
# ...            ...                ...           ...  ...     ...      ...
# 150049        0.14           0.100629    2021-10-19  ...    1.24      0.5
# 150050        0.14           0.113208    2021-10-19  ...    1.24      0.5
# 150051        0.14           0.113208    2021-10-19  ...    1.24      0.5
# 150052        0.46           0.092437    2021-10-17  ...    2.44      0.3
# 150053        0.46           0.092437    2021-10-17  ...    2.44      0.3
#
#         Margem_num selling_day  selling_day_of_week vida_util_apos_label  \
# 0             0.16         2.0             Saturday                    2
# 1             0.16         NaN                  NaN                    1
# 2             0.16         3.0               Sunday                    2
# 3             0.16         2.0             Saturday                    2
# 4             0.16         3.0               Sunday                    2
# ...            ...         ...                  ...                  ...
# 150049        0.11         NaN                  NaN                   16
# 150050        0.11         2.0             Saturday                   18
# 150051        0.11         2.0             Saturday                   18
# 150052        0.19        11.0               Monday                   11
# 150053        0.19         NaN                  NaN                   11
#
#         dias_sell_labelling  labelling_day_of_week  labelling_day  \
# 0                       1.0                 Friday              1
# 1                       NaN                 Friday              1
# 2                       2.0                 Friday              1
# 3                       1.0                 Friday              1
# 4                       2.0                 Friday              1
# ...                     ...                    ...            ...
# 150049                  NaN                 Sunday              3
# 150050                  1.0                 Friday              1
# 150051                  1.0                 Friday              1
# 150052                  5.0              Wednesday              6
# 150053                  NaN              Wednesday              6
#
#         new_pvp_calculado
# 0                   2.110
# 1                   1.980
# 2                   2.370
# 3                   2.100
# 4                   2.310
# ...                   ...
# 150049              1.245
# 150050              1.245
# 150051              1.245
# 150052              2.443
# 150053              2.443
#
# [150053 rows x 26 columns]

# %%
db['diferenca_new_pvp']=(db['new_pvp_calculado']-db['new_pvp']).round(2)
db[db['diferenca_new_pvp'] > 0.01]
# Out:
# Empty DataFrame
# Columns: [idstore, sku, brand, oldpvp, labelqty, weight (g), Payment_method, Profit (€), perc_expiring_sku, expiring_date, labelling_date, sell_date, sold, type, selling_square_ft, district, new_pvp, discount, Margem_num, selling_day, selling_day_of_week, vida_util_apos_label, dias_sell_labelling, labelling_day_of_week, labelling_day, new_pvp_calculado, diferenca_new_pvp]
# Index: []
#
# [0 rows x 27 columns]

# %%
dbteste = db[['oldpvp','new_pvp','discount','new_pvp_calculado','diferenca_new_pvp']]
dbteste[dbteste['diferenca_new_pvp'] > 0.01]
# Out:
# Empty DataFrame
# Columns: [oldpvp, new_pvp, discount, new_pvp_calculado, diferenca_new_pvp]
# Index: []

# %%
db.tail()
# Out:
#        idstore  sku    brand  oldpvp  labelqty  weight (g) Payment_method  \
# 150049     193  318   marca2    2.49         1        97.0       not_sell
# 150050     203  318   marca2    2.49         1        97.0           Cash
# 150051     203  318   marca2    2.49         1        97.0           Cash
# 150052     139  319  marca24    3.49         1       141.0           Cash
# 150053     139  319  marca24    3.49         1       141.0       not_sell
#
#         Profit (€)  perc_expiring_sku expiring_date  ... discount Margem_num  \
# 150049        0.14           0.100629    2021-10-19  ...      0.5       0.11
# 150050        0.14           0.113208    2021-10-19  ...      0.5       0.11
# 150051        0.14           0.113208    2021-10-19  ...      0.5       0.11
# 150052        0.46           0.092437    2021-10-17  ...      0.3       0.19
# 150053        0.46           0.092437    2021-10-17  ...      0.3       0.19
#
#         selling_day selling_day_of_week  vida_util_apos_label  \
# 150049          NaN                 NaN                    16
# 150050          2.0            Saturday                    18
# 150051          2.0            Saturday                    18
# 150052         11.0              Monday                    11
# 150053          NaN                 NaN                    11
#
#        dias_sell_labelling  labelling_day_of_week  labelling_day  \
# 150049                 NaN                 Sunday              3
# 150050                 1.0                 Friday              1
# 150051                 1.0                 Friday              1
# 150052                 5.0              Wednesday              6
# 150053                 NaN              Wednesday              6
#
#         new_pvp_calculado  diferenca_new_pvp
# 150049              1.245               0.01
# 150050              1.245               0.01
# 150051              1.245               0.01
# 150052              2.443               0.00
# 150053              2.443               0.00
#
# [5 rows x 27 columns]

# %% [markdown]
# #### new_pvp*margem = profit

# %%
db['profit_calculado']=(db['new_pvp']*db['Margem_num']).round(2)
db
# Out:
#        idstore  sku    brand  oldpvp  labelqty  weight (g) Payment_method  \
# 0            1    1   marca1    4.22         1       260.0           Card
# 1            1    1   marca1    3.96         1       260.0       not_sell
# 2            1    1   marca1    4.74         1       260.0           Cash
# 3            1    1   marca1    4.20         1       260.0           Card
# 4            1    1   marca1    4.62         1       260.0           Cash
# ...        ...  ...      ...     ...       ...         ...            ...
# 150049     193  318   marca2    2.49         1        97.0       not_sell
# 150050     203  318   marca2    2.49         1        97.0           Cash
# 150051     203  318   marca2    2.49         1        97.0           Cash
# 150052     139  319  marca24    3.49         1       141.0           Cash
# 150053     139  319  marca24    3.49         1       141.0       not_sell
#
#         Profit (€)  perc_expiring_sku expiring_date  ... Margem_num  \
# 0             0.34           0.010050    2021-10-03  ...       0.16
# 1             0.32           0.005025    2021-10-02  ...       0.16
# 2             0.38           0.010050    2021-10-03  ...       0.16
# 3             0.34           0.010050    2021-10-03  ...       0.16
# 4             0.37           0.010050    2021-10-03  ...       0.16
# ...            ...                ...           ...  ...        ...
# 150049        0.14           0.100629    2021-10-19  ...       0.11
# 150050        0.14           0.113208    2021-10-19  ...       0.11
# 150051        0.14           0.113208    2021-10-19  ...       0.11
# 150052        0.46           0.092437    2021-10-17  ...       0.19
# 150053        0.46           0.092437    2021-10-17  ...       0.19
#
#        selling_day  selling_day_of_week vida_util_apos_label  \
# 0              2.0             Saturday                    2
# 1              NaN                  NaN                    1
# 2              3.0               Sunday                    2
# 3              2.0             Saturday                    2
# 4              3.0               Sunday                    2
# ...            ...                  ...                  ...
# 150049         NaN                  NaN                   16
# 150050         2.0             Saturday                   18
# 150051         2.0             Saturday                   18
# 150052        11.0               Monday                   11
# 150053         NaN                  NaN                   11
#
#         dias_sell_labelling labelling_day_of_week  labelling_day  \
# 0                       1.0                Friday              1
# 1                       NaN                Friday              1
# 2                       2.0                Friday              1
# 3                       1.0                Friday              1
# 4                       2.0                Friday              1
# ...                     ...                   ...            ...
# 150049                  NaN                Sunday              3
# 150050                  1.0                Friday              1
# 150051                  1.0                Friday              1
# 150052                  5.0             Wednesday              6
# 150053                  NaN             Wednesday              6
#
#         new_pvp_calculado  diferenca_new_pvp  profit_calculado
# 0                   2.110               0.00              0.34
# 1                   1.980               0.00              0.32
# 2                   2.370               0.00              0.38
# 3                   2.100               0.00              0.34
# 4                   2.310               0.00              0.37
# ...                   ...                ...               ...
# 150049              1.245               0.01              0.14
# 150050              1.245               0.01              0.14
# 150051              1.245               0.01              0.14
# 150052              2.443               0.00              0.46
# 150053              2.443               0.00              0.46
#
# [150053 rows x 28 columns]

# %%
db['diferenca_profit']=(db['profit_calculado']-db['Profit (€)']).round(2)
dbprofiterrado = db[db['diferenca_profit'] > 0.01]
dbprofiterrado
# Out:
# Empty DataFrame
# Columns: [idstore, sku, brand, oldpvp, labelqty, weight (g), Payment_method, Profit (€), perc_expiring_sku, expiring_date, labelling_date, sell_date, sold, type, selling_square_ft, district, new_pvp, discount, Margem_num, selling_day, selling_day_of_week, vida_util_apos_label, dias_sell_labelling, labelling_day_of_week, labelling_day, new_pvp_calculado, diferenca_new_pvp, profit_calculado, diferenca_profit]
# Index: []
#
# [0 rows x 29 columns]

# %% [markdown]
# #### selling_date inferior à labelling_date

# %%
db.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 150053 entries, 0 to 150053
# Data columns (total 29 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   idstore                150053 non-null  object
#  1   sku                    150053 non-null  object
#  2   brand                  150053 non-null  object
#  3   oldpvp                 150053 non-null  float64
#  4   labelqty               150053 non-null  int64
#  5   weight (g)             150053 non-null  float64
#  6   Payment_method         150053 non-null  object
#  7   Profit (€)             150053 non-null  float64
#  8   perc_expiring_sku      150053 non-null  float64
#  9   expiring_date          150053 non-null  datetime64[ns]
#  10  labelling_date         150053 non-null  datetime64[ns]
#  11  sell_date              80511 non-null   datetime64[ns]
#  12  sold                   150053 non-null  bool
#  13  type                   150053 non-null  object
#  14  selling_square_ft      150053 non-null  float64
#  15  district               150053 non-null  object
#  16  new_pvp                150053 non-null  float64
#  17  discount               150053 non-null  float64
#  18  Margem_num             150053 non-null  float64
#  19  selling_day            80511 non-null   float64
#  20  selling_day_of_week    80511 non-null   object
#  21  vida_util_apos_label   150053 non-null  int64
#  22  dias_sell_labelling    80511 non-null   float64
#  23  labelling_day_of_week  150053 non-null  object
#  24  labelling_day          150053 non-null  int32
#  25  new_pvp_calculado      150053 non-null  float64
#  26  diferenca_new_pvp      150053 non-null  float64
#  27  profit_calculado       150053 non-null  float64
#  28  diferenca_profit       150053 non-null  float64
# dtypes: bool(1), datetime64[ns](3), float64(14), int32(1), int64(2), object(8)
# memory usage: 36.8+ MB

# %%
db['dif_sell_labelling_date'] = (db['sell_date'] - db['labelling_date']).dt.days
db
# Out:
#        idstore  sku    brand  oldpvp  labelqty  weight (g) Payment_method  \
# 0            1    1   marca1    4.22         1       260.0           Card
# 1            1    1   marca1    3.96         1       260.0       not_sell
# 2            1    1   marca1    4.74         1       260.0           Cash
# 3            1    1   marca1    4.20         1       260.0           Card
# 4            1    1   marca1    4.62         1       260.0           Cash
# ...        ...  ...      ...     ...       ...         ...            ...
# 150049     193  318   marca2    2.49         1        97.0       not_sell
# 150050     203  318   marca2    2.49         1        97.0           Cash
# 150051     203  318   marca2    2.49         1        97.0           Cash
# 150052     139  319  marca24    3.49         1       141.0           Cash
# 150053     139  319  marca24    3.49         1       141.0       not_sell
#
#         Profit (€)  perc_expiring_sku expiring_date  ... selling_day_of_week  \
# 0             0.34           0.010050    2021-10-03  ...            Saturday
# 1             0.32           0.005025    2021-10-02  ...                 NaN
# 2             0.38           0.010050    2021-10-03  ...              Sunday
# 3             0.34           0.010050    2021-10-03  ...            Saturday
# 4             0.37           0.010050    2021-10-03  ...              Sunday
# ...            ...                ...           ...  ...                 ...
# 150049        0.14           0.100629    2021-10-19  ...                 NaN
# 150050        0.14           0.113208    2021-10-19  ...            Saturday
# 150051        0.14           0.113208    2021-10-19  ...            Saturday
# 150052        0.46           0.092437    2021-10-17  ...              Monday
# 150053        0.46           0.092437    2021-10-17  ...                 NaN
#
#        vida_util_apos_label  dias_sell_labelling labelling_day_of_week  \
# 0                         2                  1.0                Friday
# 1                         1                  NaN                Friday
# 2                         2                  2.0                Friday
# 3                         2                  1.0                Friday
# 4                         2                  2.0                Friday
# ...                     ...                  ...                   ...
# 150049                   16                  NaN                Sunday
# 150050                   18                  1.0                Friday
# 150051                   18                  1.0                Friday
# 150052                   11                  5.0             Wednesday
# 150053                   11                  NaN             Wednesday
#
#         labelling_day new_pvp_calculado  diferenca_new_pvp  profit_calculado  \
# 0                   1             2.110               0.00              0.34
# 1                   1             1.980               0.00              0.32
# 2                   1             2.370               0.00              0.38
# 3                   1             2.100               0.00              0.34
# 4                   1             2.310               0.00              0.37
# ...               ...               ...                ...               ...
# 150049              3             1.245               0.01              0.14
# 150050              1             1.245               0.01              0.14
# 150051              1             1.245               0.01              0.14
# 150052              6             2.443               0.00              0.46
# 150053              6             2.443               0.00              0.46
#
#         diferenca_profit  dif_sell_labelling_date
# 0                    0.0                      1.0
# 1                    0.0                      NaN
# 2                    0.0                      2.0
# 3                    0.0                      1.0
# 4                    0.0                      2.0
# ...                  ...                      ...
# 150049               0.0                      NaN
# 150050               0.0                      1.0
# 150051               0.0                      1.0
# 150052               0.0                      5.0
# 150053               0.0                      NaN
#
# [150053 rows x 30 columns]

# %%
db_dataerrada = db[db['dif_sell_labelling_date']<0]
db_dataerrada
# Out:
#       idstore  sku   brand  oldpvp  labelqty  weight (g) Payment_method  \
# 1143       17    8  marca2    1.19         1       174.0           Card
# 1144       17    8  marca2    1.19         1       174.0           Card
# 1145       17    8  marca2    1.19         1       174.0           Cash
# 1146       17    8  marca2    1.19         1       174.0           Card
# 39214      17  102  marca2    0.99         1       188.0           Card
# 39215      17  102  marca2    0.99         1       188.0           Cash
#
#        Profit (€)  perc_expiring_sku expiring_date  ... selling_day_of_week  \
# 1143         0.12                0.2    2021-10-22  ...           Wednesday
# 1144         0.12                0.2    2021-10-22  ...           Wednesday
# 1145         0.12                0.2    2021-10-22  ...           Wednesday
# 1146         0.12                0.2    2021-10-22  ...           Wednesday
# 39214        0.08                0.5    2021-10-22  ...           Wednesday
# 39215        0.08                0.5    2021-10-22  ...           Wednesday
#
#       vida_util_apos_label  dias_sell_labelling labelling_day_of_week  \
# 1143                     1                 -1.0              Thursday
# 1144                     1                 -1.0              Thursday
# 1145                     1                 -1.0              Thursday
# 1146                     1                 -1.0              Thursday
# 39214                    1                 -1.0              Thursday
# 39215                    1                 -1.0              Thursday
#
#        labelling_day new_pvp_calculado  diferenca_new_pvp  profit_calculado  \
# 1143              21             0.833                0.0              0.12
# 1144              21             0.833                0.0              0.12
# 1145              21             0.833                0.0              0.12
# 1146              21             0.833                0.0              0.12
# 39214             21             0.693                0.0              0.08
# 39215             21             0.693                0.0              0.08
#
#        diferenca_profit  dif_sell_labelling_date
# 1143                0.0                     -1.0
# 1144                0.0                     -1.0
# 1145                0.0                     -1.0
# 1146                0.0                     -1.0
# 39214               0.0                     -1.0
# 39215               0.0                     -1.0
#
# [6 rows x 30 columns]

# %%
db_dataerrada[['dif_sell_labelling_date','labelling_date','sell_date']]
# Out:
#        dif_sell_labelling_date labelling_date  sell_date
# 1143                      -1.0     2021-10-21 2021-10-20
# 1144                      -1.0     2021-10-21 2021-10-20
# 1145                      -1.0     2021-10-21 2021-10-20
# 1146                      -1.0     2021-10-21 2021-10-20
# 39214                     -1.0     2021-10-21 2021-10-20
# 39215                     -1.0     2021-10-21 2021-10-20

# %%
# prompt: sempre que o dif_sell_labelling_date for menor que 0, quero que a sell_date seja igual à labelling_date

# Set sell_date to labelling_date when dif_sell_labelling_date is less than 0
db.loc[db['dif_sell_labelling_date'] < 0, 'sell_date'] = db.loc[db['dif_sell_labelling_date'] < 0, 'labelling_date']

# Recalculate dif_sell_labelling_date after correction
db['dif_sell_labelling_date'] = (db['sell_date'] - db['labelling_date']).dt.days

# %%
db['dif_sell_labelling_date'] = (db['sell_date'] - db['labelling_date']).dt.days
db[db['dif_sell_labelling_date']<0]
# Out:
# Empty DataFrame
# Columns: [idstore, sku, brand, oldpvp, labelqty, weight (g), Payment_method, Profit (€), perc_expiring_sku, expiring_date, labelling_date, sell_date, sold, type, selling_square_ft, district, new_pvp, discount, Margem_num, selling_day, selling_day_of_week, vida_util_apos_label, dias_sell_labelling, labelling_day_of_week, labelling_day, new_pvp_calculado, diferenca_new_pvp, profit_calculado, diferenca_profit, dif_sell_labelling_date]
# Index: []
#
# [0 rows x 30 columns]

# %% [markdown]
# #### data de expiring superior à labelling

# %%
db.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 150053 entries, 0 to 150053
# Data columns (total 30 columns):
#  #   Column                   Non-Null Count   Dtype
# ---  ------                   --------------   -----
#  0   idstore                  150053 non-null  object
#  1   sku                      150053 non-null  object
#  2   brand                    150053 non-null  object
#  3   oldpvp                   150053 non-null  float64
#  4   labelqty                 150053 non-null  int64
#  5   weight (g)               150053 non-null  float64
#  6   Payment_method           150053 non-null  object
#  7   Profit (€)               150053 non-null  float64
#  8   perc_expiring_sku        150053 non-null  float64
#  9   expiring_date            150053 non-null  datetime64[ns]
#  10  labelling_date           150053 non-null  datetime64[ns]
#  11  sell_date                80511 non-null   datetime64[ns]
#  12  sold                     150053 non-null  bool
#  13  type                     150053 non-null  object
#  14  selling_square_ft        150053 non-null  float64
#  15  district                 150053 non-null  object
#  16  new_pvp                  150053 non-null  float64
#  17  discount                 150053 non-null  float64
#  18  Margem_num               150053 non-null  float64
#  19  selling_day              80511 non-null   float64
#  20  selling_day_of_week      80511 non-null   object
#  21  vida_util_apos_label     150053 non-null  int64
#  22  dias_sell_labelling      80511 non-null   float64
#  23  labelling_day_of_week    150053 non-null  object
#  24  labelling_day            150053 non-null  int32
#  25  new_pvp_calculado        150053 non-null  float64
#  26  diferenca_new_pvp        150053 non-null  float64
#  27  profit_calculado         150053 non-null  float64
#  28  diferenca_profit         150053 non-null  float64
#  29  dif_sell_labelling_date  80511 non-null   float64
# dtypes: bool(1), datetime64[ns](3), float64(15), int32(1), int64(2), object(8)
# memory usage: 37.9+ MB

# %%
db['dif_exp_labelling_date'] = (db['expiring_date'] - db['labelling_date']).dt.days
db[db['dif_exp_labelling_date']<0]
# Out:
# Empty DataFrame
# Columns: [idstore, sku, brand, oldpvp, labelqty, weight (g), Payment_method, Profit (€), perc_expiring_sku, expiring_date, labelling_date, sell_date, sold, type, selling_square_ft, district, new_pvp, discount, Margem_num, selling_day, selling_day_of_week, vida_util_apos_label, dias_sell_labelling, labelling_day_of_week, labelling_day, new_pvp_calculado, diferenca_new_pvp, profit_calculado, diferenca_profit, dif_sell_labelling_date, dif_exp_labelling_date]
# Index: []
#
# [0 rows x 31 columns]

# %% [markdown]
# # 4. Exportar dados para excel/csv

# %%
db.to_excel("db1.xlsx", index=False)

# %%
#db.to_csv("db.csv", index=False)
